# %%
# "Location - Nose, Eyelid, Nail, Lip, Genitalia, or Acral (L)" PE 100%/A&P 100%/A 100%

# Is there a cancerous tumor on the: Nose, Eyelid, Nail, Lip, Genitalia, or Acral (Y/N)

import os
import pandas as pd
import requests
import base64

#using azure
API_KEY = "2DWhd5NlWo6U8lpUBSWgyCuCL1bgNUAlQyv4sF2Oq6TsNxszq97NJQQJ99AKACHrzpqXJ3w3AAABACOGzNKu"
ENDPOINT = "https://rg-01-hippa-standalone-openai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-15-preview"

def call_gpt(query):
    headers = {
        "Content-Type": "application/json",
        "api-key": API_KEY,
    }
    
    # Payload for the request
    payload = {
    "messages" : [
            {"role": "system", "content": "Answer the question based only on the following context, which can include text and tables: "},
            {"role": "user", "content": f"{query}"},
        ],
      "temperature": 0.7,
      "top_p": 0.95,
      "max_tokens": 800
    }
    
    
    # Send request
    try:
        response = requests.post(ENDPOINT, headers=headers, json=payload)
        response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
    except requests.RequestException as e:
        print("Response Content:", response.text)
        raise SystemExit(f"Failed to make the request. Error: {e}")

    # Handle the response as needed (e.g., print or process)
    #print(response.json())
    #return response.json().choices[0].message.content
    return response.json()["choices"][0]["message"]["content"]

# %%
# Use full Excel sheet
import pandas as pd
Cat = pd.read_excel(r'../De-Identified Mohs Full Data.xlsx',sheet_name='Identified Data',header=0) # Only Size at Greatest Dimension column
Cat.head()
# Out:
#    Randomized Study Number  \
# 0                       36
# 1                      240
# 2                       32
# 3                      111
# 4                      197
#
#   Size at Greatest Dimension (S) ***Be  sure this is from the note and not the Mohs episode!  \
# 0                                                0.8
# 1                                                0.6
# 2                                                0.3
# 3                                                6.5
# 4                                                3.5
#
#   Recurrent Tumor (R)  \
# 0                   Y
# 1                   Y
# 2                   N
# 3                   N
# 4                   N
#
#   Location - Nose, Eyelid, Nail, Lip, Genitalia, or Acral (L)  \
# 0                                                  N
# 1                                                  Y
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Aggressive Tumor Pathology Type (AT) DFSP (D)  \
# 0                                    N        N
# 1                                    N        N
# 2                                    N        N
# 3                                    N        N
# 4                                    N        N
#
#   Coordinated repair with ENT/oculoplastics (C) Additional C&F  \
# 0                                             N              N
# 1                                             N              N
# 2                                             N              N
# 3                                             Y              N
# 4                                             N              Y
#
#   Additional Excision Multiple Sites  \
# 0                   N              N
# 1                   N              N
# 2                   N              N
# 3                   N              N
# 4                   Y              N
#
#    Business Days from Referral to First Appt  \
# 0                                       32.0
# 1                                       40.0
# 2                                        4.0
# 3                                       35.0
# 4                                       35.0
#
#                                   Physical Exam (PE)  \
# 0  Physical exam:\nGeneral: Well developed, well ...
# 1  Physical exam:\nGeneral: Well-dressed; well-no...
# 2  Physical exam:\nGeneral: Well-dressed; well-no...
# 3  Physical exam:\nVital signs: There were no vit...
# 4  Physical exam:\nGeneral: Well developed, well ...
#
#                              Assessment & Plan (A&P)  \
# 0  1. Chronic actinic damage in the setting of hi...
# 1  Procedure Orders\nBiopsy [486623795] ordered b...
# 2  Assessment & Plan: \n1. Brown papule on the le...
# 3  Assessment & Plan: \nBiopsy-proven basal cell ...
# 4  Assessment & Plan:  \n1. Chronic actinic sun d...
#
#                                         Addendum (A)
# 0  Addendum 7/11/2023\n \nThe pathology results w...
# 1  Addendum 7/11/2023\nThe pathology results were...
# 2  Addendum 7/13/2023\n \nThe pathology results w...
# 3                                                NaN
# 4  Addendum 7/5/2023\n \nThe pathology results we...

# %%
# Set options here
sample_size = len(Cat) # Change number to increase or decrease number of patients read from file
#sample_size = 10
multiple_columns = True # Set to True to use all input text columns, False to use only PE column

# Array of indexes containing patients with notes that have problems (Some may be ok, these are from size so a location could exist but not size)
skip_patients_array = [7,8,22,23,32,34,38,39,49,50,52,55,62,66,73,80,88,89,101,102,107,110,121,123,131,133,135,
                       136,137,140,150,155,157,164,170,184,187,193,200,206,210,214,227,228,229,234,252,261,265,279,287,292,293]
skip_patients = False # Set to True to skip bad patient notes, False to keep them in

# %%
# Takes the text in the PE, A&P, and A columns and asks ChatGPT to return "Yes" or "No" to the question
import re

# Always split into 3 GPT calls, one for each column
def inputSplit(input_columns, que, index):
    while len(input_columns) < 3: # Some text columns may be empty so add a blank entry
        input_columns.append("")
        
    input_string = " ".join(map(str, input_columns)) # Apply str() to each index of input_columns then join with a space
    prompt = f"{input_string} \n {que}" # Create base prompt (input_columns + question)
    
    if(len(input_string) > 0):
        tmp_ans = [""] * len(input_columns)
        check_ans = [""] * len(input_columns)
        
        # Split into 3 GPT calls, one per column, and remove anything that isn't a "Yes" or "No" from the result
        for i in range(len(input_columns)):
            prompt = f"{input_columns[i]} \n {que}" # Recreate prompt with 1 column + question
            tmp_ans[i] = call_gpt(prompt) # Call GPT with prompt and save answer to array
            
            print(f"tmp_ans[{i}] = {str(tmp_ans[i])}")
            
            check_ans[i] = re.split(r'\s+|-', tmp_ans[i])  # Split by spaces or hyphens
            check_ans[i] = [re.sub(r'[^a-zA-Z]', '', j) for j in check_ans[i]]  # Remove non-alphabetic characters
            check_ans[i] = [j.lower() for j in check_ans[i]]  # Convert all to lowercase to handle variations

            check_ans[i] = [j for j in check_ans[i] if j in ['yes', 'no']] # Keep only "yes" or "no"
            
            print(f"check_ans[{i}] = {str(check_ans[i])}")
            
        # Check if 2 arrays are the same output, if so return one of them if it is not empty
        if(check_ans[0] == check_ans[1] or check_ans[0] == check_ans[2]):
            if check_ans[0]:
                return tmp_ans[0]
            elif check_ans[1]:
                return tmp_ans[1]
            elif check_ans[2]:
                return tmp_ans[2]
        elif(check_ans[1] == check_ans[2]):
            if check_ans[1]:
                return tmp_ans[1]
            elif check_ans[2]:
                return tmp_ans[2]

        # Count num of "yes" and "no"
        yes_count = [0] * len(input_columns)
        no_count = [0] * len(input_columns)
        
        for i in range(len(check_ans)):
            yes_count[i] = check_ans[i].count('yes')
            no_count[i] = check_ans[i].count('no')
            
        print(f"Yes counts: {yes_count}")
        print(f"No counts: {no_count}")
        
        # If no matches, return string that has the most "yes" or "no"
        if any(count > 0 for count in yes_count) or any(count > 0 for count in no_count): # Check count strings for any occurences or "yes" or "no"
            max_yes_no = [0] * len(input_columns)
            max_answer = 0
            max_i = -1
            
            # Check if string has more "yes" or "no"
            for i in range(len(input_columns)):
                max_yes_no[i] = max(yes_count[i], no_count[i])
                
            # Look for highest overall "yes" or "no" then return that string
            for i in range(len(input_columns)):
                if max_answer < max_yes_no[i]:
                    max_answer = max_yes_no[i]
                    max_i = i
            return tmp_ans[max_i]
        
        # All non "yes" or "no" answers, return empty string
        return ""
    else:
        # Somehow input_string is empty
        return "input_string empty"
    

true_results = [0 for i in range(sample_size)]
true_results_final = [0 for i in range(sample_size)]

output = [0 for i in range(sample_size)]
output_final = [0 for i in range(sample_size)]

for i in range(0, min(sample_size, len(Cat))):
    # If skip_patients is True and current index is in skip_patients_array, move to next index
    if skip_patients and i in skip_patients_array:
        continue
        
    true_results[i] = Cat.at[i, 'Location - Nose, Eyelid, Nail, Lip, Genitalia, or Acral (L)']
    que = 'Question: Is there a cancerous tumor on the: Nose, Eyelid, Nail, Lip, Genitalia, or Acral? Answer with ONLY "Yes" or "No".'
    ans = ""
    
    if multiple_columns:
        input_columns = Cat.loc[i, ['Physical Exam (PE)', 'Assessment & Plan (A&P)', 'Addendum (A)']]
        ans = inputSplit(input_columns, que, i) # Result from GPT call
    elif not multiple_columns:
        input_columns = Cat.at[i, 'Physical Exam (PE)']
        prompt = f"{input_columns} \n {que}"
        #if(i != 47):
            #ans = call_gpt(prompt)
    
    print(f"Result[{i}] = {ans}")
    output[i] = ans
# Out:
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[0] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[1] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[2] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[3] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[4] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[5] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[6] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[7] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[8] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[9] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[10] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[11] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[12] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[13] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[14] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[15] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[16] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[17] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[18] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[19] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[20] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[21] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[22] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[23] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[24] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[25] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[26] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[27] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[28] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[29] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[30] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[31] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[32] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[33] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[34] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[35] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[36] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[37] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[38] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[39] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[40] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[41] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[42] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[43] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[44] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[45] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[46] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[47] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[48] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[49] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[50] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[51] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[52] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[53] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[54] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[55] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[56] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[57] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[58] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[59] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[60] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[61] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[62] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[63] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[64] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[65] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[66] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[67] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[68] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[69] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[70] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[71] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[72] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[73] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[74] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[75] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[76] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[77] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[78] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[79] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[80] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[81] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[82] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[83] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[84] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[85] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[86] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[87] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[88] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[89] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[90] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[91] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[92] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[93] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[94] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[95] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[96] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[97] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[98] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[99] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[100] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[101] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[102] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[103] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[104] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[105] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[106] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[107] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[108] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[109] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[110] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[111] = Yes
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[112] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[113] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[114] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[115] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[116] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[117] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[118] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[119] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[120] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[121] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[122] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[123] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[124] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[125] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[126] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[127] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[128] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[129] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[130] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[131] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[132] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[133] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[134] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[135] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[136] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[137] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[138] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[139] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[140] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[141] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[142] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[143] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[144] = Yes
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[145] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[146] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[147] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[148] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[149] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[150] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[151] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[152] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[153] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[154] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[155] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[156] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[157] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[158] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[159] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[160] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[161] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[162] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[163] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[164] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[165] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[166] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[167] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[168] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[169] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[170] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[171] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[172] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[173] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[174] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[175] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[176] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[177] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[178] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[179] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[180] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[181] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[182] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[183] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[184] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[185] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[186] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[187] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[188] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[189] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[190] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[191] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[192] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[193] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[194] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[195] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[196] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[197] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[198] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[199] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[200] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[201] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[202] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[203] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[204] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[205] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[206] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[207] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[208] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[209] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[210] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[211] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[212] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[213] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[214] = Yes
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[215] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[216] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[217] = Yes
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[218] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[219] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[220] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[221] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[222] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[223] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[224] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[225] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[226] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[227] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[228] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[229] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[230] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[231] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[232] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[233] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[234] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[235] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[236] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[237] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[238] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[239] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[240] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[241] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[242] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[243] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[244] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[245] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[246] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[247] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[248] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[249] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[250] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[251] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[252] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[253] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[254] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[255] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[256] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[257] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[258] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[259] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[260] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[261] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[262] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[263] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[264] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[265] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[266] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[267] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[268] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[269] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[270] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[271] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[272] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[273] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[274] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[275] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[276] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[277] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No.
# check_ans[2] = ['no']
# Result[278] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[279] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[280] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[281] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[282] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[283] = No
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[284] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[285] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[286] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[287] = No.
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[288] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[289] = No.
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[290] = No.
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[291] = No
# tmp_ans[0] = Yes
# check_ans[0] = ['yes']
# tmp_ans[1] = No.
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[292] = Yes
# tmp_ans[0] = No.
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[293] = No.

# %%
import re

# Go through every GPT response and turn it into "Y" or "N" to compare
for i in range(0, min(sample_size, len(Cat))):
    if skip_patients and i in skip_patients_array:
        continue
        
    yn = output[i]
    print(f"i={i} Answer: {yn}")
    yn_real = str(true_results[i])
    
    yn = re.split(r'\s+|-', yn)  # Split by spaces or hyphens
    yn = [re.sub(r'[^a-zA-Z]', '', j) for j in yn]  # Remove non-alphabetic characters
    yn = [j.lower() for j in yn]  # Convert all to lowercase to handle variations
    
    yn = [j for j in yn if j in ['yes', 'no']] # Keep only "yes" or "no"
    
    if len(yn) == 0:
        output_final[i] = "error_2"  # No valid response detected, bad prediction
    
    yes_count = yn.count('yes')
    no_count = yn.count('no')
    
    if yes_count > no_count:
        output_final[i] = "Y"
    elif no_count > yes_count:
        output_final[i] = "N"
        
    # Check if the given input is valid
    if yn_real.strip():
        true_results_final[i] = yn_real
    else:
        true_results_final[i] = "error_1" # No valid input provided in true_results, bad note
    
    print(f"Result[{i}]: ChatGPT Prediction = {output_final[i]} Answer Given = {true_results_final[i]}")
# Out:
# i=0 Answer: No
# Result[0]: ChatGPT Prediction = N Answer Given = N
# i=1 Answer: Yes
# Result[1]: ChatGPT Prediction = Y Answer Given = Y
# i=2 Answer: No.
# Result[2]: ChatGPT Prediction = N Answer Given = N
# i=3 Answer: No
# Result[3]: ChatGPT Prediction = N Answer Given = N
# i=4 Answer: No
# Result[4]: ChatGPT Prediction = N Answer Given = N
# i=5 Answer: No
# Result[5]: ChatGPT Prediction = N Answer Given = N
# i=6 Answer: Yes
# Result[6]: ChatGPT Prediction = Y Answer Given = Y
# i=7 Answer: No.
# Result[7]: ChatGPT Prediction = N Answer Given = N
# i=8 Answer: No
# Result[8]: ChatGPT Prediction = N Answer Given = N
# i=9 Answer: No.
# Result[9]: ChatGPT Prediction = N Answer Given = N
# i=10 Answer: No
# Result[10]: ChatGPT Prediction = N Answer Given = N
# i=11 Answer: No
# Result[11]: ChatGPT Prediction = N Answer Given = N
# i=12 Answer: No.
# Result[12]: ChatGPT Prediction = N Answer Given = N
# i=13 Answer: Yes
# Result[13]: ChatGPT Prediction = Y Answer Given = Y
# i=14 Answer: No.
# Result[14]: ChatGPT Prediction = N Answer Given = N
# i=15 Answer: Yes
# Result[15]: ChatGPT Prediction = Y Answer Given = Y
# i=16 Answer: No
# Result[16]: ChatGPT Prediction = N Answer Given = N
# i=17 Answer: No
# Result[17]: ChatGPT Prediction = N Answer Given = Y/N
# i=18 Answer: No.
# Result[18]: ChatGPT Prediction = N Answer Given = N
# i=19 Answer: No.
# Result[19]: ChatGPT Prediction = N Answer Given = N
# i=20 Answer: No
# Result[20]: ChatGPT Prediction = N Answer Given = N
# i=21 Answer: No.
# Result[21]: ChatGPT Prediction = N Answer Given = N
# i=22 Answer: Yes
# Result[22]: ChatGPT Prediction = Y Answer Given = Y/N
# i=23 Answer: No.
# Result[23]: ChatGPT Prediction = N Answer Given = N
# i=24 Answer: Yes
# Result[24]: ChatGPT Prediction = Y Answer Given = nan
# i=25 Answer: No
# Result[25]: ChatGPT Prediction = N Answer Given = N
# i=26 Answer: No
# Result[26]: ChatGPT Prediction = N Answer Given = N
# i=27 Answer: No
# Result[27]: ChatGPT Prediction = N Answer Given = N
# i=28 Answer: No.
# Result[28]: ChatGPT Prediction = N Answer Given = N
# i=29 Answer: No.
# Result[29]: ChatGPT Prediction = N Answer Given = N
# i=30 Answer: No.
# Result[30]: ChatGPT Prediction = N Answer Given = N
# i=31 Answer: No
# Result[31]: ChatGPT Prediction = N Answer Given = N
# i=32 Answer: No.
# Result[32]: ChatGPT Prediction = N Answer Given = N
# i=33 Answer: Yes
# Result[33]: ChatGPT Prediction = Y Answer Given = Y
# i=34 Answer: No.
# Result[34]: ChatGPT Prediction = N Answer Given = N
# i=35 Answer: Yes
# Result[35]: ChatGPT Prediction = Y Answer Given = Y
# i=36 Answer: No
# Result[36]: ChatGPT Prediction = N Answer Given = N/Y
# i=37 Answer: No.
# Result[37]: ChatGPT Prediction = N Answer Given = N
# i=38 Answer: No.
# Result[38]: ChatGPT Prediction = N Answer Given = N
# i=39 Answer: No.
# Result[39]: ChatGPT Prediction = N Answer Given = N
# i=40 Answer: No.
# Result[40]: ChatGPT Prediction = N Answer Given = N
# i=41 Answer: No.
# Result[41]: ChatGPT Prediction = N Answer Given = N
# i=42 Answer: No
# Result[42]: ChatGPT Prediction = N Answer Given = Y
# i=43 Answer: No
# Result[43]: ChatGPT Prediction = N Answer Given = N
# i=44 Answer: No.
# Result[44]: ChatGPT Prediction = N Answer Given = N
# i=45 Answer: No.
# Result[45]: ChatGPT Prediction = N Answer Given = N
# i=46 Answer: No
# Result[46]: ChatGPT Prediction = N Answer Given = Y/N/N
# i=47 Answer: No
# Result[47]: ChatGPT Prediction = N Answer Given = N
# i=48 Answer: No.
# Result[48]: ChatGPT Prediction = N Answer Given = N
# i=49 Answer: No.
# Result[49]: ChatGPT Prediction = N Answer Given = N
# i=50 Answer: Yes
# Result[50]: ChatGPT Prediction = Y Answer Given = Y
# i=51 Answer: No
# Result[51]: ChatGPT Prediction = N Answer Given = N
# i=52 Answer: No.
# Result[52]: ChatGPT Prediction = N Answer Given = N
# i=53 Answer: Yes
# Result[53]: ChatGPT Prediction = Y Answer Given = Y
# i=54 Answer: No
# Result[54]: ChatGPT Prediction = N Answer Given = N
# i=55 Answer: No.
# Result[55]: ChatGPT Prediction = N Answer Given = N
# i=56 Answer: No
# Result[56]: ChatGPT Prediction = N Answer Given = N/N/N/N/N/N/Y
# i=57 Answer: No.
# Result[57]: ChatGPT Prediction = N Answer Given = N
# i=58 Answer: No.
# Result[58]: ChatGPT Prediction = N Answer Given = N
# i=59 Answer: No.
# Result[59]: ChatGPT Prediction = N Answer Given = N
# i=60 Answer: No.
# Result[60]: ChatGPT Prediction = N Answer Given = Y
# i=61 Answer: No.
# Result[61]: ChatGPT Prediction = N Answer Given = N
# i=62 Answer: No.
# Result[62]: ChatGPT Prediction = N Answer Given = N
# i=63 Answer: Yes
# Result[63]: ChatGPT Prediction = Y Answer Given = Y
# i=64 Answer: No.
# Result[64]: ChatGPT Prediction = N Answer Given = N
# i=65 Answer: No.
# Result[65]: ChatGPT Prediction = N Answer Given = N
# i=66 Answer: Yes
# Result[66]: ChatGPT Prediction = Y Answer Given = Y
# i=67 Answer: No.
# Result[67]: ChatGPT Prediction = N Answer Given = N
# i=68 Answer: No.
# Result[68]: ChatGPT Prediction = N Answer Given = N
# i=69 Answer: No.
# Result[69]: ChatGPT Prediction = N Answer Given = Y
# i=70 Answer: Yes
# Result[70]: ChatGPT Prediction = Y Answer Given = Y
# i=71 Answer: No
# Result[71]: ChatGPT Prediction = N Answer Given = Y
# i=72 Answer: No
# Result[72]: ChatGPT Prediction = N Answer Given = N
# i=73 Answer: Yes
# Result[73]: ChatGPT Prediction = Y Answer Given = N/Y/N/N/Y
# i=74 Answer: No.
# Result[74]: ChatGPT Prediction = N Answer Given = N
# i=75 Answer: No.
# Result[75]: ChatGPT Prediction = N Answer Given = Y/N/N
# i=76 Answer: No
# Result[76]: ChatGPT Prediction = N Answer Given = N
# i=77 Answer: No.
# Result[77]: ChatGPT Prediction = N Answer Given = N
# i=78 Answer: No.
# Result[78]: ChatGPT Prediction = N Answer Given = N
# i=79 Answer: No.
# Result[79]: ChatGPT Prediction = N Answer Given = Y
# i=80 Answer: No.
# Result[80]: ChatGPT Prediction = N Answer Given = N
# i=81 Answer: Yes
# Result[81]: ChatGPT Prediction = Y Answer Given = Y
# i=82 Answer: No.
# Result[82]: ChatGPT Prediction = N Answer Given = N
# i=83 Answer: No.
# Result[83]: ChatGPT Prediction = N Answer Given = N
# i=84 Answer: No.
# Result[84]: ChatGPT Prediction = N Answer Given = N
# i=85 Answer: No.
# Result[85]: ChatGPT Prediction = N Answer Given = N
# i=86 Answer: No
# Result[86]: ChatGPT Prediction = N Answer Given = N
# i=87 Answer: No.
# Result[87]: ChatGPT Prediction = N Answer Given = N
# i=88 Answer: No.
# Result[88]: ChatGPT Prediction = N Answer Given = Y
# i=89 Answer: Yes
# Result[89]: ChatGPT Prediction = Y Answer Given = Y
# i=90 Answer: No.
# Result[90]: ChatGPT Prediction = N Answer Given = N
# i=91 Answer: No.
# Result[91]: ChatGPT Prediction = N Answer Given = N
# i=92 Answer: No
# Result[92]: ChatGPT Prediction = N Answer Given = N
# i=93 Answer: No.
# Result[93]: ChatGPT Prediction = N Answer Given = N
# i=94 Answer: Yes
# Result[94]: ChatGPT Prediction = Y Answer Given = Y
# i=95 Answer: No.
# Result[95]: ChatGPT Prediction = N Answer Given = N
# i=96 Answer: Yes
# Result[96]: ChatGPT Prediction = Y Answer Given = Y
# i=97 Answer: No.
# Result[97]: ChatGPT Prediction = N Answer Given = N
# i=98 Answer: No.
# Result[98]: ChatGPT Prediction = N Answer Given = N
# i=99 Answer: No.
# Result[99]: ChatGPT Prediction = N Answer Given = N
# i=100 Answer: No
# Result[100]: ChatGPT Prediction = N Answer Given = N
# i=101 Answer: No
# Result[101]: ChatGPT Prediction = N Answer Given = N
# i=102 Answer: Yes
# Result[102]: ChatGPT Prediction = Y Answer Given = N
# i=103 Answer: No
# Result[103]: ChatGPT Prediction = N Answer Given = N
# i=104 Answer: No.
# Result[104]: ChatGPT Prediction = N Answer Given = N
# i=105 Answer: No.
# Result[105]: ChatGPT Prediction = N Answer Given = N
# i=106 Answer: No.
# Result[106]: ChatGPT Prediction = N Answer Given = N
# i=107 Answer: No
# Result[107]: ChatGPT Prediction = N Answer Given = N
# i=108 Answer: No
# Result[108]: ChatGPT Prediction = N Answer Given = N
# i=109 Answer: Yes
# Result[109]: ChatGPT Prediction = Y Answer Given = Y
# i=110 Answer: No.
# Result[110]: ChatGPT Prediction = N Answer Given = N
# i=111 Answer: Yes
# Result[111]: ChatGPT Prediction = Y Answer Given = Y
# i=112 Answer: Yes
# Result[112]: ChatGPT Prediction = Y Answer Given = Y
# i=113 Answer: No
# Result[113]: ChatGPT Prediction = N Answer Given = nan
# i=114 Answer: No.
# Result[114]: ChatGPT Prediction = N Answer Given = N
# i=115 Answer: No
# Result[115]: ChatGPT Prediction = N Answer Given = N
# i=116 Answer: No
# Result[116]: ChatGPT Prediction = N Answer Given = N
# i=117 Answer: No
# Result[117]: ChatGPT Prediction = N Answer Given = N
# i=118 Answer: No.
# Result[118]: ChatGPT Prediction = N Answer Given = N
# i=119 Answer: No
# Result[119]: ChatGPT Prediction = N Answer Given = N
# i=120 Answer: No
# Result[120]: ChatGPT Prediction = N Answer Given = N
# i=121 Answer: No.
# Result[121]: ChatGPT Prediction = N Answer Given = N
# i=122 Answer: No.
# Result[122]: ChatGPT Prediction = N Answer Given = N
# i=123 Answer: No
# Result[123]: ChatGPT Prediction = N Answer Given = Y
# i=124 Answer: No
# Result[124]: ChatGPT Prediction = N Answer Given = N
# i=125 Answer: No.
# Result[125]: ChatGPT Prediction = N Answer Given = N
# i=126 Answer: No
# Result[126]: ChatGPT Prediction = N Answer Given = N
# i=127 Answer: No.
# Result[127]: ChatGPT Prediction = N Answer Given = N
# i=128 Answer: No.
# Result[128]: ChatGPT Prediction = N Answer Given = N
# i=129 Answer: No
# Result[129]: ChatGPT Prediction = N Answer Given = N
# i=130 Answer: No.
# Result[130]: ChatGPT Prediction = N Answer Given = N
# i=131 Answer: No
# Result[131]: ChatGPT Prediction = N Answer Given = N
# i=132 Answer: No
# Result[132]: ChatGPT Prediction = N Answer Given = N
# i=133 Answer: No
# Result[133]: ChatGPT Prediction = N Answer Given = N
# i=134 Answer: No
# Result[134]: ChatGPT Prediction = N Answer Given = N
# i=135 Answer: No
# Result[135]: ChatGPT Prediction = N Answer Given = Y
# i=136 Answer: Yes
# Result[136]: ChatGPT Prediction = Y Answer Given = Y
# i=137 Answer: No
# Result[137]: ChatGPT Prediction = N Answer Given = N
# i=138 Answer: No
# Result[138]: ChatGPT Prediction = N Answer Given = N
# i=139 Answer: No
# Result[139]: ChatGPT Prediction = N Answer Given = N
# i=140 Answer: No
# Result[140]: ChatGPT Prediction = N Answer Given = Y
# i=141 Answer: No
# Result[141]: ChatGPT Prediction = N Answer Given = N
# i=142 Answer: No.
# Result[142]: ChatGPT Prediction = N Answer Given = N
# i=143 Answer: No
# Result[143]: ChatGPT Prediction = N Answer Given = N
# i=144 Answer: Yes
# Result[144]: ChatGPT Prediction = Y Answer Given = Y
# i=145 Answer: Yes
# Result[145]: ChatGPT Prediction = Y Answer Given = Y
# i=146 Answer: No.
# Result[146]: ChatGPT Prediction = N Answer Given = N
# i=147 Answer: No.
# Result[147]: ChatGPT Prediction = N Answer Given = N
# i=148 Answer: No
# Result[148]: ChatGPT Prediction = N Answer Given = N
# i=149 Answer: No
# Result[149]: ChatGPT Prediction = N Answer Given = N
# i=150 Answer: No.
# Result[150]: ChatGPT Prediction = N Answer Given = N
# i=151 Answer: No.
# Result[151]: ChatGPT Prediction = N Answer Given = Y
# i=152 Answer: Yes
# Result[152]: ChatGPT Prediction = Y Answer Given = Y
# i=153 Answer: No
# Result[153]: ChatGPT Prediction = N Answer Given = N
# i=154 Answer: No.
# Result[154]: ChatGPT Prediction = N Answer Given = N
# i=155 Answer: Yes
# Result[155]: ChatGPT Prediction = Y Answer Given = Y
# i=156 Answer: No.
# Result[156]: ChatGPT Prediction = N Answer Given = N
# i=157 Answer: Yes
# Result[157]: ChatGPT Prediction = Y Answer Given = Y/Y
# i=158 Answer: No.
# Result[158]: ChatGPT Prediction = N Answer Given = N/Y
# i=159 Answer: Yes
# Result[159]: ChatGPT Prediction = Y Answer Given = Y
# i=160 Answer: No.
# Result[160]: ChatGPT Prediction = N Answer Given = Y
# i=161 Answer: No
# Result[161]: ChatGPT Prediction = N Answer Given = N/Y
# i=162 Answer: No.
# Result[162]: ChatGPT Prediction = N Answer Given = N/Y
# i=163 Answer: No
# Result[163]: ChatGPT Prediction = N Answer Given = N
# i=164 Answer: No.
# Result[164]: ChatGPT Prediction = N Answer Given = N
# i=165 Answer: Yes
# Result[165]: ChatGPT Prediction = Y Answer Given = N
# i=166 Answer: No.
# Result[166]: ChatGPT Prediction = N Answer Given = N
# i=167 Answer: No
# Result[167]: ChatGPT Prediction = N Answer Given = N
# i=168 Answer: No.
# Result[168]: ChatGPT Prediction = N Answer Given = N
# i=169 Answer: No
# Result[169]: ChatGPT Prediction = N Answer Given = Y/N/N
# i=170 Answer: Yes
# Result[170]: ChatGPT Prediction = Y Answer Given = Y
# i=171 Answer: No
# Result[171]: ChatGPT Prediction = N Answer Given = N
# i=172 Answer: No.
# Result[172]: ChatGPT Prediction = N Answer Given = N
# i=173 Answer: No.
# Result[173]: ChatGPT Prediction = N Answer Given = N
# i=174 Answer: No.
# Result[174]: ChatGPT Prediction = N Answer Given = N
# i=175 Answer: No.
# Result[175]: ChatGPT Prediction = N Answer Given = N
# i=176 Answer: No
# Result[176]: ChatGPT Prediction = N Answer Given = N
# i=177 Answer: No
# Result[177]: ChatGPT Prediction = N Answer Given = N/Y
# i=178 Answer: Yes
# Result[178]: ChatGPT Prediction = Y Answer Given = Y
# i=179 Answer: No
# Result[179]: ChatGPT Prediction = N Answer Given = Y
# i=180 Answer: No.
# Result[180]: ChatGPT Prediction = N Answer Given = Y
# i=181 Answer: Yes
# Result[181]: ChatGPT Prediction = Y Answer Given = Y
# i=182 Answer: No
# Result[182]: ChatGPT Prediction = N Answer Given = N
# i=183 Answer: No.
# Result[183]: ChatGPT Prediction = N Answer Given = N
# i=184 Answer: No
# Result[184]: ChatGPT Prediction = N Answer Given = N
# i=185 Answer: No.
# Result[185]: ChatGPT Prediction = N Answer Given = N
# i=186 Answer: No
# Result[186]: ChatGPT Prediction = N Answer Given = N/Y
# i=187 Answer: No.
# Result[187]: ChatGPT Prediction = N Answer Given = N
# i=188 Answer: Yes
# Result[188]: ChatGPT Prediction = Y Answer Given = Y
# i=189 Answer: No.
# Result[189]: ChatGPT Prediction = N Answer Given = N/Y
# i=190 Answer: No.
# Result[190]: ChatGPT Prediction = N Answer Given = N
# i=191 Answer: Yes
# Result[191]: ChatGPT Prediction = Y Answer Given = Y
# i=192 Answer: No.
# Result[192]: ChatGPT Prediction = N Answer Given = N
# i=193 Answer: No.
# Result[193]: ChatGPT Prediction = N Answer Given = N
# i=194 Answer: No.
# Result[194]: ChatGPT Prediction = N Answer Given = N/N/Y/N
# i=195 Answer: No.
# Result[195]: ChatGPT Prediction = N Answer Given = N
# i=196 Answer: No
# Result[196]: ChatGPT Prediction = N Answer Given = N/Y
# i=197 Answer: No
# Result[197]: ChatGPT Prediction = N Answer Given = N
# i=198 Answer: No.
# Result[198]: ChatGPT Prediction = N Answer Given = N
# i=199 Answer: No
# Result[199]: ChatGPT Prediction = N Answer Given = N/Y
# i=200 Answer: No.
# Result[200]: ChatGPT Prediction = N Answer Given = N
# i=201 Answer: No.
# Result[201]: ChatGPT Prediction = N Answer Given = N
# i=202 Answer: No
# Result[202]: ChatGPT Prediction = N Answer Given = N
# i=203 Answer: No.
# Result[203]: ChatGPT Prediction = N Answer Given = N
# i=204 Answer: No
# Result[204]: ChatGPT Prediction = N Answer Given = N
# i=205 Answer: No
# Result[205]: ChatGPT Prediction = N Answer Given = N
# i=206 Answer: No.
# Result[206]: ChatGPT Prediction = N Answer Given = N
# i=207 Answer: No.
# Result[207]: ChatGPT Prediction = N Answer Given = N
# i=208 Answer: No.
# Result[208]: ChatGPT Prediction = N Answer Given = N
# i=209 Answer: No
# Result[209]: ChatGPT Prediction = N Answer Given = N
# i=210 Answer: Yes
# Result[210]: ChatGPT Prediction = Y Answer Given = Y
# i=211 Answer: No.
# Result[211]: ChatGPT Prediction = N Answer Given = N
# i=212 Answer: Yes
# Result[212]: ChatGPT Prediction = Y Answer Given = N
# i=213 Answer: No
# Result[213]: ChatGPT Prediction = N Answer Given = N
# i=214 Answer: Yes
# Result[214]: ChatGPT Prediction = Y Answer Given = Y
# i=215 Answer: Yes
# Result[215]: ChatGPT Prediction = Y Answer Given = Y
# i=216 Answer: No
# Result[216]: ChatGPT Prediction = N Answer Given = N
# i=217 Answer: Yes
# Result[217]: ChatGPT Prediction = Y Answer Given = Y
# i=218 Answer: Yes
# Result[218]: ChatGPT Prediction = Y Answer Given = Y
# i=219 Answer: No.
# Result[219]: ChatGPT Prediction = N Answer Given = N
# i=220 Answer: No.
# Result[220]: ChatGPT Prediction = N Answer Given = N
# i=221 Answer: No.
# Result[221]: ChatGPT Prediction = N Answer Given = N
# i=222 Answer: No.
# Result[222]: ChatGPT Prediction = N Answer Given = N
# i=223 Answer: No
# Result[223]: ChatGPT Prediction = N Answer Given = N
# i=224 Answer: No.
# Result[224]: ChatGPT Prediction = N Answer Given = N
# i=225 Answer: No
# Result[225]: ChatGPT Prediction = N Answer Given = N
# i=226 Answer: No.
# Result[226]: ChatGPT Prediction = N Answer Given = N/Y
# i=227 Answer: No.
# Result[227]: ChatGPT Prediction = N Answer Given = N
# i=228 Answer: No
# Result[228]: ChatGPT Prediction = N Answer Given = N
# i=229 Answer: No
# Result[229]: ChatGPT Prediction = N Answer Given = N
# i=230 Answer: No.
# Result[230]: ChatGPT Prediction = N Answer Given = N
# i=231 Answer: No
# Result[231]: ChatGPT Prediction = N Answer Given = N
# i=232 Answer: No
# Result[232]: ChatGPT Prediction = N Answer Given = N
# i=233 Answer: No.
# Result[233]: ChatGPT Prediction = N Answer Given = N
# i=234 Answer: No.
# Result[234]: ChatGPT Prediction = N Answer Given = N
# i=235 Answer: Yes
# Result[235]: ChatGPT Prediction = Y Answer Given = Y
# i=236 Answer: No.
# Result[236]: ChatGPT Prediction = N Answer Given = N
# i=237 Answer: Yes
# Result[237]: ChatGPT Prediction = Y Answer Given = Y
# i=238 Answer: No
# Result[238]: ChatGPT Prediction = N Answer Given = M
# i=239 Answer: No.
# Result[239]: ChatGPT Prediction = N Answer Given = Y/N
# i=240 Answer: No
# Result[240]: ChatGPT Prediction = N Answer Given = Y
# i=241 Answer: No.
# Result[241]: ChatGPT Prediction = N Answer Given = N
# i=242 Answer: No
# Result[242]: ChatGPT Prediction = N Answer Given = N
# i=243 Answer: No.
# Result[243]: ChatGPT Prediction = N Answer Given = N
# i=244 Answer: No
# Result[244]: ChatGPT Prediction = N Answer Given = Y/N
# i=245 Answer: No.
# Result[245]: ChatGPT Prediction = N Answer Given = Y
# i=246 Answer: No
# Result[246]: ChatGPT Prediction = N Answer Given = N
# i=247 Answer: No
# Result[247]: ChatGPT Prediction = N Answer Given = N
# i=248 Answer: Yes
# Result[248]: ChatGPT Prediction = Y Answer Given = Y
# i=249 Answer: No.
# Result[249]: ChatGPT Prediction = N Answer Given = N
# i=250 Answer: No.
# Result[250]: ChatGPT Prediction = N Answer Given = N
# i=251 Answer: No.
# Result[251]: ChatGPT Prediction = N Answer Given = N
# i=252 Answer: No
# Result[252]: ChatGPT Prediction = N Answer Given = N
# i=253 Answer: No.
# Result[253]: ChatGPT Prediction = N Answer Given = N
# i=254 Answer: Yes
# Result[254]: ChatGPT Prediction = Y Answer Given = Y
# i=255 Answer: No.
# Result[255]: ChatGPT Prediction = N Answer Given = N
# i=256 Answer: No.
# Result[256]: ChatGPT Prediction = N Answer Given = N
# i=257 Answer: No.
# Result[257]: ChatGPT Prediction = N Answer Given = N
# i=258 Answer: No
# Result[258]: ChatGPT Prediction = N Answer Given = N
# i=259 Answer: No.
# Result[259]: ChatGPT Prediction = N Answer Given = N
# i=260 Answer: No.
# Result[260]: ChatGPT Prediction = N Answer Given = N
# i=261 Answer: No.
# Result[261]: ChatGPT Prediction = N Answer Given = N
# i=262 Answer: No.
# Result[262]: ChatGPT Prediction = N Answer Given = N
# i=263 Answer: No.
# Result[263]: ChatGPT Prediction = N Answer Given = N
# i=264 Answer: No.
# Result[264]: ChatGPT Prediction = N Answer Given = N
# i=265 Answer: Yes
# Result[265]: ChatGPT Prediction = Y Answer Given = Y
# i=266 Answer: No
# Result[266]: ChatGPT Prediction = N Answer Given = N
# i=267 Answer: No.
# Result[267]: ChatGPT Prediction = N Answer Given = N
# i=268 Answer: No.
# Result[268]: ChatGPT Prediction = N Answer Given = N
# i=269 Answer: No
# Result[269]: ChatGPT Prediction = N Answer Given = N
# i=270 Answer: No.
# Result[270]: ChatGPT Prediction = N Answer Given = Y
# i=271 Answer: No
# Result[271]: ChatGPT Prediction = N Answer Given = N
# i=272 Answer: No
# Result[272]: ChatGPT Prediction = N Answer Given = N
# i=273 Answer: Yes
# Result[273]: ChatGPT Prediction = Y Answer Given = Y
# i=274 Answer: No
# Result[274]: ChatGPT Prediction = N Answer Given = N
# i=275 Answer: No.
# Result[275]: ChatGPT Prediction = N Answer Given = N
# i=276 Answer: Yes
# Result[276]: ChatGPT Prediction = Y Answer Given = Y/Y
# i=277 Answer: No.
# Result[277]: ChatGPT Prediction = N Answer Given = N
# i=278 Answer: No.
# Result[278]: ChatGPT Prediction = N Answer Given = N/Y
# i=279 Answer: No
# Result[279]: ChatGPT Prediction = N Answer Given = N/Y
# i=280 Answer: No.
# Result[280]: ChatGPT Prediction = N Answer Given = N
# i=281 Answer: No.
# Result[281]: ChatGPT Prediction = N Answer Given = N
# i=282 Answer: No
# Result[282]: ChatGPT Prediction = N Answer Given = Y
# i=283 Answer: No
# Result[283]: ChatGPT Prediction = N Answer Given = N
# i=284 Answer: No.
# Result[284]: ChatGPT Prediction = N Answer Given = Y/N
# i=285 Answer: No.
# Result[285]: ChatGPT Prediction = N Answer Given = N
# i=286 Answer: No.
# Result[286]: ChatGPT Prediction = N Answer Given = N
# i=287 Answer: No.
# Result[287]: ChatGPT Prediction = N Answer Given = N
# i=288 Answer: Yes
# Result[288]: ChatGPT Prediction = Y Answer Given = Y/Y
# i=289 Answer: No.
# Result[289]: ChatGPT Prediction = N Answer Given = N
# i=290 Answer: No.
# Result[290]: ChatGPT Prediction = N Answer Given = N
# i=291 Answer: No
# Result[291]: ChatGPT Prediction = N Answer Given = N
# i=292 Answer: Yes
# Result[292]: ChatGPT Prediction = Y Answer Given = Y/Y/N
# i=293 Answer: No.
# Result[293]: ChatGPT Prediction = N Answer Given = Y/Y

# %%
total_size = 0
correct_predictions = 0
no_response_given = 0
no_alphabetical_result_returned = 0
bad_cases_combined = 0
nrg_not_narr = 0
narr_not_nrg = 0
# nrg = no valid response given in (L) column
# narr = no alphabetical result returned from ChatGPT output

for i in range(0, min((sample_size), len(Cat))):
    if(output_final[i] == "error_2" and true_results_final[i] == "error_1"):
        bad_cases_combined += 1
        
    if(output_final[i] == "error_2"):
        no_alphabetical_result_returned += 1
        if(true_results_final[i] != "error_1"):
            narr_not_nrg += 1
            
    if(true_results_final[i] == "error_1"):
        no_response_given += 1
        if(output_final[i] != "error_2"):
            nrg_not_narr += 1
            
    if(output_final[i] == true_results_final[i]):
        correct_predictions += 1
        
    total_size += 1
    
accuracy = correct_predictions / total_size
print("# of Correct Predictions = " + str(correct_predictions))
print("Sample Size = " + str(total_size))
print("Accuracy = " + "{:.2f}%".format(accuracy * 100))

# Accuracy when removing cases where the Location is not given (best to look at)
no_response_given_accuracy = correct_predictions / (total_size - no_response_given)
print()
print("Number of Notes without a Given Location = " + str(no_response_given))
print("Accuracy = " +"{:.2f}%".format(no_response_given_accuracy * 100))

# Accuracy when removing cases where GPT didn't return a valid alphabetical answer (not the best to look at, could be slightly lower)
no_alphabetical_result_returned_accuracy = correct_predictions / (total_size - no_alphabetical_result_returned)
print()
print("Number of PE/A&P/A Notes without a valid GPT Given Location = " + str(no_alphabetical_result_returned))
print("Accuracy = " + "{:.2f}%".format(no_alphabetical_result_returned_accuracy * 100))

# Accuracy when removing all above bad cases (ok to look at, could be slightly lower)
bad_cases_total_accuracy = correct_predictions / (total_size - (narr_not_nrg + nrg_not_narr + bad_cases_combined))
print()
print("Number of Combined Notes without a Given Location = " + str(narr_not_nrg + nrg_not_narr + bad_cases_combined))
print("Accuracy = " + "{:.2f}%".format(bad_cases_total_accuracy * 100))
# Out:
# # of Correct Predictions = 237
# Sample Size = 294
# Accuracy = 80.61%
#
# Number of Notes without a Given Location = 0
# Accuracy = 80.61%
#
# Number of PE/A&P/A Notes without a valid GPT Given Location = 0
# Accuracy = 80.61%
#
# Number of Combined Notes without a Given Location = 0
# Accuracy = 80.61%
