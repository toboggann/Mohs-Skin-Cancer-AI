# %%
# "Aggressive Tumor Pathology Type (AT)" A 100%

# Nonaggressive Tumor Type: Superficial BCC, Nodular BCC, SCCIS, Well-Diff SCC
# Aggressive Tumor Type: All other BCC, All other SCC, AFX, Sebaceous Carcinoma, Sweat Gland Carcinoma, Merkel Cell, Other

# sBCC = superficial basal cell carcinoma, nBCC = nodular basal cell carcinoma, SCCIS = squamous cell carcinoma in situ
# Well-Diff SCC = well-differentiated squamous cell carcinoma, AFX = atypical fibroxanthoma

# Inform GPT of what qualifies as an AT and what doesn't in system message, then ask if there is a tumor that is an AT and pass in the Addendum notes

import os
import pandas as pd
import requests
import base64

#using azure
API_KEY = "2DWhd5NlWo6U8lpUBSWgyCuCL1bgNUAlQyv4sF2Oq6TsNxszq97NJQQJ99AKACHrzpqXJ3w3AAABACOGzNKu"
ENDPOINT = "https://rg-01-hippa-standalone-openai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-15-preview"

system_context = """
Your task is to determine if the following Mohs patient note contains any tumor types that qualify as Aggressive Tumor Types.
    
ONLY respond with 'Yes' or 'No'.
    
If tumor type is not explicitly named, use clinical context and wording in the note to make a best-guess classification.
    
Tumor Type Criteria:
- Nonaggressive Tumor Types: Superficial BCC, Nodular BCC, SCCIS, Well-Differentiated SCC
- Aggressive Tumor Types: All other BCC, All other SCC, AFX, Sebaceous Carcinoma, Sweat Gland Carcinoma, Merkel Cell

Only respond 'Yes' if the tumor type name or clinical description **explicitly and clearly** supports an aggressive classification.  
If the note uses vague, uncertain, or general terms — or if strong evidence of aggressiveness is missing — respond 'No'.  
When in doubt, favor 'No'.
"""

def call_gpt(query):
    headers = {
        "Content-Type": "application/json",
        "api-key": API_KEY,
    }
    
    # Payload for the request
    payload = {
    "messages" : [
            {"role": "system", "content": system_context},
            {"role": "user", "content": f"{query}"},
        ],
      "temperature": 0.3,
      "top_p": 0.95,
      "max_tokens": 30
    }
    
    
    # Send request
    try:
        response = requests.post(ENDPOINT, headers=headers, json=payload)
        response.raise_for_status()  # Will raise an HTTPError if the HTTP request returned an unsuccessful status code
    except requests.RequestException as e:
        print("Response Content:", response.text)
        raise SystemExit(f"Failed to make the request. Error: {e}")

    # Handle the response as needed (e.g., print or process)
    #print(response.json())
    return response.json()["choices"][0]["message"]["content"]

# %%
# Use full Excel sheet
import pandas as pd
Cat = pd.read_excel(r'../De-Identified Mohs Full Data.xlsx',sheet_name='Identified Data',header=0) # Only Size at Greatest Dimension column
Cat.head()
# Out:
#    Randomized Study Number  \
# 0                       36
# 1                      240
# 2                       32
# 3                      111
# 4                      197
#
#   Size at Greatest Dimension (S) ***Be  sure this is from the note and not the Mohs episode!  \
# 0                                                0.8
# 1                                                0.6
# 2                                                0.3
# 3                                                6.5
# 4                                                3.5
#
#   Recurrent Tumor (R)  \
# 0                   Y
# 1                   Y
# 2                   N
# 3                   N
# 4                   N
#
#   Location - Nose, Eyelid, Nail, Lip, Genitalia, or Acral (L)  \
# 0                                                  N
# 1                                                  Y
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Aggressive Tumor Pathology Type (AT) DFSP (D)  \
# 0                                    N        N
# 1                                    N        N
# 2                                    N        N
# 3                                    N        N
# 4                                    N        N
#
#   Coordinated repair with ENT/oculoplastics (C) Additional C&F  \
# 0                                             N              N
# 1                                             N              N
# 2                                             N              N
# 3                                             Y              N
# 4                                             N              Y
#
#   Additional Excision Multiple Sites  \
# 0                   N              N
# 1                   N              N
# 2                   N              N
# 3                   N              N
# 4                   Y              N
#
#    Business Days from Referral to First Appt  \
# 0                                       32.0
# 1                                       40.0
# 2                                        4.0
# 3                                       35.0
# 4                                       35.0
#
#                                   Physical Exam (PE)  \
# 0  Physical exam:\nGeneral: Well developed, well ...
# 1  Physical exam:\nGeneral: Well-dressed; well-no...
# 2  Physical exam:\nGeneral: Well-dressed; well-no...
# 3  Physical exam:\nVital signs: There were no vit...
# 4  Physical exam:\nGeneral: Well developed, well ...
#
#                              Assessment & Plan (A&P)  \
# 0  1. Chronic actinic damage in the setting of hi...
# 1  Procedure Orders\nBiopsy [486623795] ordered b...
# 2  Assessment & Plan: \n1. Brown papule on the le...
# 3  Assessment & Plan: \nBiopsy-proven basal cell ...
# 4  Assessment & Plan:  \n1. Chronic actinic sun d...
#
#                                         Addendum (A)
# 0  Addendum 7/11/2023\n \nThe pathology results w...
# 1  Addendum 7/11/2023\nThe pathology results were...
# 2  Addendum 7/13/2023\n \nThe pathology results w...
# 3                                                NaN
# 4  Addendum 7/5/2023\n \nThe pathology results we...

# %%
# Set options here
sample_size = len(Cat) # Change number to increase or decrease number of patients read from file
#sample_size = 10
multiple_columns = False # Set to True to use all input text columns, False to use only PE column
prioritize_column = 2   # Set to 0=PE 1=A&P 2=A to use prioritizeColumn(#), else uses callAll()
                        # If multiple_columns = False, the value of prioritize_column will be the column used
    
# Change to write GPT responses to a different txt file
txt_file = r'at_GPT_data/at_column_data_change_4.txt' # Prompt change 4 (Strict without being super strict)

# Array of indexes containing patients with notes that have problems (Some may be ok, these are from size so a location could exist but not size)
skip_patients_array = [7,8,22,23,32,34,38,39,49,50,52,55,62,66,73,80,88,89,101,102,107,110,121,123,131,133,135,
                       136,137,140,150,155,157,164,170,184,187,193,200,206,210,214,227,228,229,234,252,261,265,279,287,292,293]
skip_patients = False # Set to True to skip bad patient notes, False to keep them in

# %%
# Takes the text in the PE, A&P, and A columns and asks ChatGPT to return "Yes" or "No" to the question
# May use only A column
import re

# Get column name to save GPT column responses to txt file
def getColumnName(column_num):
    column_name = ""
    if column_num == 0: column_name = "PE"
    elif column_num == 1: column_name = "A&P"
    elif column_num == 2: column_name = "A"
    return column_name

# Regex to get only yes/no
def cleanResponse(tmp_ans):
    check_ans = re.split(r'\s+|-', tmp_ans)  # Split by spaces or hyphens
    check_ans = [re.sub(r'[^a-zA-Z]', '', j).lower() for j in check_ans]  # Remove non-alphabetic characters, convert to lowercase
    return [j for j in check_ans if j in ['yes', 'no']] # Keep only "yes" or "no" 


# Call all 3 columns at once
def callAll(prompts):
    tmp_ans = [""] * 3
    check_ans = [""] * 3
    for i in range(3):
        tmp_ans[i] = call_gpt(prompts[i]) # Call GPT with prompt and save answer to array
        print(f"tmp_ans[{i}] = {str(tmp_ans[i])}")
        check_ans[i] = cleanResponse(tmp_ans[i])
        print(f"check_ans[{i}] = {str(check_ans[i])}")
        
        column_name = getColumnName(i)
        log_file.write(f"{column_name} Unfiltered: {tmp_ans[i]}\n")
        log_file.write(f"{column_name} Filtered: {check_ans[i]}\n")
    return tmp_ans, check_ans

# Call GPT only for a single column to save time later
def prioritizeColumn(prompts, column):
    tmp_ans = [""] * 3
    check_ans = [""] * 3
    tmp_ans[column] = call_gpt(prompts[column])
    check_ans[column] = cleanResponse(tmp_ans[column])  
    return tmp_ans, check_ans

# Check if 2 arrays are the same output, if so return one of them if it is not empty
def majorityVoteCheck(tmp_ans, check_ans):
    if check_ans[0] == check_ans[1] or check_ans[0] == check_ans[2]:
        if check_ans[0]: return tmp_ans[0]
        elif check_ans[1]: return tmp_ans[1]
        elif check_ans[2]: return tmp_ans[2]
    elif check_ans[1] == check_ans[2]:
        if check_ans[1]: return tmp_ans[1]
        elif check_ans[2]: return tmp_ans[2]
    else:
        return tmp_ans[1]
            
# Only call other 2 columns to check for false positives (0=PE 1=A&P 2=A)
def prioritizeA(prompts, tmp_ans, check_ans):
    if "yes" in check_ans[2]:
        for i in [0, 1]:
            tmp_ans[i] = call_gpt(prompts[i])
            print(f"tmp_ans[{i}] = {tmp_ans[i]}")
            check_ans[i] = cleanResponse(tmp_ans[i])
            print(f"check_ans[{i}] = {check_ans[i]}")
            
        if "yes" in check_ans[0] or "yes" in check_ans[1]:
            return "yes"
        else: return "no"  # A said Yes, but others disagreed, possible false positive
    else: return "no"
        
    
# Always split into 3 GPT calls, one for each column
def inputSplit(input_columns, que, index, prioritize_column):
    while len(input_columns) < 3: # Some text columns may be empty so add a blank entry
        input_columns.append("")
        
    input_string = " ".join(map(str, input_columns)) # Apply str() to each index of input_columns then join with a space
    prompt = f"{que} \n\n {input_string}" # Create base prompt (question + input_columns)
    log_file.write(f"Index: {index}\n") # Write index to file
    
    if(len(input_string) > 0):
        prompts = [f"{que} \n\n {col}" for col in input_columns] # Recreate prompt with question + 1 column
        
        if prioritize_column in [0, 1, 2]: # PE, A&P, A
            tmp_ans, check_ans = prioritizeColumn(prompts, prioritize_column)
            return prioritizeA(prompts, tmp_ans, check_ans)
        else:
            tmp_ans, check_ans = callAll(prompts)
            return majorityVoteCheck(tmp_ans, check_ans)

        # Count num of "yes" and "no"
        yes_count = [0] * len(input_columns)
        no_count = [0] * len(input_columns)
        
        for i in range(len(check_ans)):
            yes_count[i] = check_ans[i].count('yes')
            no_count[i] = check_ans[i].count('no')
            
        print(f"Yes counts: {yes_count}")
        print(f"No counts: {no_count}")
        
        # If no matches, return string that has the most "yes" or "no"
        if any(count > 0 for count in yes_count) or any(count > 0 for count in no_count): # Check count strings for any occurences or "yes" or "no"
            max_yes_no = [0] * len(input_columns)
            max_answer = 0
            max_i = -1
            
            # Check if string has more "yes" or "no"
            for i in range(len(input_columns)):
                max_yes_no[i] = max(yes_count[i], no_count[i])
                
            # Look for highest overall "yes" or "no" then return that string
            for i in range(len(input_columns)):
                if max_answer < max_yes_no[i]:
                    max_answer = max_yes_no[i]
                    max_i = i
            return tmp_ans[max_i]
        
        # All non "yes" or "no" answers, return empty string
        return ""
    else:
        # Somehow input_string is empty
        return "input_string empty"
    

true_results = [0 for i in range(sample_size)]
true_results_final = [0 for i in range(sample_size)]

output = [0 for i in range(sample_size)]
output_final = [0 for i in range(sample_size)]

with open(txt_file, "a") as log_file: # Open file to write column answers to for vote testing
    for i in range(0, min(sample_size, len(Cat))):
        # If skip_patients is True and current index is in skip_patients_array, move to next index
        if skip_patients and i in skip_patients_array:
            continue

        true_results[i] = Cat.at[i, 'Aggressive Tumor Pathology Type (AT)']
        que = 'Question: Does the following patient note contain an Aggressive Tumor Type?'
        ans = ""

        if multiple_columns:
            input_columns = Cat.loc[i, ['Physical Exam (PE)', 'Assessment & Plan (A&P)', 'Addendum (A)']]
            ans = inputSplit(input_columns, que, i, prioritize_column) # Result from GPT call
        elif not multiple_columns:
            column_names = ['Physical Exam (PE)', 'Assessment & Plan (A&P)', 'Addendum (A)']
            input_columns = Cat.at[i, column_names[prioritize_column]]
            prompt = f"{que} \n\n {input_columns}"
            
            ans = call_gpt(prompt)
            print(f"tmp_ans[{i}] = {ans}") # Change i to prioritize_column
            ans_clean = cleanResponse(ans)
            print(f"check_ans[{i}] = {ans_clean}") # Change i to prioritize_column
            
            column_name = getColumnName(prioritize_column)
            log_file.write(f"Index: {i}\n") # Write index to file
            log_file.write(f"{column_name} Unfiltered: {ans}\n")
            log_file.write(f"{column_name} Filtered: {ans_clean}\n")

        print(f"Result[{i}] = {ans}")
        output[i] = ans
# Out:
# tmp_ans[0] = No
# check_ans[0] = ['no']
# Result[0] = No
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# Result[1] = Yes
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[2] = No
# tmp_ans[3] = No
# check_ans[3] = ['no']
# Result[3] = No
# tmp_ans[4] = No
# check_ans[4] = ['no']
# Result[4] = No
# tmp_ans[5] = No
# check_ans[5] = ['no']
# Result[5] = No
# tmp_ans[6] = No
# check_ans[6] = ['no']
# Result[6] = No
# tmp_ans[7] = No
# check_ans[7] = ['no']
# Result[7] = No
# tmp_ans[8] = Yes
# check_ans[8] = ['yes']
# Result[8] = Yes
# tmp_ans[9] = No
# check_ans[9] = ['no']
# Result[9] = No
# tmp_ans[10] = Yes
# check_ans[10] = ['yes']
# Result[10] = Yes
# tmp_ans[11] = No
# check_ans[11] = ['no']
# Result[11] = No
# tmp_ans[12] = No
# check_ans[12] = ['no']
# Result[12] = No
# tmp_ans[13] = No
# check_ans[13] = ['no']
# Result[13] = No
# tmp_ans[14] = No
# check_ans[14] = ['no']
# Result[14] = No
# tmp_ans[15] = Yes
# check_ans[15] = ['yes']
# Result[15] = Yes
# tmp_ans[16] = No
# check_ans[16] = ['no']
# Result[16] = No
# tmp_ans[17] = No
# check_ans[17] = ['no']
# Result[17] = No
# tmp_ans[18] = No
# check_ans[18] = ['no']
# Result[18] = No
# tmp_ans[19] = Yes
# check_ans[19] = ['yes']
# Result[19] = Yes
# tmp_ans[20] = No
# check_ans[20] = ['no']
# Result[20] = No
# tmp_ans[21] = No
# check_ans[21] = ['no']
# Result[21] = No
# tmp_ans[22] = No
# check_ans[22] = ['no']
# Result[22] = No
# tmp_ans[23] = No
# check_ans[23] = ['no']
# Result[23] = No
# tmp_ans[24] = No
# check_ans[24] = ['no']
# Result[24] = No
# tmp_ans[25] = No
# check_ans[25] = ['no']
# Result[25] = No
# tmp_ans[26] = No
# check_ans[26] = ['no']
# Result[26] = No
# tmp_ans[27] = No
# check_ans[27] = ['no']
# Result[27] = No
# tmp_ans[28] = Yes
# check_ans[28] = ['yes']
# Result[28] = Yes
# tmp_ans[29] = No
# check_ans[29] = ['no']
# Result[29] = No
# tmp_ans[30] = No
# check_ans[30] = ['no']
# Result[30] = No
# tmp_ans[31] = No
# check_ans[31] = ['no']
# Result[31] = No
# tmp_ans[32] = No
# check_ans[32] = ['no']
# Result[32] = No
# tmp_ans[33] = Yes
# check_ans[33] = ['yes']
# Result[33] = Yes
# tmp_ans[34] = No
# check_ans[34] = ['no']
# Result[34] = No
# tmp_ans[35] = No
# check_ans[35] = ['no']
# Result[35] = No
# tmp_ans[36] = Yes
# check_ans[36] = ['yes']
# Result[36] = Yes
# tmp_ans[37] = Yes
# check_ans[37] = ['yes']
# Result[37] = Yes
# tmp_ans[38] = No
# check_ans[38] = ['no']
# Result[38] = No
# tmp_ans[39] = No
# check_ans[39] = ['no']
# Result[39] = No
# tmp_ans[40] = Yes
# check_ans[40] = ['yes']
# Result[40] = Yes
# tmp_ans[41] = No
# check_ans[41] = ['no']
# Result[41] = No
# tmp_ans[42] = No
# check_ans[42] = ['no']
# Result[42] = No
# tmp_ans[43] = Yes
# check_ans[43] = ['yes']
# Result[43] = Yes
# tmp_ans[44] = No
# check_ans[44] = ['no']
# Result[44] = No
# tmp_ans[45] = No
# check_ans[45] = ['no']
# Result[45] = No
# tmp_ans[46] = No.
# check_ans[46] = ['no']
# Result[46] = No.
# tmp_ans[47] = No
# check_ans[47] = ['no']
# Result[47] = No
# tmp_ans[48] = No
# check_ans[48] = ['no']
# Result[48] = No
# tmp_ans[49] = Yes
# check_ans[49] = ['yes']
# Result[49] = Yes
# tmp_ans[50] = Yes
# check_ans[50] = ['yes']
# Result[50] = Yes
# tmp_ans[51] = No
# check_ans[51] = ['no']
# Result[51] = No
# tmp_ans[52] = Yes
# check_ans[52] = ['yes']
# Result[52] = Yes
# tmp_ans[53] = Yes
# check_ans[53] = ['yes']
# Result[53] = Yes
# tmp_ans[54] = No
# check_ans[54] = ['no']
# Result[54] = No
# tmp_ans[55] = Yes
# check_ans[55] = ['yes']
# Result[55] = Yes
# tmp_ans[56] = No
# check_ans[56] = ['no']
# Result[56] = No
# tmp_ans[57] = No
# check_ans[57] = ['no']
# Result[57] = No
# tmp_ans[58] = No
# check_ans[58] = ['no']
# Result[58] = No
# tmp_ans[59] = No
# check_ans[59] = ['no']
# Result[59] = No
# tmp_ans[60] = No
# check_ans[60] = ['no']
# Result[60] = No
# tmp_ans[61] = No
# check_ans[61] = ['no']
# Result[61] = No
# tmp_ans[62] = Yes
# check_ans[62] = ['yes']
# Result[62] = Yes
# tmp_ans[63] = No
# check_ans[63] = ['no']
# Result[63] = No
# tmp_ans[64] = No
# check_ans[64] = ['no']
# Result[64] = No
# tmp_ans[65] = No
# check_ans[65] = ['no']
# Result[65] = No
# tmp_ans[66] = No
# check_ans[66] = ['no']
# Result[66] = No
# tmp_ans[67] = Yes
# check_ans[67] = ['yes']
# Result[67] = Yes
# tmp_ans[68] = No
# check_ans[68] = ['no']
# Result[68] = No
# tmp_ans[69] = No
# check_ans[69] = ['no']
# Result[69] = No
# tmp_ans[70] = Yes
# check_ans[70] = ['yes']
# Result[70] = Yes
# tmp_ans[71] = No
# check_ans[71] = ['no']
# Result[71] = No
# tmp_ans[72] = No
# check_ans[72] = ['no']
# Result[72] = No
# tmp_ans[73] = No
# check_ans[73] = ['no']
# Result[73] = No
# tmp_ans[74] = No
# check_ans[74] = ['no']
# Result[74] = No
# tmp_ans[75] = No
# check_ans[75] = ['no']
# Result[75] = No
# tmp_ans[76] = No
# check_ans[76] = ['no']
# Result[76] = No
# tmp_ans[77] = No
# check_ans[77] = ['no']
# Result[77] = No
# tmp_ans[78] = No
# check_ans[78] = ['no']
# Result[78] = No
# tmp_ans[79] = No
# check_ans[79] = ['no']
# Result[79] = No
# tmp_ans[80] = Yes
# check_ans[80] = ['yes']
# Result[80] = Yes
# tmp_ans[81] = No
# check_ans[81] = ['no']
# Result[81] = No
# tmp_ans[82] = No
# check_ans[82] = ['no']
# Result[82] = No
# tmp_ans[83] = No
# check_ans[83] = ['no']
# Result[83] = No
# tmp_ans[84] = Yes
# check_ans[84] = ['yes']
# Result[84] = Yes
# tmp_ans[85] = No
# check_ans[85] = ['no']
# Result[85] = No
# tmp_ans[86] = Yes
# check_ans[86] = ['yes']
# Result[86] = Yes
# tmp_ans[87] = Yes
# check_ans[87] = ['yes']
# Result[87] = Yes
# tmp_ans[88] = Yes
# check_ans[88] = ['yes']
# Result[88] = Yes
# tmp_ans[89] = Yes
# check_ans[89] = ['yes']
# Result[89] = Yes
# tmp_ans[90] = No
# check_ans[90] = ['no']
# Result[90] = No
# tmp_ans[91] = No
# check_ans[91] = ['no']
# Result[91] = No
# tmp_ans[92] = No
# check_ans[92] = ['no']
# Result[92] = No
# tmp_ans[93] = No
# check_ans[93] = ['no']
# Result[93] = No
# tmp_ans[94] = No
# check_ans[94] = ['no']
# Result[94] = No
# tmp_ans[95] = No
# check_ans[95] = ['no']
# Result[95] = No
# tmp_ans[96] = No
# check_ans[96] = ['no']
# Result[96] = No
# tmp_ans[97] = No
# check_ans[97] = ['no']
# Result[97] = No
# tmp_ans[98] = No
# check_ans[98] = ['no']
# Result[98] = No
# tmp_ans[99] = Yes
# check_ans[99] = ['yes']
# Result[99] = Yes
# tmp_ans[100] = No
# check_ans[100] = ['no']
# Result[100] = No
# tmp_ans[101] = No
# check_ans[101] = ['no']
# Result[101] = No
# tmp_ans[102] = No
# check_ans[102] = ['no']
# Result[102] = No
# tmp_ans[103] = No
# check_ans[103] = ['no']
# Result[103] = No
# tmp_ans[104] = No.
# check_ans[104] = ['no']
# Result[104] = No.
# tmp_ans[105] = No
# check_ans[105] = ['no']
# Result[105] = No
# tmp_ans[106] = Yes
# check_ans[106] = ['yes']
# Result[106] = Yes
# tmp_ans[107] = No
# check_ans[107] = ['no']
# Result[107] = No
# tmp_ans[108] = Yes
# check_ans[108] = ['yes']
# Result[108] = Yes
# tmp_ans[109] = Yes
# check_ans[109] = ['yes']
# Result[109] = Yes
# tmp_ans[110] = No
# check_ans[110] = ['no']
# Result[110] = No
# tmp_ans[111] = Yes
# check_ans[111] = ['yes']
# Result[111] = Yes
# tmp_ans[112] = No
# check_ans[112] = ['no']
# Result[112] = No
# tmp_ans[113] = No
# check_ans[113] = ['no']
# Result[113] = No
# tmp_ans[114] = No
# check_ans[114] = ['no']
# Result[114] = No
# tmp_ans[115] = Yes
# check_ans[115] = ['yes']
# Result[115] = Yes
# tmp_ans[116] = No
# check_ans[116] = ['no']
# Result[116] = No
# tmp_ans[117] = No
# check_ans[117] = ['no']
# Result[117] = No
# tmp_ans[118] = No
# check_ans[118] = ['no']
# Result[118] = No
# tmp_ans[119] = No
# check_ans[119] = ['no']
# Result[119] = No
# tmp_ans[120] = No
# check_ans[120] = ['no']
# Result[120] = No
# tmp_ans[121] = No
# check_ans[121] = ['no']
# Result[121] = No
# tmp_ans[122] = No
# check_ans[122] = ['no']
# Result[122] = No
# tmp_ans[123] = No
# check_ans[123] = ['no']
# Result[123] = No
# tmp_ans[124] = No.
# check_ans[124] = ['no']
# Result[124] = No.
# tmp_ans[125] = No
# check_ans[125] = ['no']
# Result[125] = No
# tmp_ans[126] = No
# check_ans[126] = ['no']
# Result[126] = No
# tmp_ans[127] = No
# check_ans[127] = ['no']
# Result[127] = No
# tmp_ans[128] = No
# check_ans[128] = ['no']
# Result[128] = No
# tmp_ans[129] = Yes
# check_ans[129] = ['yes']
# Result[129] = Yes
# tmp_ans[130] = Yes
# check_ans[130] = ['yes']
# Result[130] = Yes
# tmp_ans[131] = Yes
# check_ans[131] = ['yes']
# Result[131] = Yes
# tmp_ans[132] = No
# check_ans[132] = ['no']
# Result[132] = No
# tmp_ans[133] = No
# check_ans[133] = ['no']
# Result[133] = No
# tmp_ans[134] = Yes
# check_ans[134] = ['yes']
# Result[134] = Yes
# tmp_ans[135] = No
# check_ans[135] = ['no']
# Result[135] = No
# tmp_ans[136] = Yes
# check_ans[136] = ['yes']
# Result[136] = Yes
# tmp_ans[137] = No
# check_ans[137] = ['no']
# Result[137] = No
# tmp_ans[138] = No
# check_ans[138] = ['no']
# Result[138] = No
# tmp_ans[139] = No
# check_ans[139] = ['no']
# Result[139] = No
# tmp_ans[140] = No
# check_ans[140] = ['no']
# Result[140] = No
# tmp_ans[141] = Yes
# check_ans[141] = ['yes']
# Result[141] = Yes
# tmp_ans[142] = Yes
# check_ans[142] = ['yes']
# Result[142] = Yes
# tmp_ans[143] = No
# check_ans[143] = ['no']
# Result[143] = No
# tmp_ans[144] = Yes
# check_ans[144] = ['yes']
# Result[144] = Yes
# tmp_ans[145] = No
# check_ans[145] = ['no']
# Result[145] = No
# tmp_ans[146] = No
# check_ans[146] = ['no']
# Result[146] = No
# tmp_ans[147] = No
# check_ans[147] = ['no']
# Result[147] = No
# tmp_ans[148] = No
# check_ans[148] = ['no']
# Result[148] = No
# tmp_ans[149] = No
# check_ans[149] = ['no']
# Result[149] = No
# tmp_ans[150] = No.
# check_ans[150] = ['no']
# Result[150] = No.
# tmp_ans[151] = No
# check_ans[151] = ['no']
# Result[151] = No
# tmp_ans[152] = No
# check_ans[152] = ['no']
# Result[152] = No
# tmp_ans[153] = No
# check_ans[153] = ['no']
# Result[153] = No
# tmp_ans[154] = No
# check_ans[154] = ['no']
# Result[154] = No
# tmp_ans[155] = No
# check_ans[155] = ['no']
# Result[155] = No
# tmp_ans[156] = Yes
# check_ans[156] = ['yes']
# Result[156] = Yes
# tmp_ans[157] = No
# check_ans[157] = ['no']
# Result[157] = No
# tmp_ans[158] = No.
# check_ans[158] = ['no']
# Result[158] = No.
# tmp_ans[159] = Yes
# check_ans[159] = ['yes']
# Result[159] = Yes
# tmp_ans[160] = No
# check_ans[160] = ['no']
# Result[160] = No
# tmp_ans[161] = Yes
# check_ans[161] = ['yes']
# Result[161] = Yes
# tmp_ans[162] = No
# check_ans[162] = ['no']
# Result[162] = No
# tmp_ans[163] = No
# check_ans[163] = ['no']
# Result[163] = No
# tmp_ans[164] = No
# check_ans[164] = ['no']
# Result[164] = No
# tmp_ans[165] = No
# check_ans[165] = ['no']
# Result[165] = No
# tmp_ans[166] = Yes
# check_ans[166] = ['yes']
# Result[166] = Yes
# tmp_ans[167] = Yes
# check_ans[167] = ['yes']
# Result[167] = Yes
# tmp_ans[168] = Yes
# check_ans[168] = ['yes']
# Result[168] = Yes
# tmp_ans[169] = No
# check_ans[169] = ['no']
# Result[169] = No
# tmp_ans[170] = No
# check_ans[170] = ['no']
# Result[170] = No
# tmp_ans[171] = No
# check_ans[171] = ['no']
# Result[171] = No
# tmp_ans[172] = No
# check_ans[172] = ['no']
# Result[172] = No
# tmp_ans[173] = No
# check_ans[173] = ['no']
# Result[173] = No
# tmp_ans[174] = Yes
# check_ans[174] = ['yes']
# Result[174] = Yes
# tmp_ans[175] = No
# check_ans[175] = ['no']
# Result[175] = No
# tmp_ans[176] = No
# check_ans[176] = ['no']
# Result[176] = No
# tmp_ans[177] = No
# check_ans[177] = ['no']
# Result[177] = No
# tmp_ans[178] = No
# check_ans[178] = ['no']
# Result[178] = No
# tmp_ans[179] = No
# check_ans[179] = ['no']
# Result[179] = No
# tmp_ans[180] = No
# check_ans[180] = ['no']
# Result[180] = No
# tmp_ans[181] = No
# check_ans[181] = ['no']
# Result[181] = No
# tmp_ans[182] = Yes
# check_ans[182] = ['yes']
# Result[182] = Yes
# tmp_ans[183] = No
# check_ans[183] = ['no']
# Result[183] = No
# tmp_ans[184] = No
# check_ans[184] = ['no']
# Result[184] = No
# tmp_ans[185] = No
# check_ans[185] = ['no']
# Result[185] = No
# tmp_ans[186] = Yes
# check_ans[186] = ['yes']
# Result[186] = Yes
# tmp_ans[187] = No
# check_ans[187] = ['no']
# Result[187] = No
# tmp_ans[188] = No
# check_ans[188] = ['no']
# Result[188] = No
# tmp_ans[189] = Yes
# check_ans[189] = ['yes']
# Result[189] = Yes
# tmp_ans[190] = No
# check_ans[190] = ['no']
# Result[190] = No
# tmp_ans[191] = Yes
# check_ans[191] = ['yes']
# Result[191] = Yes
# tmp_ans[192] = No
# check_ans[192] = ['no']
# Result[192] = No
# tmp_ans[193] = No
# check_ans[193] = ['no']
# Result[193] = No
# tmp_ans[194] = No
# check_ans[194] = ['no']
# Result[194] = No
# tmp_ans[195] = Yes
# check_ans[195] = ['yes']
# Result[195] = Yes
# tmp_ans[196] = No
# check_ans[196] = ['no']
# Result[196] = No
# tmp_ans[197] = Yes
# check_ans[197] = ['yes']
# Result[197] = Yes
# tmp_ans[198] = No
# check_ans[198] = ['no']
# Result[198] = No
# tmp_ans[199] = Yes
# check_ans[199] = ['yes']
# Result[199] = Yes
# tmp_ans[200] = No
# check_ans[200] = ['no']
# Result[200] = No
# tmp_ans[201] = Yes
# check_ans[201] = ['yes']
# Result[201] = Yes
# tmp_ans[202] = Yes
# check_ans[202] = ['yes']
# Result[202] = Yes
# tmp_ans[203] = Yes
# check_ans[203] = ['yes']
# Result[203] = Yes
# tmp_ans[204] = No
# check_ans[204] = ['no']
# Result[204] = No
# tmp_ans[205] = No
# check_ans[205] = ['no']
# Result[205] = No
# tmp_ans[206] = No
# check_ans[206] = ['no']
# Result[206] = No
# tmp_ans[207] = Yes
# check_ans[207] = ['yes']
# Result[207] = Yes
# tmp_ans[208] = No
# check_ans[208] = ['no']
# Result[208] = No
# tmp_ans[209] = Yes
# check_ans[209] = ['yes']
# Result[209] = Yes
# tmp_ans[210] = Yes
# check_ans[210] = ['yes']
# Result[210] = Yes
# tmp_ans[211] = No
# check_ans[211] = ['no']
# Result[211] = No
# tmp_ans[212] = No.
# check_ans[212] = ['no']
# Result[212] = No.
# tmp_ans[213] = No.
# check_ans[213] = ['no']
# Result[213] = No.
# tmp_ans[214] = No
# check_ans[214] = ['no']
# Result[214] = No
# tmp_ans[215] = Yes
# check_ans[215] = ['yes']
# Result[215] = Yes
# tmp_ans[216] = No
# check_ans[216] = ['no']
# Result[216] = No
# tmp_ans[217] = Yes
# check_ans[217] = ['yes']
# Result[217] = Yes
# tmp_ans[218] = No
# check_ans[218] = ['no']
# Result[218] = No
# tmp_ans[219] = No
# check_ans[219] = ['no']
# Result[219] = No
# tmp_ans[220] = No
# check_ans[220] = ['no']
# Result[220] = No
# tmp_ans[221] = Yes
# check_ans[221] = ['yes']
# Result[221] = Yes
# tmp_ans[222] = Yes
# check_ans[222] = ['yes']
# Result[222] = Yes
# tmp_ans[223] = No
# check_ans[223] = ['no']
# Result[223] = No
# tmp_ans[224] = No
# check_ans[224] = ['no']
# Result[224] = No
# tmp_ans[225] = Yes
# check_ans[225] = ['yes']
# Result[225] = Yes
# tmp_ans[226] = No
# check_ans[226] = ['no']
# Result[226] = No
# tmp_ans[227] = Yes
# check_ans[227] = ['yes']
# Result[227] = Yes
# tmp_ans[228] = No
# check_ans[228] = ['no']
# Result[228] = No
# tmp_ans[229] = No
# check_ans[229] = ['no']
# Result[229] = No
# tmp_ans[230] = No
# check_ans[230] = ['no']
# Result[230] = No
# tmp_ans[231] = Yes
# check_ans[231] = ['yes']
# Result[231] = Yes
# tmp_ans[232] = No
# check_ans[232] = ['no']
# Result[232] = No
# tmp_ans[233] = No
# check_ans[233] = ['no']
# Result[233] = No
# tmp_ans[234] = No
# check_ans[234] = ['no']
# Result[234] = No
# tmp_ans[235] = No
# check_ans[235] = ['no']
# Result[235] = No
# tmp_ans[236] = No
# check_ans[236] = ['no']
# Result[236] = No
# tmp_ans[237] = No
# check_ans[237] = ['no']
# Result[237] = No
# tmp_ans[238] = No
# check_ans[238] = ['no']
# Result[238] = No
# tmp_ans[239] = Yes
# check_ans[239] = ['yes']
# Result[239] = Yes
# tmp_ans[240] = No
# check_ans[240] = ['no']
# Result[240] = No
# tmp_ans[241] = No
# check_ans[241] = ['no']
# Result[241] = No
# tmp_ans[242] = No
# check_ans[242] = ['no']
# Result[242] = No
# tmp_ans[243] = Yes
# check_ans[243] = ['yes']
# Result[243] = Yes
# tmp_ans[244] = No
# check_ans[244] = ['no']
# Result[244] = No
# tmp_ans[245] = No
# check_ans[245] = ['no']
# Result[245] = No
# tmp_ans[246] = No
# check_ans[246] = ['no']
# Result[246] = No
# tmp_ans[247] = No
# check_ans[247] = ['no']
# Result[247] = No
# tmp_ans[248] = Yes
# check_ans[248] = ['yes']
# Result[248] = Yes
# tmp_ans[249] = No
# check_ans[249] = ['no']
# Result[249] = No
# tmp_ans[250] = No
# check_ans[250] = ['no']
# Result[250] = No
# tmp_ans[251] = Yes
# check_ans[251] = ['yes']
# Result[251] = Yes
# tmp_ans[252] = No
# check_ans[252] = ['no']
# Result[252] = No
# tmp_ans[253] = No
# check_ans[253] = ['no']
# Result[253] = No
# tmp_ans[254] = No
# check_ans[254] = ['no']
# Result[254] = No
# tmp_ans[255] = Yes
# check_ans[255] = ['yes']
# Result[255] = Yes
# tmp_ans[256] = Yes
# check_ans[256] = ['yes']
# Result[256] = Yes
# tmp_ans[257] = Yes
# check_ans[257] = ['yes']
# Result[257] = Yes
# tmp_ans[258] = No
# check_ans[258] = ['no']
# Result[258] = No
# tmp_ans[259] = No
# check_ans[259] = ['no']
# Result[259] = No
# tmp_ans[260] = No
# check_ans[260] = ['no']
# Result[260] = No
# tmp_ans[261] = No
# check_ans[261] = ['no']
# Result[261] = No
# tmp_ans[262] = Yes
# check_ans[262] = ['yes']
# Result[262] = Yes
# tmp_ans[263] = Yes
# check_ans[263] = ['yes']
# Result[263] = Yes
# tmp_ans[264] = Yes
# check_ans[264] = ['yes']
# Result[264] = Yes
# tmp_ans[265] = No
# check_ans[265] = ['no']
# Result[265] = No
# tmp_ans[266] = No
# check_ans[266] = ['no']
# Result[266] = No
# tmp_ans[267] = Yes
# check_ans[267] = ['yes']
# Result[267] = Yes
# tmp_ans[268] = No
# check_ans[268] = ['no']
# Result[268] = No
# tmp_ans[269] = Yes
# check_ans[269] = ['yes']
# Result[269] = Yes
# tmp_ans[270] = No
# check_ans[270] = ['no']
# Result[270] = No
# tmp_ans[271] = No
# check_ans[271] = ['no']
# Result[271] = No
# tmp_ans[272] = No
# check_ans[272] = ['no']
# Result[272] = No
# tmp_ans[273] = Yes
# check_ans[273] = ['yes']
# Result[273] = Yes
# tmp_ans[274] = No
# check_ans[274] = ['no']
# Result[274] = No
# tmp_ans[275] = Yes
# check_ans[275] = ['yes']
# Result[275] = Yes
# tmp_ans[276] = No
# check_ans[276] = ['no']
# Result[276] = No
# tmp_ans[277] = No
# check_ans[277] = ['no']
# Result[277] = No
# tmp_ans[278] = No
# check_ans[278] = ['no']
# Result[278] = No
# tmp_ans[279] = Yes
# check_ans[279] = ['yes']
# Result[279] = Yes
# tmp_ans[280] = Yes
# check_ans[280] = ['yes']
# Result[280] = Yes
# tmp_ans[281] = No
# check_ans[281] = ['no']
# Result[281] = No
# tmp_ans[282] = No
# check_ans[282] = ['no']
# Result[282] = No
# tmp_ans[283] = Yes
# check_ans[283] = ['yes']
# Result[283] = Yes
# tmp_ans[284] = Yes
# check_ans[284] = ['yes']
# Result[284] = Yes
# tmp_ans[285] = Yes
# check_ans[285] = ['yes']
# Result[285] = Yes
# tmp_ans[286] = No
# check_ans[286] = ['no']
# Result[286] = No
# tmp_ans[287] = No
# check_ans[287] = ['no']
# Result[287] = No
# tmp_ans[288] = Yes
# check_ans[288] = ['yes']
# Result[288] = Yes
# tmp_ans[289] = No
# check_ans[289] = ['no']
# Result[289] = No
# tmp_ans[290] = Yes
# check_ans[290] = ['yes']
# Result[290] = Yes
# tmp_ans[291] = No
# check_ans[291] = ['no']
# Result[291] = No
# tmp_ans[292] = No
# check_ans[292] = ['no']
# Result[292] = No
# tmp_ans[293] = No
# check_ans[293] = ['no']
# Result[293] = No

# %%
# Go through every GPT response and turn it into "Y" or "N" to compare
for i in range(0, min(sample_size, len(Cat))):
    if skip_patients and i in skip_patients_array:
        continue
        
    yn = output[i]
    print(f"i={i} Answer: {yn}")
    yn_real = str(true_results[i])
    
    yn = re.split(r'\s+|-', yn)  # Split by spaces or hyphens
    yn = [re.sub(r'[^a-zA-Z]', '', j).lower() for j in yn]  # Remove non-alphabetic characters, convert to lowercase
    yn = [j for j in yn if j in ['yes', 'no']] # Keep only "yes" or "no"
    
    if len(yn) == 0:
        output_final[i] = "error_2"  # No valid response detected, bad prediction
    
    yes_count = yn.count('yes')
    no_count = yn.count('no')
    
    if yes_count > no_count:
        output_final[i] = "Y"
    elif no_count > yes_count:
        output_final[i] = "N"
        
    # Check if the given input is valid
    if yn_real.strip() and yn_real.lower() != 'nan':
        if 'y' in yn_real.lower():
            true_results_final[i] = "Y" # Some are input like N/Y or Y/N/N so look for Y and if exists compare with that (increased acc by ~9%)
        else:
            true_results_final[i] = yn_real.strip()
    else:
        true_results_final[i] = "error_1" # No valid input provided in true_results, bad note
    
    print(f"Result[{i}]: ChatGPT Prediction = {output_final[i]} Answer Given = {true_results_final[i]}")
# Out:
# i=0 Answer: No
# Result[0]: ChatGPT Prediction = N Answer Given = N
# i=1 Answer: Yes
# Result[1]: ChatGPT Prediction = Y Answer Given = N
# i=2 Answer: No
# Result[2]: ChatGPT Prediction = N Answer Given = N
# i=3 Answer: No
# Result[3]: ChatGPT Prediction = N Answer Given = N
# i=4 Answer: No
# Result[4]: ChatGPT Prediction = N Answer Given = N
# i=5 Answer: No
# Result[5]: ChatGPT Prediction = N Answer Given = N
# i=6 Answer: No
# Result[6]: ChatGPT Prediction = N Answer Given = N
# i=7 Answer: No
# Result[7]: ChatGPT Prediction = N Answer Given = N
# i=8 Answer: Yes
# Result[8]: ChatGPT Prediction = Y Answer Given = Y
# i=9 Answer: No
# Result[9]: ChatGPT Prediction = N Answer Given = N
# i=10 Answer: Yes
# Result[10]: ChatGPT Prediction = Y Answer Given = Y
# i=11 Answer: No
# Result[11]: ChatGPT Prediction = N Answer Given = N
# i=12 Answer: No
# Result[12]: ChatGPT Prediction = N Answer Given = N
# i=13 Answer: No
# Result[13]: ChatGPT Prediction = N Answer Given = N
# i=14 Answer: No
# Result[14]: ChatGPT Prediction = N Answer Given = N
# i=15 Answer: Yes
# Result[15]: ChatGPT Prediction = Y Answer Given = Y
# i=16 Answer: No
# Result[16]: ChatGPT Prediction = N Answer Given = N
# i=17 Answer: No
# Result[17]: ChatGPT Prediction = N Answer Given = N
# i=18 Answer: No
# Result[18]: ChatGPT Prediction = N Answer Given = N
# i=19 Answer: Yes
# Result[19]: ChatGPT Prediction = Y Answer Given = N
# i=20 Answer: No
# Result[20]: ChatGPT Prediction = N Answer Given = N
# i=21 Answer: No
# Result[21]: ChatGPT Prediction = N Answer Given = N
# i=22 Answer: No
# Result[22]: ChatGPT Prediction = N Answer Given = N
# i=23 Answer: No
# Result[23]: ChatGPT Prediction = N Answer Given = N
# i=24 Answer: No
# Result[24]: ChatGPT Prediction = N Answer Given = error_1
# i=25 Answer: No
# Result[25]: ChatGPT Prediction = N Answer Given = N
# i=26 Answer: No
# Result[26]: ChatGPT Prediction = N Answer Given = N
# i=27 Answer: No
# Result[27]: ChatGPT Prediction = N Answer Given = Y
# i=28 Answer: Yes
# Result[28]: ChatGPT Prediction = Y Answer Given = Y
# i=29 Answer: No
# Result[29]: ChatGPT Prediction = N Answer Given = N
# i=30 Answer: No
# Result[30]: ChatGPT Prediction = N Answer Given = N
# i=31 Answer: No
# Result[31]: ChatGPT Prediction = N Answer Given = N
# i=32 Answer: No
# Result[32]: ChatGPT Prediction = N Answer Given = N
# i=33 Answer: Yes
# Result[33]: ChatGPT Prediction = Y Answer Given = N
# i=34 Answer: No
# Result[34]: ChatGPT Prediction = N Answer Given = N
# i=35 Answer: No
# Result[35]: ChatGPT Prediction = N Answer Given = N
# i=36 Answer: Yes
# Result[36]: ChatGPT Prediction = Y Answer Given = Y
# i=37 Answer: Yes
# Result[37]: ChatGPT Prediction = Y Answer Given = N
# i=38 Answer: No
# Result[38]: ChatGPT Prediction = N Answer Given = N
# i=39 Answer: No
# Result[39]: ChatGPT Prediction = N Answer Given = N
# i=40 Answer: Yes
# Result[40]: ChatGPT Prediction = Y Answer Given = Y
# i=41 Answer: No
# Result[41]: ChatGPT Prediction = N Answer Given = N
# i=42 Answer: No
# Result[42]: ChatGPT Prediction = N Answer Given = N
# i=43 Answer: Yes
# Result[43]: ChatGPT Prediction = Y Answer Given = N
# i=44 Answer: No
# Result[44]: ChatGPT Prediction = N Answer Given = N
# i=45 Answer: No
# Result[45]: ChatGPT Prediction = N Answer Given = N
# i=46 Answer: No.
# Result[46]: ChatGPT Prediction = N Answer Given = N
# i=47 Answer: No
# Result[47]: ChatGPT Prediction = N Answer Given = N
# i=48 Answer: No
# Result[48]: ChatGPT Prediction = N Answer Given = N
# i=49 Answer: Yes
# Result[49]: ChatGPT Prediction = Y Answer Given = N
# i=50 Answer: Yes
# Result[50]: ChatGPT Prediction = Y Answer Given = Y
# i=51 Answer: No
# Result[51]: ChatGPT Prediction = N Answer Given = N
# i=52 Answer: Yes
# Result[52]: ChatGPT Prediction = Y Answer Given = N
# i=53 Answer: Yes
# Result[53]: ChatGPT Prediction = Y Answer Given = N
# i=54 Answer: No
# Result[54]: ChatGPT Prediction = N Answer Given = N
# i=55 Answer: Yes
# Result[55]: ChatGPT Prediction = Y Answer Given = Y
# i=56 Answer: No
# Result[56]: ChatGPT Prediction = N Answer Given = N
# i=57 Answer: No
# Result[57]: ChatGPT Prediction = N Answer Given = N
# i=58 Answer: No
# Result[58]: ChatGPT Prediction = N Answer Given = N
# i=59 Answer: No
# Result[59]: ChatGPT Prediction = N Answer Given = N
# i=60 Answer: No
# Result[60]: ChatGPT Prediction = N Answer Given = N
# i=61 Answer: No
# Result[61]: ChatGPT Prediction = N Answer Given = N
# i=62 Answer: Yes
# Result[62]: ChatGPT Prediction = Y Answer Given = Y
# i=63 Answer: No
# Result[63]: ChatGPT Prediction = N Answer Given = N
# i=64 Answer: No
# Result[64]: ChatGPT Prediction = N Answer Given = N
# i=65 Answer: No
# Result[65]: ChatGPT Prediction = N Answer Given = N
# i=66 Answer: No
# Result[66]: ChatGPT Prediction = N Answer Given = N
# i=67 Answer: Yes
# Result[67]: ChatGPT Prediction = Y Answer Given = Y
# i=68 Answer: No
# Result[68]: ChatGPT Prediction = N Answer Given = N
# i=69 Answer: No
# Result[69]: ChatGPT Prediction = N Answer Given = N
# i=70 Answer: Yes
# Result[70]: ChatGPT Prediction = Y Answer Given = N
# i=71 Answer: No
# Result[71]: ChatGPT Prediction = N Answer Given = N
# i=72 Answer: No
# Result[72]: ChatGPT Prediction = N Answer Given = N
# i=73 Answer: No
# Result[73]: ChatGPT Prediction = N Answer Given = N
# i=74 Answer: No
# Result[74]: ChatGPT Prediction = N Answer Given = N
# i=75 Answer: No
# Result[75]: ChatGPT Prediction = N Answer Given = Y
# i=76 Answer: No
# Result[76]: ChatGPT Prediction = N Answer Given = N
# i=77 Answer: No
# Result[77]: ChatGPT Prediction = N Answer Given = N
# i=78 Answer: No
# Result[78]: ChatGPT Prediction = N Answer Given = N
# i=79 Answer: No
# Result[79]: ChatGPT Prediction = N Answer Given = N
# i=80 Answer: Yes
# Result[80]: ChatGPT Prediction = Y Answer Given = N
# i=81 Answer: No
# Result[81]: ChatGPT Prediction = N Answer Given = N
# i=82 Answer: No
# Result[82]: ChatGPT Prediction = N Answer Given = N
# i=83 Answer: No
# Result[83]: ChatGPT Prediction = N Answer Given = N
# i=84 Answer: Yes
# Result[84]: ChatGPT Prediction = Y Answer Given = Y
# i=85 Answer: No
# Result[85]: ChatGPT Prediction = N Answer Given = N
# i=86 Answer: Yes
# Result[86]: ChatGPT Prediction = Y Answer Given = Y
# i=87 Answer: Yes
# Result[87]: ChatGPT Prediction = Y Answer Given = Y
# i=88 Answer: Yes
# Result[88]: ChatGPT Prediction = Y Answer Given = N
# i=89 Answer: Yes
# Result[89]: ChatGPT Prediction = Y Answer Given = Y
# i=90 Answer: No
# Result[90]: ChatGPT Prediction = N Answer Given = N
# i=91 Answer: No
# Result[91]: ChatGPT Prediction = N Answer Given = N
# i=92 Answer: No
# Result[92]: ChatGPT Prediction = N Answer Given = N
# i=93 Answer: No
# Result[93]: ChatGPT Prediction = N Answer Given = N
# i=94 Answer: No
# Result[94]: ChatGPT Prediction = N Answer Given = N
# i=95 Answer: No
# Result[95]: ChatGPT Prediction = N Answer Given = N
# i=96 Answer: No
# Result[96]: ChatGPT Prediction = N Answer Given = N
# i=97 Answer: No
# Result[97]: ChatGPT Prediction = N Answer Given = N
# i=98 Answer: No
# Result[98]: ChatGPT Prediction = N Answer Given = N
# i=99 Answer: Yes
# Result[99]: ChatGPT Prediction = Y Answer Given = Y
# i=100 Answer: No
# Result[100]: ChatGPT Prediction = N Answer Given = N
# i=101 Answer: No
# Result[101]: ChatGPT Prediction = N Answer Given = N
# i=102 Answer: No
# Result[102]: ChatGPT Prediction = N Answer Given = Y
# i=103 Answer: No
# Result[103]: ChatGPT Prediction = N Answer Given = N
# i=104 Answer: No.
# Result[104]: ChatGPT Prediction = N Answer Given = N
# i=105 Answer: No
# Result[105]: ChatGPT Prediction = N Answer Given = Y
# i=106 Answer: Yes
# Result[106]: ChatGPT Prediction = Y Answer Given = Y
# i=107 Answer: No
# Result[107]: ChatGPT Prediction = N Answer Given = N
# i=108 Answer: Yes
# Result[108]: ChatGPT Prediction = Y Answer Given = N
# i=109 Answer: Yes
# Result[109]: ChatGPT Prediction = Y Answer Given = N
# i=110 Answer: No
# Result[110]: ChatGPT Prediction = N Answer Given = N
# i=111 Answer: Yes
# Result[111]: ChatGPT Prediction = Y Answer Given = Y
# i=112 Answer: No
# Result[112]: ChatGPT Prediction = N Answer Given = N
# i=113 Answer: No
# Result[113]: ChatGPT Prediction = N Answer Given = error_1
# i=114 Answer: No
# Result[114]: ChatGPT Prediction = N Answer Given = N
# i=115 Answer: Yes
# Result[115]: ChatGPT Prediction = Y Answer Given = Y
# i=116 Answer: No
# Result[116]: ChatGPT Prediction = N Answer Given = Y
# i=117 Answer: No
# Result[117]: ChatGPT Prediction = N Answer Given = N
# i=118 Answer: No
# Result[118]: ChatGPT Prediction = N Answer Given = N
# i=119 Answer: No
# Result[119]: ChatGPT Prediction = N Answer Given = N
# i=120 Answer: No
# Result[120]: ChatGPT Prediction = N Answer Given = N
# i=121 Answer: No
# Result[121]: ChatGPT Prediction = N Answer Given = N
# i=122 Answer: No
# Result[122]: ChatGPT Prediction = N Answer Given = N
# i=123 Answer: No
# Result[123]: ChatGPT Prediction = N Answer Given = N
# i=124 Answer: No.
# Result[124]: ChatGPT Prediction = N Answer Given = N
# i=125 Answer: No
# Result[125]: ChatGPT Prediction = N Answer Given = N
# i=126 Answer: No
# Result[126]: ChatGPT Prediction = N Answer Given = Y
# i=127 Answer: No
# Result[127]: ChatGPT Prediction = N Answer Given = N
# i=128 Answer: No
# Result[128]: ChatGPT Prediction = N Answer Given = N
# i=129 Answer: Yes
# Result[129]: ChatGPT Prediction = Y Answer Given = Y
# i=130 Answer: Yes
# Result[130]: ChatGPT Prediction = Y Answer Given = N
# i=131 Answer: Yes
# Result[131]: ChatGPT Prediction = Y Answer Given = Y
# i=132 Answer: No
# Result[132]: ChatGPT Prediction = N Answer Given = N
# i=133 Answer: No
# Result[133]: ChatGPT Prediction = N Answer Given = N
# i=134 Answer: Yes
# Result[134]: ChatGPT Prediction = Y Answer Given = Y
# i=135 Answer: No
# Result[135]: ChatGPT Prediction = N Answer Given = N
# i=136 Answer: Yes
# Result[136]: ChatGPT Prediction = Y Answer Given = Y
# i=137 Answer: No
# Result[137]: ChatGPT Prediction = N Answer Given = N
# i=138 Answer: No
# Result[138]: ChatGPT Prediction = N Answer Given = N
# i=139 Answer: No
# Result[139]: ChatGPT Prediction = N Answer Given = N
# i=140 Answer: No
# Result[140]: ChatGPT Prediction = N Answer Given = N
# i=141 Answer: Yes
# Result[141]: ChatGPT Prediction = Y Answer Given = N
# i=142 Answer: Yes
# Result[142]: ChatGPT Prediction = Y Answer Given = Y
# i=143 Answer: No
# Result[143]: ChatGPT Prediction = N Answer Given = N
# i=144 Answer: Yes
# Result[144]: ChatGPT Prediction = Y Answer Given = Y
# i=145 Answer: No
# Result[145]: ChatGPT Prediction = N Answer Given = N
# i=146 Answer: No
# Result[146]: ChatGPT Prediction = N Answer Given = N
# i=147 Answer: No
# Result[147]: ChatGPT Prediction = N Answer Given = N
# i=148 Answer: No
# Result[148]: ChatGPT Prediction = N Answer Given = N
# i=149 Answer: No
# Result[149]: ChatGPT Prediction = N Answer Given = N
# i=150 Answer: No.
# Result[150]: ChatGPT Prediction = N Answer Given = N
# i=151 Answer: No
# Result[151]: ChatGPT Prediction = N Answer Given = N
# i=152 Answer: No
# Result[152]: ChatGPT Prediction = N Answer Given = N
# i=153 Answer: No
# Result[153]: ChatGPT Prediction = N Answer Given = N
# i=154 Answer: No
# Result[154]: ChatGPT Prediction = N Answer Given = N
# i=155 Answer: No
# Result[155]: ChatGPT Prediction = N Answer Given = N
# i=156 Answer: Yes
# Result[156]: ChatGPT Prediction = Y Answer Given = Y
# i=157 Answer: No
# Result[157]: ChatGPT Prediction = N Answer Given = N
# i=158 Answer: No.
# Result[158]: ChatGPT Prediction = N Answer Given = N
# i=159 Answer: Yes
# Result[159]: ChatGPT Prediction = Y Answer Given = N
# i=160 Answer: No
# Result[160]: ChatGPT Prediction = N Answer Given = N
# i=161 Answer: Yes
# Result[161]: ChatGPT Prediction = Y Answer Given = N
# i=162 Answer: No
# Result[162]: ChatGPT Prediction = N Answer Given = N
# i=163 Answer: No
# Result[163]: ChatGPT Prediction = N Answer Given = N
# i=164 Answer: No
# Result[164]: ChatGPT Prediction = N Answer Given = N
# i=165 Answer: No
# Result[165]: ChatGPT Prediction = N Answer Given = N
# i=166 Answer: Yes
# Result[166]: ChatGPT Prediction = Y Answer Given = Y
# i=167 Answer: Yes
# Result[167]: ChatGPT Prediction = Y Answer Given = Y
# i=168 Answer: Yes
# Result[168]: ChatGPT Prediction = Y Answer Given = N
# i=169 Answer: No
# Result[169]: ChatGPT Prediction = N Answer Given = N
# i=170 Answer: No
# Result[170]: ChatGPT Prediction = N Answer Given = N
# i=171 Answer: No
# Result[171]: ChatGPT Prediction = N Answer Given = N
# i=172 Answer: No
# Result[172]: ChatGPT Prediction = N Answer Given = N
# i=173 Answer: No
# Result[173]: ChatGPT Prediction = N Answer Given = N
# i=174 Answer: Yes
# Result[174]: ChatGPT Prediction = Y Answer Given = Y
# i=175 Answer: No
# Result[175]: ChatGPT Prediction = N Answer Given = N
# i=176 Answer: No
# Result[176]: ChatGPT Prediction = N Answer Given = N
# i=177 Answer: No
# Result[177]: ChatGPT Prediction = N Answer Given = N
# i=178 Answer: No
# Result[178]: ChatGPT Prediction = N Answer Given = N
# i=179 Answer: No
# Result[179]: ChatGPT Prediction = N Answer Given = N
# i=180 Answer: No
# Result[180]: ChatGPT Prediction = N Answer Given = N
# i=181 Answer: No
# Result[181]: ChatGPT Prediction = N Answer Given = N
# i=182 Answer: Yes
# Result[182]: ChatGPT Prediction = Y Answer Given = Y
# i=183 Answer: No
# Result[183]: ChatGPT Prediction = N Answer Given = N
# i=184 Answer: No
# Result[184]: ChatGPT Prediction = N Answer Given = N
# i=185 Answer: No
# Result[185]: ChatGPT Prediction = N Answer Given = N
# i=186 Answer: Yes
# Result[186]: ChatGPT Prediction = Y Answer Given = Y
# i=187 Answer: No
# Result[187]: ChatGPT Prediction = N Answer Given = N
# i=188 Answer: No
# Result[188]: ChatGPT Prediction = N Answer Given = N
# i=189 Answer: Yes
# Result[189]: ChatGPT Prediction = Y Answer Given = Y
# i=190 Answer: No
# Result[190]: ChatGPT Prediction = N Answer Given = N
# i=191 Answer: Yes
# Result[191]: ChatGPT Prediction = Y Answer Given = Y
# i=192 Answer: No
# Result[192]: ChatGPT Prediction = N Answer Given = N
# i=193 Answer: No
# Result[193]: ChatGPT Prediction = N Answer Given = N
# i=194 Answer: No
# Result[194]: ChatGPT Prediction = N Answer Given = N
# i=195 Answer: Yes
# Result[195]: ChatGPT Prediction = Y Answer Given = Y
# i=196 Answer: No
# Result[196]: ChatGPT Prediction = N Answer Given = N
# i=197 Answer: Yes
# Result[197]: ChatGPT Prediction = Y Answer Given = Y
# i=198 Answer: No
# Result[198]: ChatGPT Prediction = N Answer Given = N
# i=199 Answer: Yes
# Result[199]: ChatGPT Prediction = Y Answer Given = Y
# i=200 Answer: No
# Result[200]: ChatGPT Prediction = N Answer Given = N
# i=201 Answer: Yes
# Result[201]: ChatGPT Prediction = Y Answer Given = Y
# i=202 Answer: Yes
# Result[202]: ChatGPT Prediction = Y Answer Given = Y
# i=203 Answer: Yes
# Result[203]: ChatGPT Prediction = Y Answer Given = Y
# i=204 Answer: No
# Result[204]: ChatGPT Prediction = N Answer Given = N
# i=205 Answer: No
# Result[205]: ChatGPT Prediction = N Answer Given = N
# i=206 Answer: No
# Result[206]: ChatGPT Prediction = N Answer Given = N
# i=207 Answer: Yes
# Result[207]: ChatGPT Prediction = Y Answer Given = Y
# i=208 Answer: No
# Result[208]: ChatGPT Prediction = N Answer Given = N
# i=209 Answer: Yes
# Result[209]: ChatGPT Prediction = Y Answer Given = Y
# i=210 Answer: Yes
# Result[210]: ChatGPT Prediction = Y Answer Given = Y
# i=211 Answer: No
# Result[211]: ChatGPT Prediction = N Answer Given = N
# i=212 Answer: No.
# Result[212]: ChatGPT Prediction = N Answer Given = Y
# i=213 Answer: No.
# Result[213]: ChatGPT Prediction = N Answer Given = N
# i=214 Answer: No
# Result[214]: ChatGPT Prediction = N Answer Given = N
# i=215 Answer: Yes
# Result[215]: ChatGPT Prediction = Y Answer Given = Y
# i=216 Answer: No
# Result[216]: ChatGPT Prediction = N Answer Given = N
# i=217 Answer: Yes
# Result[217]: ChatGPT Prediction = Y Answer Given = Y
# i=218 Answer: No
# Result[218]: ChatGPT Prediction = N Answer Given = N
# i=219 Answer: No
# Result[219]: ChatGPT Prediction = N Answer Given = N
# i=220 Answer: No
# Result[220]: ChatGPT Prediction = N Answer Given = N
# i=221 Answer: Yes
# Result[221]: ChatGPT Prediction = Y Answer Given = Y
# i=222 Answer: Yes
# Result[222]: ChatGPT Prediction = Y Answer Given = Y
# i=223 Answer: No
# Result[223]: ChatGPT Prediction = N Answer Given = N
# i=224 Answer: No
# Result[224]: ChatGPT Prediction = N Answer Given = N
# i=225 Answer: Yes
# Result[225]: ChatGPT Prediction = Y Answer Given = Y
# i=226 Answer: No
# Result[226]: ChatGPT Prediction = N Answer Given = N
# i=227 Answer: Yes
# Result[227]: ChatGPT Prediction = Y Answer Given = Y
# i=228 Answer: No
# Result[228]: ChatGPT Prediction = N Answer Given = Y
# i=229 Answer: No
# Result[229]: ChatGPT Prediction = N Answer Given = N
# i=230 Answer: No
# Result[230]: ChatGPT Prediction = N Answer Given = N
# i=231 Answer: Yes
# Result[231]: ChatGPT Prediction = Y Answer Given = Y
# i=232 Answer: No
# Result[232]: ChatGPT Prediction = N Answer Given = N
# i=233 Answer: No
# Result[233]: ChatGPT Prediction = N Answer Given = N
# i=234 Answer: No
# Result[234]: ChatGPT Prediction = N Answer Given = N
# i=235 Answer: No
# Result[235]: ChatGPT Prediction = N Answer Given = N
# i=236 Answer: No
# Result[236]: ChatGPT Prediction = N Answer Given = N
# i=237 Answer: No
# Result[237]: ChatGPT Prediction = N Answer Given = Y
# i=238 Answer: No
# Result[238]: ChatGPT Prediction = N Answer Given = N
# i=239 Answer: Yes
# Result[239]: ChatGPT Prediction = Y Answer Given = Y
# i=240 Answer: No
# Result[240]: ChatGPT Prediction = N Answer Given = N
# i=241 Answer: No
# Result[241]: ChatGPT Prediction = N Answer Given = Y
# i=242 Answer: No
# Result[242]: ChatGPT Prediction = N Answer Given = Y
# i=243 Answer: Yes
# Result[243]: ChatGPT Prediction = Y Answer Given = Y
# i=244 Answer: No
# Result[244]: ChatGPT Prediction = N Answer Given = N
# i=245 Answer: No
# Result[245]: ChatGPT Prediction = N Answer Given = N
# i=246 Answer: No
# Result[246]: ChatGPT Prediction = N Answer Given = N
# i=247 Answer: No
# Result[247]: ChatGPT Prediction = N Answer Given = N
# i=248 Answer: Yes
# Result[248]: ChatGPT Prediction = Y Answer Given = N
# i=249 Answer: No
# Result[249]: ChatGPT Prediction = N Answer Given = N
# i=250 Answer: No
# Result[250]: ChatGPT Prediction = N Answer Given = N
# i=251 Answer: Yes
# Result[251]: ChatGPT Prediction = Y Answer Given = N
# i=252 Answer: No
# Result[252]: ChatGPT Prediction = N Answer Given = N
# i=253 Answer: No
# Result[253]: ChatGPT Prediction = N Answer Given = N
# i=254 Answer: No
# Result[254]: ChatGPT Prediction = N Answer Given = Y
# i=255 Answer: Yes
# Result[255]: ChatGPT Prediction = Y Answer Given = Y
# i=256 Answer: Yes
# Result[256]: ChatGPT Prediction = Y Answer Given = Y
# i=257 Answer: Yes
# Result[257]: ChatGPT Prediction = Y Answer Given = Y
# i=258 Answer: No
# Result[258]: ChatGPT Prediction = N Answer Given = N
# i=259 Answer: No
# Result[259]: ChatGPT Prediction = N Answer Given = N
# i=260 Answer: No
# Result[260]: ChatGPT Prediction = N Answer Given = N
# i=261 Answer: No
# Result[261]: ChatGPT Prediction = N Answer Given = N
# i=262 Answer: Yes
# Result[262]: ChatGPT Prediction = Y Answer Given = Y
# i=263 Answer: Yes
# Result[263]: ChatGPT Prediction = Y Answer Given = N
# i=264 Answer: Yes
# Result[264]: ChatGPT Prediction = Y Answer Given = Y
# i=265 Answer: No
# Result[265]: ChatGPT Prediction = N Answer Given = N
# i=266 Answer: No
# Result[266]: ChatGPT Prediction = N Answer Given = N
# i=267 Answer: Yes
# Result[267]: ChatGPT Prediction = Y Answer Given = Y
# i=268 Answer: No
# Result[268]: ChatGPT Prediction = N Answer Given = N
# i=269 Answer: Yes
# Result[269]: ChatGPT Prediction = Y Answer Given = Y
# i=270 Answer: No
# Result[270]: ChatGPT Prediction = N Answer Given = N
# i=271 Answer: No
# Result[271]: ChatGPT Prediction = N Answer Given = N
# i=272 Answer: No
# Result[272]: ChatGPT Prediction = N Answer Given = N
# i=273 Answer: Yes
# Result[273]: ChatGPT Prediction = Y Answer Given = Y
# i=274 Answer: No
# Result[274]: ChatGPT Prediction = N Answer Given = N
# i=275 Answer: Yes
# Result[275]: ChatGPT Prediction = Y Answer Given = Y
# i=276 Answer: No
# Result[276]: ChatGPT Prediction = N Answer Given = N
# i=277 Answer: No
# Result[277]: ChatGPT Prediction = N Answer Given = N
# i=278 Answer: No
# Result[278]: ChatGPT Prediction = N Answer Given = N
# i=279 Answer: Yes
# Result[279]: ChatGPT Prediction = Y Answer Given = Y
# i=280 Answer: Yes
# Result[280]: ChatGPT Prediction = Y Answer Given = N
# i=281 Answer: No
# Result[281]: ChatGPT Prediction = N Answer Given = error_1
# i=282 Answer: No
# Result[282]: ChatGPT Prediction = N Answer Given = N
# i=283 Answer: Yes
# Result[283]: ChatGPT Prediction = Y Answer Given = Y
# i=284 Answer: Yes
# Result[284]: ChatGPT Prediction = Y Answer Given = N
# i=285 Answer: Yes
# Result[285]: ChatGPT Prediction = Y Answer Given = N
# i=286 Answer: No
# Result[286]: ChatGPT Prediction = N Answer Given = Y
# i=287 Answer: No
# Result[287]: ChatGPT Prediction = N Answer Given = Y
# i=288 Answer: Yes
# Result[288]: ChatGPT Prediction = Y Answer Given = Y
# i=289 Answer: No
# Result[289]: ChatGPT Prediction = N Answer Given = N
# i=290 Answer: Yes
# Result[290]: ChatGPT Prediction = Y Answer Given = Y
# i=291 Answer: No
# Result[291]: ChatGPT Prediction = N Answer Given = N
# i=292 Answer: No
# Result[292]: ChatGPT Prediction = N Answer Given = N
# i=293 Answer: No
# Result[293]: ChatGPT Prediction = N Answer Given = N

# %%
def confusionMatrix():
    TP = TN = FP = FN = 0
    for i in range(0, min((sample_size), len(Cat))):
        if output_final[i] == true_results_final[i]: # True+/True-
            if output_final[i] == "Y": # True Positive
                TP += 1
            elif output_final[i] == "N": # True Negative
                TN += 1
        elif(output_final[i] != true_results_final[i] and true_results_final[i] != "error_1" and true_results_final[i] != "error_2"): # False+/False-
            if output_final[i] == "Y": # False Positive
                FP += 1
            elif output_final[i] == "N": # False Negative
                FN += 1
    return {"TP": TP, "TN": TN, "FP": FP, "FN": FN}

def confusionMetrics(confusion_matrix):
    TP = confusion_matrix["TP"]
    TN = confusion_matrix["TN"]
    FP = confusion_matrix["FP"]
    FN = confusion_matrix["FN"]
    
    total = TP + TN + FP + FN
    accuracy = (TP + TN) / (TP + TN + FP + FN) if total else 0 # How often did model predict correctly
    precision = TP / (TP + FP) if (TP + FP) else 0 # When model predicted Y, how often was it correct
    recall = TP / (TP + FN) if (TP + FN) else 0 # How many of the true Y cases did model correctly identify
    F1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) else 0 # Balance between Precision and Recall
    
    return {"accuracy": accuracy, "precision": precision, "recall": recall, "F1": F1}

            
total_size = 0
correct_predictions = 0
no_response_given = 0
no_alphabetical_result_returned = 0
bad_cases_combined = 0
nrg_not_narr = 0
narr_not_nrg = 0
# nrg = no valid response given in (L) column
# narr = no alphabetical result returned from ChatGPT output

for i in range(0, min((sample_size), len(Cat))):
    if(output_final[i] == "error_2" and true_results_final[i] == "error_1"):
        bad_cases_combined += 1
        
    if output_final[i] == "error_2":
        no_alphabetical_result_returned += 1
        if true_results_final[i] != "error_1":
            narr_not_nrg += 1
            
    if true_results_final[i] == "error_1":
        no_response_given += 1
        if output_final[i] != "error_2":
            nrg_not_narr += 1
    
    if output_final[i] == true_results_final[i]:
        correct_predictions += 1
        
    total_size += 1
    
accuracy = correct_predictions / total_size
print("# of Correct Predictions = " + str(correct_predictions))
print("Sample Size = " + str(total_size))
print("Accuracy = " + "{:.2f}%".format(accuracy * 100))
print()

# Accuracy when removing cases where the Location is not given (best to look at)
no_response_given_accuracy = correct_predictions / (total_size - no_response_given)
print("Number of Notes without a Given AT = " + str(no_response_given))
print("Accuracy = " +"{:.2f}%".format(no_response_given_accuracy * 100))
print()

# Accuracy when removing cases where GPT didn't return a valid alphabetical answer (not the best to look at, could be slightly lower)
no_alphabetical_result_returned_accuracy = correct_predictions / (total_size - no_alphabetical_result_returned)
print("Number of PE/A&P/A Notes without a valid GPT Given AT = " + str(no_alphabetical_result_returned))
print("Accuracy = " + "{:.2f}%".format(no_alphabetical_result_returned_accuracy * 100))
print()

# Accuracy when removing all above bad cases (ok to look at, could be slightly lower)
bad_cases_total_accuracy = correct_predictions / (total_size - (narr_not_nrg + nrg_not_narr + bad_cases_combined))
print("Number of Combined Notes without a Given AT = " + str(narr_not_nrg + nrg_not_narr + bad_cases_combined))
print("Accuracy = " + "{:.2f}%".format(bad_cases_total_accuracy * 100))
print()

confusion_matrix = confusionMatrix()
confusion_metrics = confusionMetrics(confusion_matrix)

print("Confusion Matrix:")
for name, value in confusion_matrix.items():
    print(f"{name}: {value}")

print("\nConfusion Matrix Metrics:")
for name, value in confusion_metrics.items():
    print(f"{name}: {(value * 100):.2f}")
# Out:
# # of Correct Predictions = 253
# Sample Size = 294
# Accuracy = 86.05%
#
# Number of Notes without a Given AT = 3
# Accuracy = 86.94%
#
# Number of PE/A&P/A Notes without a valid GPT Given AT = 0
# Accuracy = 86.05%
#
# Number of Combined Notes without a Given AT = 3
# Accuracy = 86.94%
#
# Confusion Matrix:
# TP: 63
# TN: 190
# FP: 24
# FN: 14
#
# Confusion Matrix Metrics:
# accuracy: 86.94
# precision: 72.41
# recall: 81.82
# F1: 76.83

# %%
n_count = 0
for i in range(0, min((sample_size), len(Cat))):
    if output_final[i].strip() != true_results_final[i].strip() and true_results_final[i] != "error_1" and output[i] != "yes":
        n_count += 1
        print(f"i = {i}: Unfiltered ChatGPT Prediction = {output[i]}\nUnfiltered AT Given = {true_results[i]}")
        print(f"i = {i}: ChatGPT Prediction = {output_final[i]} AT Given = {true_results_final[i]}")
        print()
        print("-"*40) # Spacer
print(f"n_count = {n_count}")
# Classifying as Yes way too often, maybe the other is what is causing the issue
# False positive is better than false negative, but early stages so there might be a fix
# 27, 102, 228 (N/Y), 237, 254 (Y/N), 286 (N/Y), 287 (N/Y)
# 126 (Y/N) 241 (N/Y)
# Out:
# i = 8: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 8: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 10: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 10: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 15: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 15: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 27: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 27: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 28: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 28: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 36: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/N
# i = 36: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 40: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 40: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 50: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 50: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 55: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 55: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 62: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/N/Y
# i = 62: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 67: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 67: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 84: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 84: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 87: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 87: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 89: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 89: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 102: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 102: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 105: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 105: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 106: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 106: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 111: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 111: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 115: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/N/N
# i = 115: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 116: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 116: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 126: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/N
# i = 126: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 129: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 129: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 131: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 131: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 134: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 134: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 142: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 142: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 166: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 166: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 167: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 167: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 174: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 174: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 182: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 182: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 189: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/Y
# i = 189: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 191: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 191: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 195: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 195: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 197: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/N
# i = 197: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 199: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/Y
# i = 199: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 201: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 201: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 203: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 203: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 210: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 210: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 212: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 212: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 215: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 215: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 217: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 217: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 222: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/Y
# i = 222: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 225: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 225: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 237: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 237: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 239: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/Y
# i = 239: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 241: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 241: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 242: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 242: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 243: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 243: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 254: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y/N
# i = 254: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 255: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 255: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 256: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 256: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 262: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 262: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 267: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 267: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 269: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 269: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 273: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 273: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 275: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 275: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 283: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = Y
# i = 283: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 286: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 286: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 287: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = N/Y
# i = 287: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 290: Unfiltered ChatGPT Prediction = no
# Unfiltered AT Given = y
# i = 290: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# n_count = 59

# %%
y_count = 0
for i in range(0, min((sample_size), len(Cat))):
    if output_final[i] != true_results_final[i] and true_results_final[i] != "error_1" and output[i] != "no":
        y_count += 1
        print(f"i = {i}: Unfiltered ChatGPT Prediction = {output[i]}\nUnfiltered AT Given = {true_results[i]}")
        print(f"i = {i}: ChatGPT Prediction = {output_final[i]} AT Given = {true_results_final[i]}")
        print()
        print("-"*40) # Spacer
print(f"y_count = {y_count}")
# Out:
# i = 9: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 9: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 16: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 16: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 17: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 17: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 32: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 32: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 37: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 37: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 47: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 47: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 52: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 52: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 53: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 53: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 82: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 82: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 96: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 96: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 109: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 109: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 153: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 153: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 155: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 155: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 159: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 159: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 161: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 161: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 163: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 163: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 175: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 175: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 178: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 178: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 184: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 184: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 187: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 187: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 194: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 194: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 204: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 204: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 208: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 208: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 220: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 220: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 223: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 223: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 226: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 226: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 238: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 238: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 240: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 240: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 265: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 265: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 268: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 268: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 270: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 270: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 284: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 284: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 285: Unfiltered ChatGPT Prediction = yes
# Unfiltered AT Given = N
# i = 285: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# y_count = 33
