# %%
# "Additional Excision (AE)" - A (100%)

# Inform GPT of what qualifies as an AE and what doesn't in system message, then ask if an AE is required and pass in A notes

import os
import pandas as pd
import requests
import base64

#using azure
API_KEY = "2DWhd5NlWo6U8lpUBSWgyCuCL1bgNUAlQyv4sF2Oq6TsNxszq97NJQQJ99AKACHrzpqXJ3w3AAABACOGzNKu"
ENDPOINT = "https://rg-01-hippa-standalone-openai.openai.azure.com/openai/deployments/gpt-4o/chat/completions?api-version=2024-02-15-preview"
def call_gpt(clinical_text):
    """Improved function for AE determination"""
    if not clinical_text.strip():
        return "No"  # Default to No if no clinical text
    
    headers = {
        "Content-Type": "application/json",
        "api-key": API_KEY,
    }
    system_context = """
You are a dermatology specialist analyzing ONLY the Addendum section of clinical notes to determine whether Additional Excision (AE) is being planned, recommended, or discussed.

Return "Yes" if ANY of the following appear in the addendum:
- Additional excision is explicitly stated or implied: e.g., “additional excision recommended,” “to return for wider excision,” “needs AE,” “to schedule further excision,” “coordinating AE,” or “awaiting final excision.”
- Pathology results or margin descriptions clearly justify AE, such as:
   - “positive margin” or “positive at deep margin”
   - “tumor extends to base,” “not clear at base”
   - “residual tumor,” “tumor not fully excised”
   - “infiltrative features,” “aggressive subtype”
- The provider communicates to the patient or clinical team that more surgery is needed or likely.
- The plan includes coordination with surgery or multidisciplinary follow-up specifically related to margin or tumor concerns.

Return "No" if:
- The addendum indicates margins are clear, negative, or completely excised with no mention of future excision.
- The follow-up is routine, cosmetic, observational, or unrelated to AE.
- There is no suggestion of margin involvement or need for further treatment.

**Key rule:**
If the addendum includes *any indication* that the current treatment is insufficient and further excision is under consideration or planned, classify as "Yes".

Output only: "Yes" or "No"
"""






 
    payload = {
        "messages": [
            {"role": "system", "content": system_context},
            {"role": "user", "content": f"Does this patient require additional excision? Clinical notes:\n{clinical_text}"},
        ],
        "temperature": 0.3,  # Lower temperature for more deterministic responses
        "top_p": 0.9,
        "max_tokens": 10
    }
    
    try:
        response = requests.post(ENDPOINT, headers=headers, json=payload)
        response.raise_for_status()
        return response.json()["choices"][0]["message"]["content"].strip()
    except Exception as e:
        print(f"Error calling GPT: {e}")
        return "Error"

# %%
# Use full Excel sheet
import pandas as pd
pd.set_option('display.max_colwidth', 50)

Cat = pd.read_excel(r'../De-Identified Mohs Full Data.xlsx',sheet_name='Identified Data',header=0) # Only Size at Greatest Dimension column
Cat.head()
# Out:
#    Randomized Study Number Size at Greatest Dimension (S) ***Be  sure this is from the note and not the Mohs episode! Recurrent Tumor (R) Location - Nose, Eyelid, Nail, Lip, Genitalia, or Acral (L) Aggressive Tumor Pathology Type (AT) DFSP (D) Coordinated repair with ENT/oculoplastics (C) Additional C&F Additional Excision Multiple Sites  Business Days from Referral to First Appt                                 Physical Exam (PE)                            Assessment & Plan (A&P)                                       Addendum (A)
# 0                       36                                                0.8                                                           Y                                                  N                                             N        N                                             N              N                   N              N                                       32.0  Physical exam:\nGeneral: Well developed, well ...  1. Chronic actinic damage in the setting of hi...  Addendum 7/11/2023\n \nThe pathology results w...
# 1                      240                                                0.6                                                           Y                                                  Y                                             N        N                                             N              N                   N              N                                       40.0  Physical exam:\nGeneral: Well-dressed; well-no...  Procedure Orders\nBiopsy [486623795] ordered b...  Addendum 7/11/2023\nThe pathology results were...
# 2                       32                                                0.3                                                           N                                                  N                                             N        N                                             N              N                   N              N                                        4.0  Physical exam:\nGeneral: Well-dressed; well-no...  Assessment & Plan: \n1. Brown papule on the le...  Addendum 7/13/2023\n \nThe pathology results w...
# 3                      111                                                6.5                                                           N                                                  N                                             N        N                                             Y              N                   N              N                                       35.0  Physical exam:\nVital signs: There were no vit...  Assessment & Plan: \nBiopsy-proven basal cell ...                                                NaN
# 4                      197                                                3.5                                                           N                                                  N                                             N        N                                             N              Y                   Y              N                                       35.0  Physical exam:\nGeneral: Well developed, well ...  Assessment & Plan:  \n1. Chronic actinic sun d...  Addendum 7/5/2023\n \nThe pathology results we...

# %%
# Set options here
sample_size = len(Cat) # Change number to increase or decrease number of patients read from file
#sample_size = 10
multiple_columns = True # Set to True to use all input text columns, False to use only PE column

# Array of indexes containing patients with notes that have problems (Some may be ok, these are from size so a location could exist but not size)
skip_patients_array = [7,8,22,23,32,34,38,39,49,50,52,55,62,66,73,80,88,89,101,102,107,110,121,123,131,133,135,
                       136,137,140,150,155,157,164,170,184,187,193,200,206,210,214,227,228,229,234,252,261,265,279,287,292,293]
skip_patients = False # Set to True to skip bad patient notes, False to keep them in

# %%
# Takes the text in the PE, A&P, and A columns and asks ChatGPT to return "Yes" or "No" to the question
# May use only A column
import re

# Always split into 3 GPT calls, one for each column
def inputSplit(input_columns, que, index):
    while len(input_columns) < 3: # Some text columns may be empty so add a blank entry
        input_columns.append("")
        
    input_string = " ".join(map(str, input_columns)) # Apply str() to each index of input_columns then join with a space
    prompt = f"{que} \n\n {input_string}" # Create base prompt (question + input_columns)
    
    if(len(input_string) > 0):
        tmp_ans = [""] * len(input_columns)
        check_ans = [""] * len(input_columns)
        
        # Split into 3 GPT calls, one per column, and remove anything that isn't a "Yes" or "No" from the result
        for i in range(len(input_columns)):
            prompt = f"{que} \n\n {input_columns[i]}" # Recreate prompt with question + 1 column
            tmp_ans[i] = call_gpt(prompt) # Call GPT with prompt and save answer to array
            
            print(f"tmp_ans[{i}] = {str(tmp_ans[i])}")
            
            check_ans[i] = re.split(r'\s+|-', tmp_ans[i])  # Split by spaces or hyphens
            check_ans[i] = [re.sub(r'[^a-zA-Z]', '', j) for j in check_ans[i]]  # Remove non-alphabetic characters
            check_ans[i] = [j.lower() for j in check_ans[i]]  # Convert all to lowercase to handle variations

            check_ans[i] = [j for j in check_ans[i] if j in ['yes', 'no']] # Keep only "yes" or "no"
            
            print(f"check_ans[{i}] = {str(check_ans[i])}")
        if(check_ans[0] == check_ans[1] or check_ans[0] == check_ans[2]):
            if check_ans[0]:
                return tmp_ans[0]
            elif check_ans[1]:
                return tmp_ans[1]
            elif check_ans[2]:
                return tmp_ans[2]
        elif(check_ans[1] == check_ans[2]):
            if check_ans[1]:
                return tmp_ans[1]
            elif check_ans[2]:
                return tmp_ans[2]    


        # Count num of "yes" and "no"
        yes_count = [0] * len(input_columns)
        no_count = [0] * len(input_columns)
        
        for i in range(len(check_ans)):
            yes_count[i] = check_ans[i].count('yes')
            no_count[i] = check_ans[i].count('no')
            
        print(f"Yes counts: {yes_count}")
        print(f"No counts: {no_count}")
        
        # If no matches, return string that has the most "yes" or "no"
        if any(count > 0 for count in yes_count) or any(count > 0 for count in no_count): # Check count strings for any occurences or "yes" or "no"
            max_yes_no = [0] * len(input_columns)
            max_answer = 0
            max_i = -1
            
            # Check if string has more "yes" or "no"
            for i in range(len(input_columns)):
                max_yes_no[i] = max(yes_count[i], no_count[i])
                
            # Look for highest overall "yes" or "no" then return that string
            for i in range(len(input_columns)):
                if max_answer < max_yes_no[i]:
                    max_answer = max_yes_no[i]
                    max_i = i
            return tmp_ans[max_i]
        
        # All non "yes" or "no" answers, return empty string
        return ""
    else:
        # Somehow input_string is empty
        return "input_string empty"
    

true_results = [0 for i in range(sample_size)]
true_results_final = [0 for i in range(sample_size)]

output = [0 for i in range(sample_size)]
output_final = [0 for i in range(sample_size)]

for i in range(0, min(sample_size, len(Cat))):
    # If skip_patients is True and current index is in skip_patients_array, move to next index
    if skip_patients and i in skip_patients_array:
        continue
        
    true_results[i] = Cat.at[i, 'Additional Excision']
    que = que = "Does this case require an additional excision?"
    ans = ""
    
    if multiple_columns:
        input_columns = Cat.loc[i, ['Physical Exam (PE)', 'Assessment & Plan (A&P)', 'Addendum (A)']]
        ans = inputSplit(input_columns, que, i) # Result from GPT call
    elif not multiple_columns:
        input_columns = Cat.at[i, 'Addendum (A)']
        prompt = f"{que} \n\n {input_columns}"
        ans = call_gpt(prompt)
    
    print(f"Result[{i}] = {ans}")
    output[i] = ans
# Out:
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[0] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[1] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[2] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[3] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[4] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[5] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[6] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[7] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[8] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[9] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[10] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[11] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[12] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[13] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[14] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[15] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[16] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[17] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[18] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[19] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[20] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[21] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[22] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[23] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[24] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[25] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[26] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[27] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[28] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[29] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[30] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[31] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[32] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[33] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[34] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[35] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[36] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[37] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[38] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[39] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[40] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[41] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[42] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[43] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[44] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[45] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[46] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[47] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[48] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[49] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[50] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[51] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[52] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[53] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[54] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[55] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[56] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[57] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[58] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[59] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[60] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[61] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[62] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[63] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[64] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[65] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[66] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[67] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[68] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[69] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[70] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[71] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[72] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[73] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[74] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[75] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[76] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[77] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[78] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[79] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[80] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[81] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[82] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[83] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[84] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[85] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[86] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[87] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[88] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[89] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[90] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[91] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[92] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[93] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[94] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[95] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[96] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[97] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[98] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[99] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[100] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[101] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[102] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[103] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[104] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[105] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[106] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[107] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[108] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[109] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[110] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[111] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[112] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[113] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[114] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[115] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[116] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[117] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[118] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[119] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[120] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[121] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[122] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[123] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[124] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[125] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[126] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[127] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[128] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[129] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[130] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[131] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[132] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[133] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[134] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[135] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[136] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[137] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[138] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[139] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[140] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[141] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[142] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[143] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[144] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[145] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[146] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[147] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[148] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[149] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[150] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[151] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[152] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[153] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[154] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[155] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[156] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[157] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[158] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[159] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[160] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[161] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[162] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[163] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[164] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[165] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[166] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[167] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[168] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[169] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[170] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[171] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[172] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[173] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[174] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[175] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[176] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[177] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[178] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[179] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[180] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[181] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[182] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[183] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[184] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[185] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[186] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[187] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[188] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[189] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[190] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[191] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[192] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[193] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[194] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[195] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[196] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[197] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[198] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[199] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[200] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[201] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[202] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[203] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[204] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[205] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[206] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[207] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[208] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[209] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[210] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[211] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[212] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[213] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[214] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[215] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[216] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[217] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[218] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[219] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[220] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[221] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[222] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[223] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[224] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[225] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[226] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[227] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[228] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[229] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[230] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[231] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[232] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[233] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[234] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[235] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[236] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[237] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[238] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[239] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[240] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[241] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[242] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[243] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[244] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[245] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[246] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[247] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[248] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[249] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[250] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[251] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[252] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[253] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[254] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[255] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[256] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[257] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[258] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[259] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[260] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[261] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[262] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[263] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[264] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[265] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[266] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[267] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[268] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[269] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[270] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[271] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[272] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[273] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[274] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[275] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[276] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = No
# check_ans[2] = ['no']
# Result[277] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[278] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = Yes
# check_ans[1] = ['yes']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[279] = Yes
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[280] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[281] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[282] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[283] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[284] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[285] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[286] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[287] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[288] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[289] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[290] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[291] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[292] = No
# tmp_ans[0] = No
# check_ans[0] = ['no']
# tmp_ans[1] = No
# check_ans[1] = ['no']
# tmp_ans[2] = Yes
# check_ans[2] = ['yes']
# Result[293] = No

# %%
import re

# Go through every GPT response and turn it into "Y" or "N" to compare
for i in range(0, min(sample_size, len(Cat))):
    if skip_patients and i in skip_patients_array:
        continue
        
    yn = output[i]
    print(f"i={i} Answer: {yn}")
    yn_real = str(true_results[i])
    
    yn = re.split(r'\s+|-', yn)  # Split by spaces or hyphens
    yn = [re.sub(r'[^a-zA-Z]', '', j) for j in yn]  # Remove non-alphabetic characters
    yn = [j.lower() for j in yn]  # Convert all to lowercase to handle variations
    
    yn = [j for j in yn if j in ['yes', 'no']] # Keep only "yes" or "no"
    
    if len(yn) == 0:
        output_final[i] = "error_2"  # No valid response detected, bad prediction
    
    yes_count = yn.count('yes')
    no_count = yn.count('no')
    
    if yes_count > no_count:
        output_final[i] = "Y"
    elif no_count > yes_count:
        output_final[i] = "N"
        
    # Check if the given input is valid
    if yn_real.strip() and yn_real.lower() != 'nan':
        if 'y' in yn_real.lower():
            true_results_final[i] = "Y" # Some are input like N/Y or Y/N/N so look for Y and if exists compare with that
        else:
            true_results_final[i] = yn_real.strip()
    else:
        true_results_final[i] = "error_1" # No valid input provided in true_results, bad note
    
    print(f"Result[{i}]: ChatGPT Prediction = {output_final[i]} Answer Given = {true_results_final[i]}")
# Out:
# i=0 Answer: No
# Result[0]: ChatGPT Prediction = N Answer Given = N
# i=1 Answer: Yes
# Result[1]: ChatGPT Prediction = Y Answer Given = N
# i=2 Answer: No
# Result[2]: ChatGPT Prediction = N Answer Given = N
# i=3 Answer: No
# Result[3]: ChatGPT Prediction = N Answer Given = N
# i=4 Answer: No
# Result[4]: ChatGPT Prediction = N Answer Given = Y
# i=5 Answer: No
# Result[5]: ChatGPT Prediction = N Answer Given = N
# i=6 Answer: No
# Result[6]: ChatGPT Prediction = N Answer Given = N
# i=7 Answer: No
# Result[7]: ChatGPT Prediction = N Answer Given = N
# i=8 Answer: No
# Result[8]: ChatGPT Prediction = N Answer Given = N
# i=9 Answer: No
# Result[9]: ChatGPT Prediction = N Answer Given = N
# i=10 Answer: No
# Result[10]: ChatGPT Prediction = N Answer Given = N
# i=11 Answer: Yes
# Result[11]: ChatGPT Prediction = Y Answer Given = N
# i=12 Answer: No
# Result[12]: ChatGPT Prediction = N Answer Given = N
# i=13 Answer: No
# Result[13]: ChatGPT Prediction = N Answer Given = N
# i=14 Answer: No
# Result[14]: ChatGPT Prediction = N Answer Given = N
# i=15 Answer: No
# Result[15]: ChatGPT Prediction = N Answer Given = N
# i=16 Answer: No
# Result[16]: ChatGPT Prediction = N Answer Given = N
# i=17 Answer: No
# Result[17]: ChatGPT Prediction = N Answer Given = N
# i=18 Answer: No
# Result[18]: ChatGPT Prediction = N Answer Given = N
# i=19 Answer: No
# Result[19]: ChatGPT Prediction = N Answer Given = N
# i=20 Answer: No
# Result[20]: ChatGPT Prediction = N Answer Given = N
# i=21 Answer: No
# Result[21]: ChatGPT Prediction = N Answer Given = N
# i=22 Answer: No
# Result[22]: ChatGPT Prediction = N Answer Given = N
# i=23 Answer: No
# Result[23]: ChatGPT Prediction = N Answer Given = N
# i=24 Answer: No
# Result[24]: ChatGPT Prediction = N Answer Given = error_1
# i=25 Answer: No
# Result[25]: ChatGPT Prediction = N Answer Given = N
# i=26 Answer: No
# Result[26]: ChatGPT Prediction = N Answer Given = N
# i=27 Answer: No
# Result[27]: ChatGPT Prediction = N Answer Given = N
# i=28 Answer: No
# Result[28]: ChatGPT Prediction = N Answer Given = N
# i=29 Answer: No
# Result[29]: ChatGPT Prediction = N Answer Given = N
# i=30 Answer: No
# Result[30]: ChatGPT Prediction = N Answer Given = N
# i=31 Answer: No
# Result[31]: ChatGPT Prediction = N Answer Given = N
# i=32 Answer: Yes
# Result[32]: ChatGPT Prediction = Y Answer Given = N
# i=33 Answer: No
# Result[33]: ChatGPT Prediction = N Answer Given = N
# i=34 Answer: Yes
# Result[34]: ChatGPT Prediction = Y Answer Given = N
# i=35 Answer: No
# Result[35]: ChatGPT Prediction = N Answer Given = N
# i=36 Answer: No
# Result[36]: ChatGPT Prediction = N Answer Given = N
# i=37 Answer: No
# Result[37]: ChatGPT Prediction = N Answer Given = N
# i=38 Answer: No
# Result[38]: ChatGPT Prediction = N Answer Given = N
# i=39 Answer: No
# Result[39]: ChatGPT Prediction = N Answer Given = N
# i=40 Answer: No
# Result[40]: ChatGPT Prediction = N Answer Given = N
# i=41 Answer: No
# Result[41]: ChatGPT Prediction = N Answer Given = N
# i=42 Answer: No
# Result[42]: ChatGPT Prediction = N Answer Given = N
# i=43 Answer: No
# Result[43]: ChatGPT Prediction = N Answer Given = N
# i=44 Answer: No
# Result[44]: ChatGPT Prediction = N Answer Given = N
# i=45 Answer: No
# Result[45]: ChatGPT Prediction = N Answer Given = N
# i=46 Answer: No
# Result[46]: ChatGPT Prediction = N Answer Given = N
# i=47 Answer: No
# Result[47]: ChatGPT Prediction = N Answer Given = N
# i=48 Answer: No
# Result[48]: ChatGPT Prediction = N Answer Given = Y
# i=49 Answer: No
# Result[49]: ChatGPT Prediction = N Answer Given = N
# i=50 Answer: No
# Result[50]: ChatGPT Prediction = N Answer Given = N
# i=51 Answer: No
# Result[51]: ChatGPT Prediction = N Answer Given = Y
# i=52 Answer: No
# Result[52]: ChatGPT Prediction = N Answer Given = N
# i=53 Answer: No
# Result[53]: ChatGPT Prediction = N Answer Given = N
# i=54 Answer: No
# Result[54]: ChatGPT Prediction = N Answer Given = N
# i=55 Answer: No
# Result[55]: ChatGPT Prediction = N Answer Given = N
# i=56 Answer: No
# Result[56]: ChatGPT Prediction = N Answer Given = error_1
# i=57 Answer: No
# Result[57]: ChatGPT Prediction = N Answer Given = N
# i=58 Answer: No
# Result[58]: ChatGPT Prediction = N Answer Given = N
# i=59 Answer: No
# Result[59]: ChatGPT Prediction = N Answer Given = N
# i=60 Answer: No
# Result[60]: ChatGPT Prediction = N Answer Given = N
# i=61 Answer: No
# Result[61]: ChatGPT Prediction = N Answer Given = N
# i=62 Answer: No
# Result[62]: ChatGPT Prediction = N Answer Given = N
# i=63 Answer: No
# Result[63]: ChatGPT Prediction = N Answer Given = N
# i=64 Answer: No
# Result[64]: ChatGPT Prediction = N Answer Given = N
# i=65 Answer: No
# Result[65]: ChatGPT Prediction = N Answer Given = N
# i=66 Answer: No
# Result[66]: ChatGPT Prediction = N Answer Given = Y
# i=67 Answer: No
# Result[67]: ChatGPT Prediction = N Answer Given = N
# i=68 Answer: No
# Result[68]: ChatGPT Prediction = N Answer Given = N
# i=69 Answer: No
# Result[69]: ChatGPT Prediction = N Answer Given = N
# i=70 Answer: No
# Result[70]: ChatGPT Prediction = N Answer Given = N
# i=71 Answer: No
# Result[71]: ChatGPT Prediction = N Answer Given = N
# i=72 Answer: No
# Result[72]: ChatGPT Prediction = N Answer Given = N
# i=73 Answer: No
# Result[73]: ChatGPT Prediction = N Answer Given = N
# i=74 Answer: No
# Result[74]: ChatGPT Prediction = N Answer Given = N
# i=75 Answer: No
# Result[75]: ChatGPT Prediction = N Answer Given = N
# i=76 Answer: No
# Result[76]: ChatGPT Prediction = N Answer Given = N
# i=77 Answer: No
# Result[77]: ChatGPT Prediction = N Answer Given = N
# i=78 Answer: No
# Result[78]: ChatGPT Prediction = N Answer Given = Y
# i=79 Answer: No
# Result[79]: ChatGPT Prediction = N Answer Given = N
# i=80 Answer: No
# Result[80]: ChatGPT Prediction = N Answer Given = N
# i=81 Answer: No
# Result[81]: ChatGPT Prediction = N Answer Given = N
# i=82 Answer: No
# Result[82]: ChatGPT Prediction = N Answer Given = N
# i=83 Answer: No
# Result[83]: ChatGPT Prediction = N Answer Given = N
# i=84 Answer: No
# Result[84]: ChatGPT Prediction = N Answer Given = N
# i=85 Answer: No
# Result[85]: ChatGPT Prediction = N Answer Given = N
# i=86 Answer: No
# Result[86]: ChatGPT Prediction = N Answer Given = N
# i=87 Answer: No
# Result[87]: ChatGPT Prediction = N Answer Given = N
# i=88 Answer: No
# Result[88]: ChatGPT Prediction = N Answer Given = N
# i=89 Answer: No
# Result[89]: ChatGPT Prediction = N Answer Given = N
# i=90 Answer: No
# Result[90]: ChatGPT Prediction = N Answer Given = N
# i=91 Answer: No
# Result[91]: ChatGPT Prediction = N Answer Given = N
# i=92 Answer: No
# Result[92]: ChatGPT Prediction = N Answer Given = N
# i=93 Answer: No
# Result[93]: ChatGPT Prediction = N Answer Given = N
# i=94 Answer: No
# Result[94]: ChatGPT Prediction = N Answer Given = Y
# i=95 Answer: No
# Result[95]: ChatGPT Prediction = N Answer Given = Y
# i=96 Answer: No
# Result[96]: ChatGPT Prediction = N Answer Given = Y
# i=97 Answer: No
# Result[97]: ChatGPT Prediction = N Answer Given = N
# i=98 Answer: No
# Result[98]: ChatGPT Prediction = N Answer Given = N
# i=99 Answer: No
# Result[99]: ChatGPT Prediction = N Answer Given = N
# i=100 Answer: No
# Result[100]: ChatGPT Prediction = N Answer Given = N
# i=101 Answer: No
# Result[101]: ChatGPT Prediction = N Answer Given = N
# i=102 Answer: No
# Result[102]: ChatGPT Prediction = N Answer Given = N
# i=103 Answer: No
# Result[103]: ChatGPT Prediction = N Answer Given = N
# i=104 Answer: No
# Result[104]: ChatGPT Prediction = N Answer Given = N
# i=105 Answer: No
# Result[105]: ChatGPT Prediction = N Answer Given = N
# i=106 Answer: No
# Result[106]: ChatGPT Prediction = N Answer Given = N
# i=107 Answer: No
# Result[107]: ChatGPT Prediction = N Answer Given = N
# i=108 Answer: No
# Result[108]: ChatGPT Prediction = N Answer Given = N
# i=109 Answer: No
# Result[109]: ChatGPT Prediction = N Answer Given = N
# i=110 Answer: No
# Result[110]: ChatGPT Prediction = N Answer Given = N
# i=111 Answer: No
# Result[111]: ChatGPT Prediction = N Answer Given = N
# i=112 Answer: No
# Result[112]: ChatGPT Prediction = N Answer Given = N
# i=113 Answer: No
# Result[113]: ChatGPT Prediction = N Answer Given = error_1
# i=114 Answer: No
# Result[114]: ChatGPT Prediction = N Answer Given = N
# i=115 Answer: No
# Result[115]: ChatGPT Prediction = N Answer Given = N
# i=116 Answer: No
# Result[116]: ChatGPT Prediction = N Answer Given = N
# i=117 Answer: No
# Result[117]: ChatGPT Prediction = N Answer Given = N
# i=118 Answer: No
# Result[118]: ChatGPT Prediction = N Answer Given = N
# i=119 Answer: No
# Result[119]: ChatGPT Prediction = N Answer Given = N
# i=120 Answer: No
# Result[120]: ChatGPT Prediction = N Answer Given = N
# i=121 Answer: No
# Result[121]: ChatGPT Prediction = N Answer Given = N
# i=122 Answer: No
# Result[122]: ChatGPT Prediction = N Answer Given = Y
# i=123 Answer: No
# Result[123]: ChatGPT Prediction = N Answer Given = N
# i=124 Answer: No
# Result[124]: ChatGPT Prediction = N Answer Given = N
# i=125 Answer: No
# Result[125]: ChatGPT Prediction = N Answer Given = Y
# i=126 Answer: No
# Result[126]: ChatGPT Prediction = N Answer Given = N
# i=127 Answer: No
# Result[127]: ChatGPT Prediction = N Answer Given = N
# i=128 Answer: No
# Result[128]: ChatGPT Prediction = N Answer Given = N
# i=129 Answer: No
# Result[129]: ChatGPT Prediction = N Answer Given = N
# i=130 Answer: No
# Result[130]: ChatGPT Prediction = N Answer Given = N
# i=131 Answer: No
# Result[131]: ChatGPT Prediction = N Answer Given = Y
# i=132 Answer: No
# Result[132]: ChatGPT Prediction = N Answer Given = N
# i=133 Answer: No
# Result[133]: ChatGPT Prediction = N Answer Given = N
# i=134 Answer: No
# Result[134]: ChatGPT Prediction = N Answer Given = N
# i=135 Answer: No
# Result[135]: ChatGPT Prediction = N Answer Given = N
# i=136 Answer: No
# Result[136]: ChatGPT Prediction = N Answer Given = N
# i=137 Answer: No
# Result[137]: ChatGPT Prediction = N Answer Given = N
# i=138 Answer: No
# Result[138]: ChatGPT Prediction = N Answer Given = N
# i=139 Answer: No
# Result[139]: ChatGPT Prediction = N Answer Given = N
# i=140 Answer: No
# Result[140]: ChatGPT Prediction = N Answer Given = N
# i=141 Answer: No
# Result[141]: ChatGPT Prediction = N Answer Given = N
# i=142 Answer: No
# Result[142]: ChatGPT Prediction = N Answer Given = N
# i=143 Answer: No
# Result[143]: ChatGPT Prediction = N Answer Given = N
# i=144 Answer: No
# Result[144]: ChatGPT Prediction = N Answer Given = N
# i=145 Answer: No
# Result[145]: ChatGPT Prediction = N Answer Given = N
# i=146 Answer: No
# Result[146]: ChatGPT Prediction = N Answer Given = N
# i=147 Answer: No
# Result[147]: ChatGPT Prediction = N Answer Given = N
# i=148 Answer: No
# Result[148]: ChatGPT Prediction = N Answer Given = N
# i=149 Answer: No
# Result[149]: ChatGPT Prediction = N Answer Given = N
# i=150 Answer: No
# Result[150]: ChatGPT Prediction = N Answer Given = Y
# i=151 Answer: No
# Result[151]: ChatGPT Prediction = N Answer Given = N
# i=152 Answer: No
# Result[152]: ChatGPT Prediction = N Answer Given = N
# i=153 Answer: No
# Result[153]: ChatGPT Prediction = N Answer Given = N
# i=154 Answer: No
# Result[154]: ChatGPT Prediction = N Answer Given = N
# i=155 Answer: No
# Result[155]: ChatGPT Prediction = N Answer Given = N
# i=156 Answer: No
# Result[156]: ChatGPT Prediction = N Answer Given = N
# i=157 Answer: No
# Result[157]: ChatGPT Prediction = N Answer Given = N
# i=158 Answer: No
# Result[158]: ChatGPT Prediction = N Answer Given = N
# i=159 Answer: No
# Result[159]: ChatGPT Prediction = N Answer Given = Y
# i=160 Answer: No
# Result[160]: ChatGPT Prediction = N Answer Given = N
# i=161 Answer: No
# Result[161]: ChatGPT Prediction = N Answer Given = N
# i=162 Answer: No
# Result[162]: ChatGPT Prediction = N Answer Given = N
# i=163 Answer: No
# Result[163]: ChatGPT Prediction = N Answer Given = N
# i=164 Answer: No
# Result[164]: ChatGPT Prediction = N Answer Given = Y
# i=165 Answer: No
# Result[165]: ChatGPT Prediction = N Answer Given = N
# i=166 Answer: No
# Result[166]: ChatGPT Prediction = N Answer Given = N
# i=167 Answer: No
# Result[167]: ChatGPT Prediction = N Answer Given = N
# i=168 Answer: No
# Result[168]: ChatGPT Prediction = N Answer Given = N
# i=169 Answer: No
# Result[169]: ChatGPT Prediction = N Answer Given = N
# i=170 Answer: No
# Result[170]: ChatGPT Prediction = N Answer Given = N
# i=171 Answer: No
# Result[171]: ChatGPT Prediction = N Answer Given = N
# i=172 Answer: No
# Result[172]: ChatGPT Prediction = N Answer Given = N
# i=173 Answer: No
# Result[173]: ChatGPT Prediction = N Answer Given = N
# i=174 Answer: No
# Result[174]: ChatGPT Prediction = N Answer Given = N
# i=175 Answer: No
# Result[175]: ChatGPT Prediction = N Answer Given = N
# i=176 Answer: No
# Result[176]: ChatGPT Prediction = N Answer Given = N
# i=177 Answer: No
# Result[177]: ChatGPT Prediction = N Answer Given = N
# i=178 Answer: No
# Result[178]: ChatGPT Prediction = N Answer Given = N
# i=179 Answer: No
# Result[179]: ChatGPT Prediction = N Answer Given = N
# i=180 Answer: No
# Result[180]: ChatGPT Prediction = N Answer Given = Y
# i=181 Answer: No
# Result[181]: ChatGPT Prediction = N Answer Given = N
# i=182 Answer: No
# Result[182]: ChatGPT Prediction = N Answer Given = N
# i=183 Answer: No
# Result[183]: ChatGPT Prediction = N Answer Given = N
# i=184 Answer: No
# Result[184]: ChatGPT Prediction = N Answer Given = N
# i=185 Answer: No
# Result[185]: ChatGPT Prediction = N Answer Given = N
# i=186 Answer: No
# Result[186]: ChatGPT Prediction = N Answer Given = N
# i=187 Answer: No
# Result[187]: ChatGPT Prediction = N Answer Given = Y
# i=188 Answer: No
# Result[188]: ChatGPT Prediction = N Answer Given = N
# i=189 Answer: No
# Result[189]: ChatGPT Prediction = N Answer Given = N
# i=190 Answer: No
# Result[190]: ChatGPT Prediction = N Answer Given = N
# i=191 Answer: No
# Result[191]: ChatGPT Prediction = N Answer Given = N
# i=192 Answer: No
# Result[192]: ChatGPT Prediction = N Answer Given = N
# i=193 Answer: No
# Result[193]: ChatGPT Prediction = N Answer Given = N
# i=194 Answer: No
# Result[194]: ChatGPT Prediction = N Answer Given = N
# i=195 Answer: No
# Result[195]: ChatGPT Prediction = N Answer Given = N
# i=196 Answer: No
# Result[196]: ChatGPT Prediction = N Answer Given = N
# i=197 Answer: No
# Result[197]: ChatGPT Prediction = N Answer Given = N
# i=198 Answer: No
# Result[198]: ChatGPT Prediction = N Answer Given = N
# i=199 Answer: No
# Result[199]: ChatGPT Prediction = N Answer Given = N
# i=200 Answer: No
# Result[200]: ChatGPT Prediction = N Answer Given = N
# i=201 Answer: No
# Result[201]: ChatGPT Prediction = N Answer Given = N
# i=202 Answer: No
# Result[202]: ChatGPT Prediction = N Answer Given = N
# i=203 Answer: No
# Result[203]: ChatGPT Prediction = N Answer Given = N
# i=204 Answer: No
# Result[204]: ChatGPT Prediction = N Answer Given = N
# i=205 Answer: No
# Result[205]: ChatGPT Prediction = N Answer Given = N
# i=206 Answer: No
# Result[206]: ChatGPT Prediction = N Answer Given = N
# i=207 Answer: Yes
# Result[207]: ChatGPT Prediction = Y Answer Given = N
# i=208 Answer: No
# Result[208]: ChatGPT Prediction = N Answer Given = N
# i=209 Answer: No
# Result[209]: ChatGPT Prediction = N Answer Given = N
# i=210 Answer: No
# Result[210]: ChatGPT Prediction = N Answer Given = N
# i=211 Answer: No
# Result[211]: ChatGPT Prediction = N Answer Given = N
# i=212 Answer: No
# Result[212]: ChatGPT Prediction = N Answer Given = N
# i=213 Answer: No
# Result[213]: ChatGPT Prediction = N Answer Given = N
# i=214 Answer: No
# Result[214]: ChatGPT Prediction = N Answer Given = N
# i=215 Answer: No
# Result[215]: ChatGPT Prediction = N Answer Given = N
# i=216 Answer: No
# Result[216]: ChatGPT Prediction = N Answer Given = N
# i=217 Answer: No
# Result[217]: ChatGPT Prediction = N Answer Given = N
# i=218 Answer: No
# Result[218]: ChatGPT Prediction = N Answer Given = N
# i=219 Answer: No
# Result[219]: ChatGPT Prediction = N Answer Given = N
# i=220 Answer: No
# Result[220]: ChatGPT Prediction = N Answer Given = N
# i=221 Answer: No
# Result[221]: ChatGPT Prediction = N Answer Given = N
# i=222 Answer: No
# Result[222]: ChatGPT Prediction = N Answer Given = N
# i=223 Answer: No
# Result[223]: ChatGPT Prediction = N Answer Given = N
# i=224 Answer: No
# Result[224]: ChatGPT Prediction = N Answer Given = N
# i=225 Answer: No
# Result[225]: ChatGPT Prediction = N Answer Given = N
# i=226 Answer: No
# Result[226]: ChatGPT Prediction = N Answer Given = N
# i=227 Answer: No
# Result[227]: ChatGPT Prediction = N Answer Given = Y
# i=228 Answer: No
# Result[228]: ChatGPT Prediction = N Answer Given = N
# i=229 Answer: No
# Result[229]: ChatGPT Prediction = N Answer Given = Y
# i=230 Answer: No
# Result[230]: ChatGPT Prediction = N Answer Given = N
# i=231 Answer: No
# Result[231]: ChatGPT Prediction = N Answer Given = N
# i=232 Answer: No
# Result[232]: ChatGPT Prediction = N Answer Given = N
# i=233 Answer: No
# Result[233]: ChatGPT Prediction = N Answer Given = N
# i=234 Answer: No
# Result[234]: ChatGPT Prediction = N Answer Given = N
# i=235 Answer: No
# Result[235]: ChatGPT Prediction = N Answer Given = N
# i=236 Answer: No
# Result[236]: ChatGPT Prediction = N Answer Given = N
# i=237 Answer: No
# Result[237]: ChatGPT Prediction = N Answer Given = N
# i=238 Answer: No
# Result[238]: ChatGPT Prediction = N Answer Given = Y
# i=239 Answer: No
# Result[239]: ChatGPT Prediction = N Answer Given = N
# i=240 Answer: No
# Result[240]: ChatGPT Prediction = N Answer Given = N
# i=241 Answer: No
# Result[241]: ChatGPT Prediction = N Answer Given = N
# i=242 Answer: No
# Result[242]: ChatGPT Prediction = N Answer Given = N
# i=243 Answer: No
# Result[243]: ChatGPT Prediction = N Answer Given = N
# i=244 Answer: No
# Result[244]: ChatGPT Prediction = N Answer Given = N
# i=245 Answer: No
# Result[245]: ChatGPT Prediction = N Answer Given = N
# i=246 Answer: No
# Result[246]: ChatGPT Prediction = N Answer Given = Y
# i=247 Answer: No
# Result[247]: ChatGPT Prediction = N Answer Given = N
# i=248 Answer: No
# Result[248]: ChatGPT Prediction = N Answer Given = N
# i=249 Answer: No
# Result[249]: ChatGPT Prediction = N Answer Given = N
# i=250 Answer: No
# Result[250]: ChatGPT Prediction = N Answer Given = N
# i=251 Answer: No
# Result[251]: ChatGPT Prediction = N Answer Given = N
# i=252 Answer: No
# Result[252]: ChatGPT Prediction = N Answer Given = N
# i=253 Answer: No
# Result[253]: ChatGPT Prediction = N Answer Given = N
# i=254 Answer: No
# Result[254]: ChatGPT Prediction = N Answer Given = N
# i=255 Answer: No
# Result[255]: ChatGPT Prediction = N Answer Given = N
# i=256 Answer: No
# Result[256]: ChatGPT Prediction = N Answer Given = N
# i=257 Answer: No
# Result[257]: ChatGPT Prediction = N Answer Given = N
# i=258 Answer: No
# Result[258]: ChatGPT Prediction = N Answer Given = N
# i=259 Answer: No
# Result[259]: ChatGPT Prediction = N Answer Given = N
# i=260 Answer: No
# Result[260]: ChatGPT Prediction = N Answer Given = N
# i=261 Answer: No
# Result[261]: ChatGPT Prediction = N Answer Given = N
# i=262 Answer: No
# Result[262]: ChatGPT Prediction = N Answer Given = N
# i=263 Answer: No
# Result[263]: ChatGPT Prediction = N Answer Given = N
# i=264 Answer: No
# Result[264]: ChatGPT Prediction = N Answer Given = N
# i=265 Answer: No
# Result[265]: ChatGPT Prediction = N Answer Given = Y
# i=266 Answer: No
# Result[266]: ChatGPT Prediction = N Answer Given = N
# i=267 Answer: No
# Result[267]: ChatGPT Prediction = N Answer Given = N
# i=268 Answer: No
# Result[268]: ChatGPT Prediction = N Answer Given = N
# i=269 Answer: No
# Result[269]: ChatGPT Prediction = N Answer Given = N
# i=270 Answer: No
# Result[270]: ChatGPT Prediction = N Answer Given = N
# i=271 Answer: No
# Result[271]: ChatGPT Prediction = N Answer Given = N
# i=272 Answer: No
# Result[272]: ChatGPT Prediction = N Answer Given = N
# i=273 Answer: No
# Result[273]: ChatGPT Prediction = N Answer Given = N
# i=274 Answer: No
# Result[274]: ChatGPT Prediction = N Answer Given = N
# i=275 Answer: No
# Result[275]: ChatGPT Prediction = N Answer Given = N
# i=276 Answer: No
# Result[276]: ChatGPT Prediction = N Answer Given = N
# i=277 Answer: No
# Result[277]: ChatGPT Prediction = N Answer Given = N
# i=278 Answer: No
# Result[278]: ChatGPT Prediction = N Answer Given = N
# i=279 Answer: Yes
# Result[279]: ChatGPT Prediction = Y Answer Given = N
# i=280 Answer: No
# Result[280]: ChatGPT Prediction = N Answer Given = N
# i=281 Answer: No
# Result[281]: ChatGPT Prediction = N Answer Given = N
# i=282 Answer: No
# Result[282]: ChatGPT Prediction = N Answer Given = N
# i=283 Answer: No
# Result[283]: ChatGPT Prediction = N Answer Given = N
# i=284 Answer: No
# Result[284]: ChatGPT Prediction = N Answer Given = N
# i=285 Answer: No
# Result[285]: ChatGPT Prediction = N Answer Given = Y
# i=286 Answer: No
# Result[286]: ChatGPT Prediction = N Answer Given = N
# i=287 Answer: No
# Result[287]: ChatGPT Prediction = N Answer Given = N
# i=288 Answer: No
# Result[288]: ChatGPT Prediction = N Answer Given = N
# i=289 Answer: No
# Result[289]: ChatGPT Prediction = N Answer Given = N
# i=290 Answer: No
# Result[290]: ChatGPT Prediction = N Answer Given = N
# i=291 Answer: No
# Result[291]: ChatGPT Prediction = N Answer Given = N
# i=292 Answer: No
# Result[292]: ChatGPT Prediction = N Answer Given = N
# i=293 Answer: No
# Result[293]: ChatGPT Prediction = N Answer Given = N

# %%
# Configure pandas to show full text
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

for i in range(sample_size):
    if true_results[i] == "Y" and output[i] == "No":
        print(f"\n==== False Negative at index {i} ====")
        # Print full text of both columns
        print("[Addendum]:", Cat.at[i, 'Addendum (A)'])
        print("=" * 50)
# Out:
# ==== False Negative at index 4 ====
# [Addendum]: Addendum 7/5/2023
#
# The pathology results were relayed to the patient's sister via phone call (see below).
#
# Lesion A: considered treated. No further intervention necessary.
#
# Lesion B: Discussed therapeutic options, including Efudex and curettage and electrofulguration, and their associated risks and benefits. Sister opts for curettage and electrofulguration.
#
# Lesion C:  Follow up for excision. Patient's sister denies the patient having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Lesion D: Advised Mohs surgery due to size and location where tissue conservation is critical. Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# We will plan for surgery for lesions B-D on the same day.
#
# Pathology:
# Results for orders placed or performed in visit on 06/28/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Dang, Jacquelyn T, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Swick, Brian L, MD
# Specimens:   A) - Skin shave, right distal dorsal forearm
#              B) - Skin shave, left proximal shin
#              C) - Skin shave, right lateral calf
#              D) - Skin punch, left lateral shin
#
#  	Diagnosis
#  	 	A. Skin, right distal dorsal forearm, shave:
#            Squamous cell carcinoma in situ.
#
# B. Skin, left proximal shin, shave:
#            Superficial basal cell carcinoma.
#
# C. Skin, right lateral calf, shave:
#            Basal cell carcinoma.
#
# D. Skin, left lateral shin, punch:
#            Basal cell carcinoma.
#
# I have personally reviewed this case and edited the report as necessary.
#
#
# ==================================================
#
# ==== False Negative at index 66 ====
# [Addendum]: Addendum 8/29/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# For site A) Patient notified of biopsy result, advised Mohs surgery due to  location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# For site B) Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# For site C patient elects to treat with Curettage and electrofulguration day of mohs procedure/ excision.
#
# Pathology:
# Results for orders placed or performed in visit on 08/21/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Thompson, Hannah J, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Liu, Vincent, MD
# Specimens:   A) - Skin shave, left nasal ala
#              B) - Skin shave, left shoulder
#              C) - Skin shave, right anterior upper arm
#
#  	Diagnosis
#  	 	A. Skin, left nasal ala, shave:
#             Basal cell carcinoma, with nodular features.
#
# B. Skin, left shoulder, shave:
#             Basal cell carcinoma, with nodular features, focally pigmented.
#
# C. Skin, right anterior upper arm, shave:
#             Basal cell carcinoma, with superficial features.
#
#  	Clinical Information
#  	 	59 year old man.  A) Skin shave, left nasal ala.  B) Skin shave, left shoulder.  C) Skin shave, right anterior upper arm.
# A) pink ulcerated papule of 5 weeks duration. Bleeds but not painful. History of squamous cell carcinoma of the lip and clear cell carcinoma of the soft palate.
# Differential diagnosis squamous cell carcinoma vs basal cell carcinoma vs other
# B) pink papule with telangiectasia and a single blue grey globule on dermoscopy
# Differential diagnosis rule out basal cell carcinoma
# C) pink patch with telangiectasia
# Differential diagnosis superficial basal cell carcinoma vs squamous cell carcinoma in situ vs actinic keratosis vs other
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled  "left nasal ala", is a 0.6 x 0.6 x 0.2 cm tan-pink shave biopsy.  The specimen is inked, trisected and submitted entirely in A1.
# MW/tkr
# Specimen B
# Received in formalin, in a container labeled "left shoulder", is a 0.7 x 0.5 x 0.2 cm tan-pink shave biopsy.  The specimen is inked, bisected and submitted entirely in B1.
# MW/tkr
# Specimen C
# Received in formalin, in a container labeled "right anterior upper arm", is a 0.6 x 0.6 x 0.2 cm tan-pink shave biopsy.  The specimen is inked, trisected and submitted entirely in C1.
# MW/tkr
#
#  	Microscopic Description
#  	 	A: Sections show a skin shave demonstrating a serous-crusted and ulcerated proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending from the epidermis into the underlying dermis, transected at specimen base.
# B. Sections show a skin shave demonstrating a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending from the epidermis into the underlying dermis, harboring focal pigment, transected at specimen base.
# C: Sections show a skin shave demonstrating a basaloid proliferation of atypical epithelial cells arranged in islands that demonstrate multiple attachments to the overlying epidermis.  The tumor islands appear confined to the superficial dermis.  Peripheral margin is involved.
# Performed by: Roshan Abid, MD. PGY-3
#
# I have personally reviewed this case and edited the report as necessary.
# Vincent Liu, MD
#
#
#
# ==================================================
#
# ==== False Negative at index 94 ====
# [Addendum]: Addendum 9/18/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Follow up for excision for melanoma in situ. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Patient notified of biopsy result, advised Mohs surgery for the basal cell carcinoma due to the location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 09/08/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Katzman, Charles S, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, left cutaneous upper lip
#              B) - Skin shave, right bicep
#
#  	Diagnosis
#  	 	A) Skin, left cutaneous upper lip, shave biopsy:
#             Basal cell carcinoma
# B) Skin, right bicep, shave biopsy:
#             Melanoma in situ, superficial spreading type.
#
# I have personally reviewed this case and edited the report as necessary.
#
#  	Clinical Information
#  	 	A) 4 mm pearly papule with telangiectasias, differential diagnosis basal cell carcinoma vs sebaceous hyperplasia vs other sebaceous neoplasm vs adnexal neoplasm
# B) 3 mm light brown thin papule on right bicep that is changing in color with irregular pigment on dermoscopy, differential diagnosis includes collision nevus vs seborrheic keratosis vs other melanocytic neoplasm
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "left cutaneous upper lip", is a 0.5 x 0.4 x 0.2 cm tan-pink shave biopsy.  The specimen is inked, bisected and submitted entirely in A1.
# MW/tkr
# Specimen B
# Received in formalin, in a container labeled "right bicep", is a 0.4 x 0.3 x 0.2 cm tan-pink shave biopsy.  The specimen is inked, bisected and submitted entirely in B1.
# MW/tkr
#
#  	Microscopic Description
#  	 	A) Sections of skin show a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending into the dermis. The lesion is transected at the base.
# B) Sections show a lentiginous, nested and pagetoid proliferation of atypical melanocytes within the epidermis. Margins appear uninvolved in the plane of sectioning.
#
# Hannah Thompson, MD
# Dermatology, PGY-3
#
#
#
# ==================================================
#
# ==== False Negative at index 95 ====
# [Addendum]: Addendum 9/18/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# For the basal cell carcinoma on the left upper forehead, advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# For the basal cell carcinoma on the base of the posterior neck, recommended excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Patient was instructed to continue management as planned and call the clinic for any further questions or concerns. Plan to follow up with patient in 6 months.
#
# Pathology:
# Results for orders placed or performed in visit on 09/01/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  O'Bryan, Collin, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Liu, Vincent, MD
# Specimens:   A) - Skin shave, Left upper forehead
#              B) - Skin shave, Base of posterior neck
#
#  	Diagnosis
#  	 	A. Skin, left upper forehead, shave:
#             Basal cell carcinoma, with nodular features.
#
# B. Skin, base of posterior neck, shave:
#             Basal cell carcinoma, with nodular features.
#
#  	Clinical Information
#  	 	A) Skin shave, left upper forehead.  B) Skin shave, base of posterior neck.
# A) Pink papule with overlying telangiectasias. Differential diagnosis includes basal cell carcinoma vs seborrheic keratosis vs benign lichenoid keratosis vs other
# B) Pink papule with overlying telangiectasias. Differential diagnosis includes basal cell carcinoma vs benign lichenoid keratosis vs other
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "left upper forehead" is a 0.6 x 0.4 x 0.1 cm tan-white shave biopsy.  The specimen is inked blue, bisected and submitted entirely in A1.
# KMK/tkr
# Specimen B
# Received in formalin, in a container labeled  "base of posterior neck" is a 0.8 x 0.6 x 0.1 cm tan-white-brown shave biopsy with one hair growing out of it.  The specimen is inked blue, bisected and submitted entirely in B1.
# KMK/tkr
#
#  	Microscopic Description
#  	 	A. Sections show a skin shave demonstrating a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, within the dermis, transected at specimen base.
# B. Sections show a skin shave demonstrating a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending from the epidermis into the underlying dermis, transected at specimen base.
# Hannah Thompson, MD
# Dermatology, PGY-3
#
# I have personally reviewed this case and edited the report as necessary.
# Vincent Liu, MD
#
#
#
# ==================================================
#
# ==== False Negative at index 96 ====
# [Addendum]: Addendum 9/18/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Will plan for excision of left post auricular lesion.
#
# Patient notified of biopsy result, advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 09/12/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Gibbons, Mitchell, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Swick, Brian L, MD
# Specimens:   A) - Skin shave, Right nasal tip
#              B) - Skin shave, Left post auricular skin
#
#  	Diagnosis
#  	 	A. Skin, right nasal tip, shave:
#            Basal cell carcinoma.
#
# B. Skin, left post-auricular, shave:
#            Basal cell carcinoma.
#
# I have personally reviewed this case and edited the report as necessary.
#
#  	Clinical Information	A)  Basal cell carcinoma
# B)  Basal cell carcinoma
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled  "right nasal tip", are two tan-white, unoriented skin shave biopsy fragments measuring 0.3-0.4 cm.  The resection margins are differentially inked blue and green, and each fragment is bisected.  Submitted entirely in A1.
# ARV/rkw
# Specimen B
# Received in formalin, in a container labeled "left post auricular skin", is a 0.5 x 0.3 x 0.1 cm tan-white shave biopsy.  The specimen is inked, bisected and submitted entirely in B1.
# ARV/rkw
#
#  	Microscopic Description
#  	 	A and B. Sections of skin show a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending into the dermis. Margins are involved.
#
#
#
# ==================================================
#
# ==== False Negative at index 122 ====
# [Addendum]: Addendum 9/21/2023
# Attempted to call on 9/21/23 and 9/22/23 and left voicemail. The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# A) Skin, left lateral forehead, shave biopsy: Basal cell carcinoma
# Discussed treatment options including Mohs surgery versus clinical monitoring. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# B) Skin, left anterior shoulder, shave biopsy: Superficial basal cell carcinoma
# Discussed treatment options including excision versus  topical imiquimod versus  curettage and electrofulguration versus clinical monitoring. At this time, patient elects for curettage and electrofulguration. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for curettage and electrofulguration . Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months.
#
# C) Skin, left forearm, shave biopsy: Basal cell carcinoma
# Discussed treatment options including excision versus curettage and electrofulguration versus clinical monitoring. At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Pathology:
# Results for orders placed or performed in visit on 09/18/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Anderson, Elizabeth J, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, Left lateral forehead
#              B) - Skin shave, Left anterior shoulder
#              C) - Skin shave, Left forearm
#
#  	Diagnosis
#  	 	A) Skin, left lateral forehead, shave biopsy:
#             Basal cell carcinoma
# B) Skin, left anterior shoulder, shave biopsy:
#             Superficial basal cell carcinoma
# C) Skin, left forearm, shave biopsy:
#             Basal cell carcinoma
#
# I have personally reviewed this case and edited the report as necessary.
#
#  	Clinical Information
#  	 	History of Non-melanoma skin cancer and Melanoma skin cancer
#
# - A) Left lateral forehead; differential diagnosis basal cell carcinoma vs. other
# - B) Left anterior shoulder; differential diagnosis basal cell carcinoma vs. other
# - C) Left forearm; differential diagnosis basal cell carcinoma vs. Other
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "left lateral forehead", is a 0.7 x 0.7 x 0.1 cm tan-white shave biopsy.  The specimen is inked, trisected and submitted entirely in A1.
# TAE/rkw
# Specimen B
# Received in formalin, in a container labeled  "left anterior shoulder", is a 0.8 x 0.6 x 0.1 cm tan-white shave biopsy.  The specimen is inked, trisected and submitted entirely in B1.
# TAE/rkw
# Specimen C
# Received in formalin, in a container labeled "left forearm", is a 1.0 x 0.7 x 0.2 cm tan-white shave biopsy.  The specimen is inked, quadrisected and submitted entirely in C1.
# TAE/rkw
#
#  	Microscopic Description
#  	 	A) Sections of skin show a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending into the dermis. The lesion is transected at the base.
# B) Sections show a basaloid proliferation of atypical epithelial cells arranged in islands that demonstrate multiple attachments to the overlying epidermis.  The tumor islands are confined to the superficial dermis. Margins very closely approximated.
# C) Sections of skin show a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending into the dermis. The lesion is transected at the base.
# Hannah Thompson, MD
# Dermatology, PGY-3
#
#
#
# ==================================================
#
# ==== False Negative at index 125 ====
# [Addendum]: Addendum 9/18/2023
# Have attempted several calls without answer the past several days to relay biopsy results. Left voicemail for patient to call nursing line with good time of day to reach her. In the meantime. will continue to reach out throughout the week.
#
#
# Rob Shaver, MD
# Dermatology Resident, PGY-2
#
#
# Addendum 9/27/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# Discussed treatment options for basal cell carcinoma on the upper right chest including excision versus curettage and electrofulguration. At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Discussed treatment options for basal cell carcinoma on the right temple including Mohs surgery. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# She did mention that she has residual basal cell carcinoma after excision of right anterior lateral neck and left lateral neck with Dr. Cusick on 8/4/23 which she elected to clinically monitor until follow up in 6 months after this procedure. She wondered if this would alter her above treatment plan. I told her that I would look into this, but after review of the Mohs documentation from 8/4/23, do not see any contraindication to pursuing these above procedures.
#
# Pathology:
# Results for orders placed or performed in visit on 09/01/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Shaver, Rob L, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Liu, Vincent, MD
# Specimens:   A) - Skin shave, right temple
#              B) - Skin shave, upper right chest
#
#  	Diagnosis
#  	 	A. Skin, right temple, shave:
#             Basal cell carcinoma, with nodular features.
#
# B. Skin, upper right chest, shave:
#             Basal cell carcinoma, with superficial and nodular features.
#
#  	Clinical Information
#  	 	85 year old woman.  A) Skin shave, right temple.  B) Skin shave, upper right chest.
# 85 yo female with past medical history of several basal cell carcinoma, with new pink scaly macule on right temple and upper right chest.
#
# Differential diagnosis includes superficial basal cell carcinoma vs actinic keratosis.
#
# Differential diagnosis includes superficial basal cell carcinoma vs actinic keratosis.
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "right temple", is a 0.4 x 0.3 x 0.2 cm tan-white shave biopsy.  The specimen is inked and entirely submitted in A1.
# MME/tkr
# Specimen B
# Received in formalin, in a container labeled "upper right chest", is a 0.4 x 0.2 x 0.1 cm tan-white shave biopsy.   The specimen is inked, bisected and entirely submitted in B1.
# MME/tkr
#
#  	Microscopic Description
#  	 	A, Sections show a skin shave demonstrating a focally serous-crusted and eroded proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending from the epidermis into the underlying dermis, transected at specimen base.  Margins are involved.
# B. Sections show a skin shave demonstrating a basaloid proliferation of atypical epithelial cells arranged in islands that demonstrate multiple attachments to the overlying epidermis.  Margin is involved.
# Hannah Thompson, MD
# Dermatology, PGY-3
#
# I have personally reviewed this case and edited the report as necessary.
# Vincent Liu, MD
#
#
#
#
# ==================================================
#
# ==== False Negative at index 131 ====
# [Addendum]: Addendum 9/29/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Discussed that the lesions of the posterior left leg and face were melanoma in situ. Discussed the treatment of these lesions and the others as below.
#
# Discussed treatment options for melanoma in situ of the left posterior leg including wide local excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for wide local excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Discussed treatment options of midline low back and left posterior shoulder including topical efudex versus curettage and electrofulguration versus clinical monitoring. At this time, patient elects for curettage and electrofulguration . Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for curettage and electrofulguration. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months.
#
# Discussed treatment options for right cheek melanoma in situ and right pretibial skin infiltrative basal cell carcinoma including Mohs surgery. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical and high risk histopathology.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 09/25/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Palmer, Samuel J, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, Left posterior leg
#              B) - Skin shave, Right frontotemporal hairline
#              C) - Skin punch, Right malar cheek
#              D) - Skin shave, Left superior posterior shoulder
#              E) - Skin shave, Right of midline low back
#              F) - Skin shave, Right mid pretibial skin
#
#  	Diagnosis
#  	 	A. Skin, left posterior leg, shave biopsy:
#             Melanoma in situ, superficial spreading type.
#
# B. Skin, right frontotemporal hairline, shave biopsy:
#             Dermal nevus.
#
# C. Skin, right malar cheek, punch biopsy:
#             Melanoma in situ, lentigo maligna type.
#
# D. Skin, left superior posterior shoulder, shave biopsy:
#             Superficial basal cell carcinoma.
#
# E. Skin, right of midline low back, shave biopsy:
#             Superficial basal cell carcinoma.
#
# F. Skin, right mid pretibial skin, shave biopsy:
#             Basal cell carcinoma, with infiltrative features.
#
#
# I have personally reviewed this case and edited the report as necessary.
#
#  	Clinical Information
#  	 	A. Tan and brown patch with irregular borders and focus of telangiectasia differential diagnosis lentigo maligna vs lentigo vs collision nevus vs other
# B. Skin colored papule with inconspicuous telangiectasia differential diagnosis dermal nevus vs basal cell carcinoma vs other
# C. Tan to brown patch of the right cheek with overlying gritty scale differential diagnosis pigmented actinic keratosis vs lentigo vs lentigo maligna vs other
# D. Erythematous macule with telangiectasia on the left superior posterior shoulder differential diagnosis basal cell carcinoma vs other
# E. Erythematous macule with telangiectasia and shiny white lines on dermoscopy on the right of midline low back
# F. Erythematous pearly macule with telangiectasia on the left pretibial skin differential diagnosis basal cell carcinoma vs squamous cell carcinoma vs other
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "left posterior leg", is a 1.4 x 1 x 0.1 cm tan-white shave biopsy.  The specimen is inked, quadrisected and submitted entirely in A1.
# ARV/tkr
# Specimen B
# Received in formalin, in a container labeled "right frontotemporal hairline", is a 0.8 x 0.5 x 0.1 cm tan-white shave biopsy.  The specimen is inked, bisected and submitted entirely in B1.
# ARV/tkr
# Specimen C
# Received in formalin, in a container labeled "right malar cheek", is a 0.3 cm in diameter x 0.2 cm in length tan-white punch biopsy.  The specimen is inked, bisected and submitted entirely in C1.
# ARV/tkr
# Specimen D
# Received in formalin, in a container labeled "left superior posterior shoulder", is a 0.6 x 0.4 x 0.1 cm tan-white shave biopsy.  The specimen is inked, bisected and submitted entirely in D1.
# ARV/tkr
# Specimen E
# Received in formalin, in a container labeled "right of midline low back", is a 1 x 0.8 x 0.1 cm tan-white shave biopsy.  The specimen is inked, trisected and submitted entirely in E1.
# ARV/tkr
# Specimen F
# Received in formalin, in a container labeled "right mid pretibial skin", is a 1.1 x 0.9 x 0.1 cm tan-white shave biopsy.  The specimen is inked, trisected and submitted entirely in F1.
# ARV/tkr
#
#  	Microscopic Description
#  	 	A. Sections show a lentiginous, nested and pagetoid proliferation proliferation of atypical melanocytes intraepidermally. Margins are involved.
#
# B. Sections show a dermal proliferation of cytologically bland nevomelanocytes that are organized into nests.  The melanocytes demonstrate maturation with descent. Margins are involved.
#
# C. Sections show a lentiginous single cell and nested proliferation of atypical melanocytes intraepidermally along the dermal-epidermal junction with areas of background epidermal rete ridge attenuation noted.  Areas of lentiginous melanocytic confluence, focal pagetoid scatter, and melanocytic extension along follicular epithelia are seen. Margins are involved.
#
# D. Sections show a basaloid proliferation of atypical epithelial cells arranged in islands that demonstrate multiple attachments to the overlying epidermis.  The tumor islands are confined to the superficial dermis. Margins appear uninvolved in the plane of sectioning.
#
# E. Sections show a basaloid proliferation of atypical epithelial cells arranged in islands that demonstrate multiple attachments to the overlying epidermis.  The tumor islands are confined to the superficial dermis. Margins appear uninvolved in the plane of sectioning.
#
# F. Sections of skin show a proliferation of angulated islands of atypical basaloid epithelial cells with peripheral palisading, extending into the dermis. Margins are involved.
#
# Performed by: Mouaz Alsawas MD, R4
#
#
#
# ==================================================
#
# ==== False Negative at index 180 ====
# [Addendum]: Addendum 10/26/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# For G (right inferior calf)Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# For B (right dorsal medial wrist/hand), advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# For D (right dorsal medial hand), E (anterior upper thigh) discussed possibility of using Efudex twice daily for total of 6 weeks versus curettage and fulguration.  Patient elects to proceed with curettage and electrofulguration.  Will place order for same days as Mohs procedure and excision noted above.
#
# For C (right dorsal lateral hand) discussed possibility of deeper involvement of a skin cancer and options including use of Efudex versus rebiopsy to rule out deeper involvement.  Patient would rather do curettage and fulguration to this area if already doing procedures in nearby locations.  I discussed that we can discuss further about this at in person day of clinic visit for Mohs procedure/excision.
#
# Pathology:
# Results for orders placed or performed in visit on 10/19/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Thompson, Hannah J, MD     Collected:           10/19/2023 10:30 AM
# Ordering Location:     Dermatology Clinic         Received:            10/19/2023 11:56 AM
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, right dorsal forearm
#              B) - Skin shave, right dorsal medial wrist
#              C) - Skin shave, right dorsal lateral hand
#              D) - Skin shave, right dorsal medial hand
#              E) - Skin shave, anterior upper thigh
#              F) - Skin shave, right superior calf
#               G) - Skin shave, right inferior calf
#              H) - Skin punch, left upper eyelid
#
#  	Diagnosis
#  	 	A. Skin, right dorsal forearm, shave:
#            Verrucous keratosis.
# B. Skin, right dorsal medial wrist, shave:
#            Squamous cell carcinoma, well differentiated
# C. Skin, right dorsal lateral hand, shave:
#            At least hypertrophic actinic keratosis.
# D. Skin, right dorsal medial hand, shave:
#            Squamous cell carcinoma in situ.
# E. Skin, anterior upper thigh, shave:
#            At least squamous cell carcinoma in situ with keratoacanthomatous features in a background of verrucous keratosis.
# F. Skin, right superior calf, shave:
#            Verruca vulgaris.
# G. Skin, right inferior calf, shave:
#            Squamous cell carcinoma, well differentiated.
# H. Skin, left upper eyelid, shave:
#            Mild chronic inflammation.
#
#
# ==================================================
#
# ==== False Negative at index 187 ====
# [Addendum]: Addendum 10/27/2023
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# B, left ear lobe/C, central upper back) Discussed treatment options including excision versus clinical monitoring. At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# A, right temple) Discussed treatment options including Mohs surgery versus clinical monitoring. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 10/18/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Palmer, Samuel J, MD       Collected:           10/18/2023 02:36 PM
# Ordering Location:     Dermatology Clinic         Received:            10/18/2023 03:28 PM
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, Right temple
#              B) - Skin shave, Left ear lobule
#              C) - Skin shave, Central upper back
#
#  	Diagnosis
#  	 	A. Skin, right temple, shave:
#             Basal cell carcinoma.
#
# B. Skin, left ear lobule, shave:
#             Basal cell carcinoma.
#
# C. Skin, central upper back, shave:
#             Basal cell carcinoma.
#
#
# ==================================================
#
# ==== False Negative at index 227 ====
# [Addendum]: Addendum 11/17/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# For lesion (A):
# Advised Mohs surgery due to  location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# For lesion (B):
# At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# For lesion (C):
# No further treatment is indicated at this time.
#
#
# Pathology:
# Results for orders placed or performed in visit on 11/07/23
# DERMATOPATHOLOGY EXAM
#  	Diagnosis
#  	 	A. Skin, right lower antihelix, shave:
#             Basal cell carcinoma, with nodular and infiltrative features.
#
# B. Skin, right dorsal hand medial, shave:
#             Squamous cell carcinoma, invasive, well-differentiated, with adjacent features consistent with prurigo nodularis.
#
# C. Skin, right dorsal hand lateral, shave:
#              Features consistent with lentigo with associated melanin incontinence.
#
#
# ==================================================
#
# ==== False Negative at index 229 ====
# [Addendum]: Addendum 11/17/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# Discussed treatment options for lesion A (superficial basal cell carcinoma) on left postauricular skin including excision versus topical efudex versus curettage and electrofulguration versus clinical monitoring. At this time, patient elects for curettage and electrofulguration . Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for curettage and electrofulguration. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months.
#
# Discussed treatment options lesion B (basal cell carcinoma) on right posterior ear including Mohs surgery. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Discussed treatment options for lesion C (basal cell carcinoma) on right arm including excision versus curettage and electrofulguration versus clinical monitoring. At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Pathology:
# Results for orders placed or performed in visit on 11/13/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Shaver, Rob L, MD          Collected:           11/13/2023 02:45 PM
# Ordering Location:     Dermatology Clinic         Received:            11/13/2023 04:43 PM
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, Left postauricular skin
#              B) - Skin shave, Right posterior ear
#              C) - Skin shave, Right arm
#
#  	Diagnosis
#  	 	A: Skin, left postauricular skin, shave:
#             Superficial basal cell carcinoma.
#
# B: Skin, right posterior ear, shave:
#             Basal cell carcinoma.
#
#
# C: Skin, right arm, shave:
#             Basal cell carcinoma.
#
#
# ==================================================
#
# ==== False Negative at index 238 ====
# [Addendum]: addendum 11/16/2023
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# B) Discussed treatment options including excision versus curettage and electrofulguration. At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# A) Discussed treatment options including Mohs surgery versus excision vs clinical monitoring. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to large size and recurrent nature where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 11/10/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Anderson, Elizabeth J, MD  Collected:           11/10/2023 05:28 PM
# Ordering Location:     Dermatology Clinic         Received:            11/13/2023 09:53 AM
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, superior medial upper back
#              B) - Skin shave, inferior medial upper back
#              C) - Skin shave, left posterior shoulder
#
#  	Diagnosis
#  	 	A. Skin, superior medial upper back, shave:
#             Basal cell carcinoma.
#
# B. Skin, inferior medial upper back, shave:
#             Basal cell carcinoma.
#
# C. Skin, left posterior shoulder, shave:
#             Chronic and granulomatous inflammation.
#
#
# ==================================================
#
# ==== False Negative at index 246 ====
# [Addendum]: Addendum 11/29/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# Follow up for excision on the back. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# Patient notified of biopsy result, advised Mohs surgery due to  location where tissue conservation is critical on the right cheek.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are  not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Follow up in 3 months for repeat skin check.
#
# Pathology:
# Results for orders placed or performed in visit on 11/22/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Burdick, Halie N, MD       Collected:           11/22/2023 08:55 AM
# Ordering Location:     Dermatology Clinic         Received:            11/22/2023 09:58 AM
# Pathologist:           Seline, Alison E, MD
# Specimens:   A) - Skin shave, right cheek
#              B) - Skin shave, central back
#
#  	Diagnosis
#  	 	A. Skin, right cheek, shave:
#             Malignant melanoma in situ, lentigo maligna type.
#
# B. Skin, central back, shave:
#             Malignant melanoma, superficial spreading type, 0.3 mm Breslow depth, Clark level II, arising in association with a lentiginous compound nevus.
#             See synoptic report for details.
#
#
# ==================================================
#
# ==== False Negative at index 265 ====
# [Addendum]: ADDENDUM
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# B- right clavicle) Discussed treatment options including excision vs curettage and electrofulguration vs clinical monitoring. At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# A- nasal dorsum) Discussed treatment options including Mohs surgery vs excision vs curettage and electrofulguration. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 12/04/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Anderson, Elizabeth J, MD  Collected:           12/04/2023 11:16 AM
# Ordering Location:     Dermatology Clinic         Received:            12/04/2023 11:45 AM
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, nasal dorsum
#              B) - Skin shave, right clavicle
#
#  	Diagnosis
#  	 	A: Skin, nasal dorsum, shave:
#      Basal cell carcinoma.
#
# B: Skin, right clavicle, shave:
#      Basal cell carcinoma, pigmented.
#
#
# ==================================================
#
# ==== False Negative at index 285 ====
# [Addendum]: Addendum 12/8/2023
# Attempted to call on 12/8/23 @ 5 pm, 12/11/23 @ 5:15pm, left voicemail. The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
#
# B) Discussed treatment options including excision vs curettage and electrofulguration  At this time, patient elects for excision. Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits. Follow up for excision. Patient denies having artificial heart valves, artificial joints, or a cardiac stent within the last 3 months. Prophylactic antibiotics are not indicated.
#
# A) Discussed treatment options including Mohs surgery vs excision.  At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 12/04/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Anderson, Elizabeth J, MD  Collected:           12/04/2023 04:55 PM
# Ordering Location:     Dermatology Clinic         Received:            12/04/2023 05:11 PM
# Pathologist:           Swick, Brian L, MD
# Specimens:   A) - Skin shave, Left posterior neck
#              B) - Skin shave, Right posterior shoulder
#
#  	Diagnosis
#  	 	A.  Skin, left posterior neck, shave:
#             Basal cell carcinoma, micronodular.
# B.  Skin, right posterior shoulder, shave:
#             Basal cell carcinoma.
#
#
# ==================================================

# %%
# Configure pandas to show full text
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

for i in range(sample_size):
    if true_results[i] == "N" and output[i] == "Yes":
        print(f"\n==== False Positive at index {i} ====")
        # Print full text of both columns
        print("[Addendum]:", Cat.at[i, 'Addendum (A)'])
        print("=" * 50)
# Out:
# ==== False Positive at index 1 ====
# [Addendum]: Addendum 7/11/2023
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Patient notified of biopsy result, advised Mohs surgery due to recurrent nature, ill defined margins, and location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications.  Preoperative antibiotics are  not indicated.  Phone Mohs completed and order placed for Mohs 3.0.
#
# Pathology:
# Results for orders placed or performed in visit on 07/05/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Killoran, Emma A, MD       Colle
# Ordering Location:     Dermatology Clinic
# Pathologist:           Swick, Brian L, MD
# Specimen:    Skin shave, right alar groove
#
#  	Diagnosis
#  	 	Skin, right alar groove, shave biopsy:
#             Basal cell carcinoma.
#
#
# I have personally reviewed this case and edited the report as necessary.
#
#  	Clinical Information
#  	 	Eroded erythematous papule on the right nasal alar groove pt reports prior surgery to the area eval for basal cell carcinoma vs other
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "right alar groove", is a 0.7 x 0.7 x 0.1 cm white-tan shave biopsy.  The specimen is inked, quartered and submitted entirely in A1.
# BNS/rkw
#
#  	Microscopic Description
#  	 	Sections of skin show a proliferation of islands of atypical basaloid epithelial cells with peripheral palisading, extending into the dermis. Margins are involved.
#
#
# ==================================================
#
# ==== False Positive at index 11 ====
# [Addendum]: Addendum 7/20/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Patient notified of biopsy result, advised Mohs surgery due to location where tissue conservation is critical and recurrent nature of the lesion.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure. Preoperative antibiotics are not indicated. Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 07/12/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Poggemiller, Andrew M, MD  Collected:
# Ordering Location:     Dermatology Clinic
# Pathologist:           Liu, Vincent, MD
# Specimen:    Skin shave, left dorsal hand previous c and f site
#
#  	Diagnosis
#  	 	Skin, left dorsal hand (previous C and F site), shave:
#              Residual squamous cell carcinoma, at least in situ.
#              Scar and changes consistent with prior surgical site.
#
#  	Clinical Information
#  	 	Skin shave, left dorsal hand previous c and f site.
# New nodularity and tenderness at previous curettage and electrofulguration site (biopsy confirmed at least squamous cell carcinoma in situ). Differential diagnosis squamous cell carcinoma vs residual squamous cell carcinoma in situ vs other.:
# "... B. Skin, left dorsal hand, shave:
#              Squamous cell carcinoma, at least in situ."]
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled Bell, Mary T, hospital number, and "left dorsal hand previous C and F site", are two separate shave excisions of tan-pink skin measuring up to 0.7 and 1.3 cm in greatest dimension.  The smaller shave is inked green and the larger shave is inked blue and each are sectioned.  The entire specimen is submitted in A1.
# MW/rkw
#
#  	Microscopic Description
#  	 	Sections show a skin shave demonstrating a hyperparakeratotic squamocystic proliferation of atypical keratinocytes, extending to margin, and transected at specimen base.  Background epidermal rete ridge attenuation overlying horizontal dermal fibrosis featuring variably arcuate, small blood vessels and scattered chronic inflammation is seen.
# Performed by: Amr Masaadeh, MBBS, R3
#
# I have personally reviewed this case and edited the report as necessary.
# Vincent Liu, MD
#
#
# ==================================================
#
# ==== False Positive at index 32 ====
# [Addendum]: Addendum 8/3/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# For both lesions (A) and (B):
# Discussed treatment options including Mohs surgery versus excision versus topical efudex versus clinical monitoring. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to  location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# In addition, will recommend scout biopsies of 3.5 cm x 2.2 cm erythematous scaly verruciform plaque on the left anterior neck, as this lesion is suspicious for squamous cell carcinoma. This lesion was mistakenly thought to be the previously biopsied and treated squamous cell carcinoma in situ of the left neck (biopsied 2/17/22), therefore we forewent biopsy at his last visit.
#
# Pathology:
# Results for orders placed or performed in visit on 07/20/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Abid, Roshan A, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Liu, Vincent, MD
# Specimens:   A) - Skin shave, left superior neck
#              B) - Skin shave, left inferior neck
#
#  	Diagnosis
#  	 	A. Skin, left superior neck, shave:
#             Squamous cell carcinoma in situ.
#
# B. Skin, left inferior neck, shave:
#             Squamous cell carcinoma, microinvasive, well-differentiated.
#
#  	Clinical Information
#  	 	 A) Skin shave, left superior neck.  B) Skin shave, left inferior neck.
# (A) 7 mm x 5 mm erythematous scaly papule differential diagnosis includes squamous cell carcinoma vs squamous cell carcinoma in situ vs actinic keratosis vs other
# (B) 6 mm x 5 mm erythematous scaly papule differential diagnosis includes squamous cell carcinoma vs squamous cell carcinoma in situ vs actinic keratosis vs other
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "left superior neck", is a 1.1 x 0.9 x 0.1 cm tan-white shave biopsy.  The specimen is inked, trisected and submitted entirely in A1.
# ARV/tkr
# Specimen B
# Received in formalin, in a container labeled  "left inferior neck", is a 1.2 x 1 x 0.1 cm tan-white shave biopsy.  The specimen is inked, quadrisected and submitted entirely in B1.
# ARV/tkr
#
#  	Microscopic Description
#  	 	A. Sections show a skin shave demonstrating a compactly parakeratotic proliferation of full epidermal thickness jumbled, densely packed atypical keratinocytes, exhibiting scattered mitotic activity, trailing off peripheral margin.
# B. Sections show a skin shave demonstrating a serous-crusted and eroded hyperparakeratotic atypical squamous proliferation arising from the epidermis with extension into the dermis, measuring to a thickness of approximately 0.7 mm, trailing off to peripheral margin.
# Performed by: Amr Masaadeh, MBBS, R3
#
# I have personally reviewed this case and edited the report as necessary.
# Vincent Liu, MD
#
#
#
# Roshan Abid, MD
#
# Addendum 9/22/2023
# Attempted to call pt twice, unable to leave voicemail due to full mail box. Will attempt to call again with lab results.
#
# Morgan Samson, RN
#
#
# ==================================================
#
# ==== False Positive at index 34 ====
# [Addendum]: Addendum 8/3/2023
# Reviewed case with Dr. Liu and Mohs surgery, Dr. Cusick, who agree that definitive management with Mohs surgery for site of prior biopsy showing at least melanoma in situ is recommended. Other options include close clinical monitoring and topical imiquimod.
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge. Discussed options including risks and benefits of Mohs surgery vs close clinical monitoring vs topical imiquimod. Patient elected to proceed with Mohs surgery.
#
# Patient notified of biopsy result, advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation), benefits and alternatives as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 08/03/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Cheung, Kevin, MD
# Ordering Location:     UIHC Hospital Lab
# Pathologist:           Swick, Brian L, MD
# Specimen:    Outside material
#
#  	Diagnosis
#  	 	Skin, right cheek, shave
#             Melanoma in situ, lentigo maligna type
#
#
# I have personally reviewed this case and edited the report as necessary.
#
#  	Clinical Information
#  	 	Biopsy of the right cheek, previously diagnosed by outside read as at least melanoma in situ with deep and lateral edges involved.
#
# Comment: the lesion is focally transected, underlying invasion cannot be excluded.
#  	Gross Description
#  	 	Specimen A
#
#
#  	Microscopic Description
#  	 	A. Reviewed is a single H&E slide  Sections show a lentiginous single cell and nested proliferation of atypical melanocytes intraepidermally along the dermal-epidermal junction with areas of background epidermal rete ridge attenuation noted. Areas of lentiginous melanocytic confluence, focal pagetoid scatter, and melanocytic extension along follicular epithelia are seen. Margins are involved.
#
# Reviewed by Zak Sharif-Sidi, MD, PGY-3
#
#
# Results for orders placed or performed in visit on 07/25/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology
# Authorizing Provider:  Cheung, Kevin, MD
# Ordering Location:     Dermatology Clinic
# Pathologist:           Liu, Vincent, MD
# Specimen:    Skin punch, right cheek
#
#  	Diagnosis
#  	 	Skin, right cheek, punch:
#             Superficial dermal scar with associated chronic inflammation including melanophages (see comment).
#
#  	Comment
#  	 	Some features raise the possibility of regression.  Clinicopathologic correlation is recommended.
#
#
#  	Clinical Information
#  	 	Skin punch, right cheek.
# Pigmented scar, right cheek, previously biopsied as at least melanoma in situ in 7/2022, with positive margins, never received definitive treatment, now with increased pigmentation. Likely residual melanoma in situ in scar, would like to rule out invasive melanoma.
#  	Gross Description
#  	 	Specimen A
# Received in formalin, in a container labeled "right cheek", is a 0.3 cm in diameter x 0.4 cm in length tan-white punch biopsy.  The specimen is inked, bisected and submitted entirely in A1.
# TAE/tkr
#
#  	Microscopic Description
#  	 	Sections of a skin punch show a low density population of lentiginous melanocytes arrayed along the basilar epidermis, with also manifests central epidermal rete ridge attenuation whose dermal-epidermal junctional interface is partially obscured by lymphocyte-associated basilar epidermal squamatization with rare dyskeratosis, overlying horizontal dermal fibrosis featuring variably arcuate, small blood vessels and scattered chronic inflammation including melanophages..
# I have personally reviewed this case and edited the report as necessary.
# Vincent Liu, MD
#
#
#
# ==================================================
#
# ==== False Positive at index 207 ====
# [Addendum]: Addendum 11/13/2023
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
# Patient was instructed to continue management as planned and call the clinic for any further questions or concerns.
# Discussed treatment options for lesions A, B, C including Mohs surgery. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Plan to have separate day of surgery for lesions biopsied on 11/10/23, if indicated by biopsy results.
#
# Pathology:
# Results for orders placed or performed in visit on 11/03/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Shaver, Rob L, MD          Collected:           11/03/2023 01:48 PM
# Ordering Location:     Dermatology Clinic         Received:            11/03/2023 02:14 PM
# Pathologist:           Swick, Brian L, MD
# Specimens:   A) - Skin punch, right cheek
#              B) - Skin shave, right postauricular skin
#              C) - Skin shave, right superior lateral posterior neck
#
#  	Diagnosis
#  	 	A. Skin, right cheek, punch:
#            Infiltrative basal cell carcinoma.
#
# B. Skin, right postauricular skin, shave:
#            Basal cell carcinoma.
#
# C. Skin, right superior lateral posterior neck, shave:
#            Basal cell carcinoma.
#
#
# ==================================================
#
# ==== False Positive at index 279 ====
# [Addendum]: Addendum 12/8/2023
#
# The pathology results were relayed via phone call (see below). The patient is healing well without redness or discharge.
#
# Discussed treatment options including Mohs surgery for the site on the nose and scalp. At this time, patient elects for Mohs surgery. Advised Mohs surgery due to location where tissue conservation is critical.  Discussed risks (including but not limited to infection, bleeding, scar formation) and benefits as well as repair options that are often uncertain until the lesion has been excised, discussed that the surgical defect may be larger than the clinically evident lesion.  Reviewed the Mohs surgery process and advised to reserve the entire day for the procedure.  Advised to continue all medications. Preoperative antibiotics are not indicated.  Phone Mohs completed and submitted for scheduling.
#
# Pathology:
# Results for orders placed or performed in visit on 12/04/23
# DERMATOPATHOLOGY EXAM
# Result	Value	Ref Range
#  	Case Report
#  	 	Surgical Pathology                                Case:
# Authorizing Provider:  Palmer, Samuel J, MD       Collected:           12/04/2023 01:08 PM
# Ordering Location:     Dermatology Clinic         Received:            12/04/2023 02:30 PM
# Pathologist:           Stone, Mary S, MD
# Specimens:   A) - Skin shave, Frontal scalp
#              B) - Skin shave, Right nose
#
#  	Diagnosis
#  	 	A: Skin, frontal scalp, shave:
#      Squamous cell carcinoma in situ.
#
# B: Skin, right nose, shave:
#      Squamous cell carcinoma, moderately differentiated.
#
#
# ==================================================

# %%
n_count = 0
for i in range(0, min((sample_size), len(Cat))):
    if output_final[i].strip() != true_results_final[i].strip() and true_results_final[i] != "error_1" and output[i] != "Yes":
        n_count += 1
        print(f"i = {i}: Unfiltered ChatGPT Prediction = {output[i]}\nUnfiltered AT Given = {true_results[i]}")
        print(f"i = {i}: ChatGPT Prediction = {output_final[i]} AT Given = {true_results_final[i]}")
        print()
        print("-"*40) # Spacer
print(f"n_count = {n_count}")
# Out:
# i = 4: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 4: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 48: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y x 2
# i = 48: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 51: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y x 2
# i = 51: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 66: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 66: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 78: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y x 2
# i = 78: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 94: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 94: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 95: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 95: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 96: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 96: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 122: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 122: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 125: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 125: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 131: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 131: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 150: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y x5
# i = 150: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 159: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 159: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 164: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y x2
# i = 164: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 180: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 180: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 187: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 187: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 227: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 227: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 229: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 229: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 238: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 238: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 246: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 246: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 265: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 265: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# i = 285: Unfiltered ChatGPT Prediction = No
# Unfiltered AT Given = Y
# i = 285: ChatGPT Prediction = N AT Given = Y
#
# ----------------------------------------
# n_count = 22

# %%
y_count = 0
for i in range(0, min((sample_size), len(Cat))):
    if output_final[i] != true_results_final[i] and true_results_final[i] != "error_1" and output[i] != "No":
        y_count += 1
        print(f"i = {i}: Unfiltered ChatGPT Prediction = {output[i]}\nUnfiltered AT Given = {true_results[i]}")
        print(f"i = {i}: ChatGPT Prediction = {output_final[i]} AT Given = {true_results_final[i]}")
        print()
        print("-"*40) # Spacer
print(f"y_count = {y_count}")
# Out:
# i = 1: Unfiltered ChatGPT Prediction = Yes
# Unfiltered AT Given = N
# i = 1: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 11: Unfiltered ChatGPT Prediction = Yes
# Unfiltered AT Given = N
# i = 11: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 32: Unfiltered ChatGPT Prediction = Yes
# Unfiltered AT Given = N
# i = 32: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 34: Unfiltered ChatGPT Prediction = Yes
# Unfiltered AT Given = N
# i = 34: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 207: Unfiltered ChatGPT Prediction = Yes
# Unfiltered AT Given = N
# i = 207: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# i = 279: Unfiltered ChatGPT Prediction = Yes
# Unfiltered AT Given = N
# i = 279: ChatGPT Prediction = Y AT Given = N
#
# ----------------------------------------
# y_count = 6

# %%
count = 0
for i in range(0, min((sample_size), len(Cat))):
    if true_results_final[i] == "N":
        count += 1
print(f"no_count = {count}")
# 24 and 113 are bad notes for comparing, NA on every ground truth column
# Out:
# no_count = 269

# %%
def confusionMatrix():
    TP = TN = FP = FN = 0
    for i in range(0, min((sample_size), len(Cat))):
        if output_final[i] == true_results_final[i]: # True+/True-
            if output_final[i] == "Y": # True Positive
                TP += 1
            elif output_final[i] == "N": # True Negative
                TN += 1
        elif(output_final[i] != true_results_final[i] and true_results_final[i] != "error_1" and true_results_final[i] != "error_2"): # False+/False-
            if output_final[i] == "Y": # False Positive
                FP += 1
            elif output_final[i] == "N": # False Negative
                FN += 1
    return {"TP": TP, "TN": TN, "FP": FP, "FN": FN}

def confusionMetrics(confusion_matrix):
    TP = confusion_matrix["TP"]
    TN = confusion_matrix["TN"]
    FP = confusion_matrix["FP"]
    FN = confusion_matrix["FN"]
    
    total = TP + TN + FP + FN
    accuracy = (TP + TN) / (TP + TN + FP + FN) if total else 0 # How often did model predict correctly
    precision = TP / (TP + FP) if (TP + FP) else 0 # When model predicted Y, how often was it correct
    recall = TP / (TP + FN) if (TP + FN) else 0 # How many of the true Y cases did model correctly identify
    F1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) else 0 # Balance between Precision and Recall
    
    return {"accuracy": accuracy, "precision": precision, "recall": recall, "F1": F1}

            
total_size = 0
correct_predictions = 0
no_response_given = 0
no_alphabetical_result_returned = 0
bad_cases_combined = 0
nrg_not_narr = 0
narr_not_nrg = 0
# nrg = no valid response given in (L) column
# narr = no alphabetical result returned from ChatGPT output

for i in range(0, min((sample_size), len(Cat))):
    if(output_final[i] == "error_2" and true_results_final[i] == "error_1"):
        bad_cases_combined += 1
        
    if output_final[i] == "error_2":
        no_alphabetical_result_returned += 1
        if true_results_final[i] != "error_1":
            narr_not_nrg += 1
            
    if true_results_final[i] == "error_1":
        no_response_given += 1
        if output_final[i] != "error_2":
            nrg_not_narr += 1
    
    if output_final[i] == true_results_final[i]:
        correct_predictions += 1
        
    total_size += 1
    
accuracy = correct_predictions / total_size
print("# of Correct Predictions = " + str(correct_predictions))
print("Sample Size = " + str(total_size))
print("Accuracy = " + "{:.2f}%".format(accuracy * 100))
print()

# Accuracy when removing cases where the Location is not given (best to look at)
no_response_given_accuracy = correct_predictions / (total_size - no_response_given)
print("Number of Notes without a Given AE = " + str(no_response_given))
print("Accuracy = " +"{:.2f}%".format(no_response_given_accuracy * 100))
print()

# Accuracy when removing cases where GPT didn't return a valid alphabetical answer (not the best to look at, could be slightly lower)
no_alphabetical_result_returned_accuracy = correct_predictions / (total_size - no_alphabetical_result_returned)
print("Number of PE/A&P/A Notes without a valid GPT Given AE = " + str(no_alphabetical_result_returned))
print("Accuracy = " + "{:.2f}%".format(no_alphabetical_result_returned_accuracy * 100))
print()

# Accuracy when removing all above bad cases (ok to look at, could be slightly lower)
bad_cases_total_accuracy = correct_predictions / (total_size - (narr_not_nrg + nrg_not_narr + bad_cases_combined))
print("Number of Combined Notes without a Given AE = " + str(narr_not_nrg + nrg_not_narr + bad_cases_combined))
print("Accuracy = " + "{:.2f}%".format(bad_cases_total_accuracy * 100))
print()

confusion_matrix = confusionMatrix()
confusion_metrics = confusionMetrics(confusion_matrix)

print("Confusion Matrix:")
for name, value in confusion_matrix.items():
    print(f"{name}: {value}")

print("\nConfusion Matrix Metrics:")
for name, value in confusion_metrics.items():
    print(f"{name}: {(value * 100):.2f}")
# Out:
# # of Correct Predictions = 263
# Sample Size = 294
# Accuracy = 89.46%
#
# Number of Notes without a Given AE = 3
# Accuracy = 90.38%
#
# Number of PE/A&P/A Notes without a valid GPT Given AE = 0
# Accuracy = 89.46%
#
# Number of Combined Notes without a Given AE = 3
# Accuracy = 90.38%
#
# Confusion Matrix:
# TP: 0
# TN: 263
# FP: 6
# FN: 22
#
# Confusion Matrix Metrics:
# accuracy: 90.38
# precision: 0.00
# recall: 0.00
# F1: 0.00
